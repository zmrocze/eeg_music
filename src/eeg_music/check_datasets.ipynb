# %%
# Investigate music channel scaling and search for meaningful values
from mne_bids import BIDSPath, read_raw_bids
import pandas as pd
import numpy as np

print("🔍 INVESTIGATING MUSIC CHANNEL SCALING")
print("=" * 50)

# Load genMusic01 data
bids_path = BIDSPath(
    subject='01',
    task='genMusic01', 
    datatype='eeg',
    root='./datasets/bcmi/bcmi-fmri'
)

raw = read_raw_bids(bids_path, verbose=False)

# Get the full music channel data
music_idx = raw.ch_names.index('music')
music_data = raw.get_data(picks=[music_idx])[0]

print(f"Music channel statistics:")
print(f"  Min: {music_data.min():.6e}")
print(f"  Max: {music_data.max():.6e}")
print(f"  Mean: {music_data.mean():.6e}")
print(f"  Std: {music_data.std():.6e}")

# Look for meaningful values (not tiny)
non_zero = music_data[music_data != 0]
print(f"  Non-zero values: {len(non_zero)}")

if len(non_zero) > 0:
    print(f"  Non-zero min: {non_zero.min():.6e}")
    print(f"  Non-zero max: {non_zero.max():.6e}")
    
    # Try different scaling factors
    print(f"\nTrying different scaling factors:")
    for scale in [1, 10, 20, 100, 1000, 10000, 100000, 1000000]:
        scaled_values = non_zero * scale
        reasonable_codes = scaled_values[(scaled_values >= 100) & (scaled_values <= 999)]
        
        print(f"  Scale x{scale:7d}: Range [{scaled_values.min():.1f}, {scaled_values.max():.1f}], "
              f"3-digit codes: {len(reasonable_codes)}")
        
        if len(reasonable_codes) > 0:
            print(f"    Sample 3-digit codes: {reasonable_codes[:5].astype(int)}")

# Check if there are distinct levels in the music channel
unique_values = np.unique(music_data)
print(f"\nUnique values in music channel: {len(unique_values)}")
if len(unique_values) <= 20:
    print(f"All unique values: {unique_values}")
else:
    print(f"First 10 unique values: {unique_values[:10]}")
    print(f"Last 10 unique values: {unique_values[-10:]}")

# Try to find the pattern around meaningful transitions
if len(unique_values) > 2:  # More than just 0 and one other value
    # Find transitions between different values
    diff_indices = np.where(np.diff(music_data) != 0)[0]
    print(f"\nTransitions in music channel: {len(diff_indices)}")
    
    if len(diff_indices) > 0:
        print("Sample transitions:")
        for i, idx in enumerate(diff_indices[:10]):
            time_s = idx / raw.info['sfreq']
            val_before = music_data[idx]
            val_after = music_data[idx + 1]
            print(f"  {i+1:2d}: t={time_s:7.3f}s, {val_before:.6e} -> {val_after:.6e}")
# Out:
# 🔍 INVESTIGATING MUSIC CHANNEL SCALING
# ==================================================
# Music channel statistics:
#   Min: 0.000000e+00
#   Max: 4.115000e-05
#   Mean: 3.410357e-07
#   Std: 3.113802e-06
#   Non-zero values: 11000
#   Non-zero min: 1.405009e-05
#   Non-zero max: 4.115000e-05
#
# Trying different scaling factors:
#   Scale x      1: Range [0.0, 0.0], 3-digit codes: 0
#   Scale x     10: Range [0.0, 0.0], 3-digit codes: 0
#   Scale x     20: Range [0.0, 0.0], 3-digit codes: 0
#   Scale x    100: Range [0.0, 0.0], 3-digit codes: 0
#   Scale x   1000: Range [0.0, 0.0], 3-digit codes: 0
#   Scale x  10000: Range [0.1, 0.4], 3-digit codes: 0
#   Scale x 100000: Range [1.4, 4.1], 3-digit codes: 0
#   Scale x1000000: Range [14.1, 41.1], 3-digit codes: 0
#
# Unique values in music channel: 8
# All unique values: [0.00000000e+00 1.40500862e-05 1.40996910e-05 1.41499237e-05
#  2.25996918e-05 4.10501625e-05 4.10997673e-05 4.11500000e-05]
#
# Transitions in music channel: 22
# Sample transitions:
#    1: t=190.999s, 0.000000e+00 -> 1.405009e-05
#    2: t=191.999s, 1.405009e-05 -> 0.000000e+00
#    3: t=237.999s, 0.000000e+00 -> 2.259969e-05
#    4: t=238.999s, 2.259969e-05 -> 0.000000e+00
#    5: t=282.999s, 0.000000e+00 -> 1.409969e-05
#    6: t=283.999s, 1.409969e-05 -> 0.000000e+00
#    7: t=326.999s, 0.000000e+00 -> 4.105016e-05
#    8: t=327.999s, 4.105016e-05 -> 0.000000e+00
#    9: t=372.999s, 0.000000e+00 -> 1.409969e-05
#   10: t=373.999s, 1.409969e-05 -> 0.000000e+00
# /tmp/ipykernel_147882/2173051345.py:17: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_147882/2173051345.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_147882/2173051345.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_147882/2173051345.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_147882/2173051345.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_147882/2173051345.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_147882/2173051345.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_147882/2173051345.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_147882/2173051345.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_147882/2173051345.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_147882/2173051345.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_147882/2173051345.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_147882/2173051345.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_147882/2173051345.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_147882/2173051345.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_147882/2173051345.py:17: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_147882/2173051345.py:17: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)

# %%
# Map distinct music channel values to music codes
print("🎵 MAPPING MUSIC CHANNEL VALUES TO CODES")
print("=" * 50)

# We found 8 unique non-zero values
unique_music_vals = np.array([1.40500862e-05, 1.40996910e-05, 1.41499237e-05,
                              2.25996918e-05, 4.10501625e-05, 4.10997673e-05, 4.11500000e-05])

print("Distinct music channel values (non-zero):")
for i, val in enumerate(unique_music_vals):
    # Try different scaling approaches
    scaled_20 = val * 20
    scaled_100k = val * 100000
    scaled_1m = val * 1000000
    
    print(f"  Value {i+1}: {val:.6e}")
    print(f"    * 20 = {scaled_20:.6f}")
    print(f"    * 100k = {scaled_100k:.1f}")
    print(f"    * 1M = {scaled_1m:.1f}")
    print()

# Let's look at the actual pattern - maybe the values correspond to simple indices
print("Trying to map values to simple indices:")
value_to_code = {}
for i, val in enumerate(sorted(unique_music_vals)):
    code = i + 1  # Start from 1
    value_to_code[val] = code
    print(f"  {val:.6e} -> Code {code}")

print(f"\nValue-to-code mapping: {len(value_to_code)} codes")

# Now let's apply this mapping to the trial onsets
events_path = bids_path.copy().update(suffix='events', extension='.tsv')
events_df = pd.read_csv(events_path.fpath, sep='\t')
trial_starts = events_df[events_df['trial_type'] == 768].copy()
onsets = trial_starts['onset'].values
unique_onsets = onsets[np.concatenate([[True], np.diff(onsets) > 1])]

print(f"\nApplying mapping to trial onsets:")
music_idx = raw.ch_names.index('music')
sfreq = raw.info['sfreq']

for i, onset in enumerate(unique_onsets):
    sample_idx = int(onset * sfreq)
    if sample_idx < raw.n_times:
        music_val = raw.get_data(picks=[music_idx])[0, sample_idx]
        
        # Find closest matching value
        if music_val == 0:
            music_code = 0
            music_file = "generated/silence_or_baseline.wav"
        else:
            # Find the closest non-zero value
            closest_val = min(unique_music_vals, key=lambda x: abs(x - music_val))
            music_code = value_to_code[closest_val]
            
            # Format as traditional music file naming
            if music_code <= 9:
                # Single digit codes
                music_file = f"generated/unknown_code_{music_code}.wav"
            else:
                # Try to format as XXX -> X-X_X
                s_code = str(music_code).zfill(3)
                music_file = f"generated/{s_code[0]}-{s_code[1]}_{s_code[2]}.wav"
            
        print(f"  Trial {i+1:2d}: onset={onset:7.3f}s, val={music_val:.6e}, "
              f"code={music_code:2d}, file={music_file}")

# Let's also try a different approach - maybe the values encode actual music file numbers
print(f"\nAlternative: Direct value encoding (trying different scales):")
for i, onset in enumerate(unique_onsets[:5]):  # Just first 5 trials
    sample_idx = int(onset * sfreq)
    if sample_idx < raw.n_times:
        music_val = raw.get_data(picks=[music_idx])[0, sample_idx]
        
        # Try interpreting the value differently
        # Maybe it's encoded as a fraction or needs different scaling
        alt_code1 = int(round(music_val * 1000000))  # Scale to get integer
        alt_code2 = int(round(music_val / min(unique_music_vals)))  # Relative to smallest
        
        print(f"  Trial {i+1}: val={music_val:.6e}, alt1={alt_code1}, alt2={alt_code2}")
# Out:
# 🎵 MAPPING MUSIC CHANNEL VALUES TO CODES
# ==================================================
# Distinct music channel values (non-zero):
#   Value 1: 1.405009e-05
#     * 20 = 0.000281
#     * 100k = 1.4
#     * 1M = 14.1
#
#   Value 2: 1.409969e-05
#     * 20 = 0.000282
#     * 100k = 1.4
#     * 1M = 14.1
#
#   Value 3: 1.414992e-05
#     * 20 = 0.000283
#     * 100k = 1.4
#     * 1M = 14.1
#
#   Value 4: 2.259969e-05
#     * 20 = 0.000452
#     * 100k = 2.3
#     * 1M = 22.6
#
#   Value 5: 4.105016e-05
#     * 20 = 0.000821
#     * 100k = 4.1
#     * 1M = 41.1
#
#   Value 6: 4.109977e-05
#     * 20 = 0.000822
#     * 100k = 4.1
#     * 1M = 41.1
#
#   Value 7: 4.115000e-05
#     * 20 = 0.000823
#     * 100k = 4.1
#     * 1M = 41.1
#
# Trying to map values to simple indices:
#   1.405009e-05 -> Code 1
#   1.409969e-05 -> Code 2
#   1.414992e-05 -> Code 3
#   2.259969e-05 -> Code 4
#   4.105016e-05 -> Code 5
#   4.109977e-05 -> Code 6
#   4.115000e-05 -> Code 7
#
# Value-to-code mapping: 7 codes
#
# Applying mapping to trial onsets:
#   Trial  1: onset=191.151s, val=1.405009e-05, code= 1, file=generated/unknown_code_1.wav
#   Trial  2: onset=238.056s, val=2.259969e-05, code= 4, file=generated/unknown_code_4.wav
#   Trial  3: onset=283.447s, val=1.409969e-05, code= 2, file=generated/unknown_code_2.wav
#   Trial  4: onset=327.102s, val=4.105016e-05, code= 5, file=generated/unknown_code_5.wav
#   Trial  5: onset=373.110s, val=1.409969e-05, code= 2, file=generated/unknown_code_2.wav
#   Trial  6: onset=417.098s, val=1.409969e-05, code= 2, file=generated/unknown_code_2.wav
#   Trial  7: onset=464.092s, val=4.109977e-05, code= 6, file=generated/unknown_code_6.wav
#   Trial  8: onset=507.697s, val=1.414992e-05, code= 3, file=generated/unknown_code_3.wav
#   Trial  9: onset=552.086s, val=1.405009e-05, code= 1, file=generated/unknown_code_1.wav
#   Trial 10: onset=597.493s, val=0.000000e+00, code= 0, file=generated/silence_or_baseline.wav
#   Trial 11: onset=643.735s, val=4.115000e-05, code= 7, file=generated/unknown_code_7.wav
#   Trial 12: onset=689.143s, val=2.259969e-05, code= 4, file=generated/unknown_code_4.wav
#
# Alternative: Direct value encoding (trying different scales):
#   Trial 1: val=1.405009e-05, alt1=14, alt2=1
#   Trial 2: val=2.259969e-05, alt1=23, alt2=2
#   Trial 3: val=1.409969e-05, alt1=14, alt2=1
#   Trial 4: val=4.105016e-05, alt1=41, alt2=3
#   Trial 5: val=1.409969e-05, alt1=14, alt2=1

# %%
# Test classical music trial processing
print("🎼 TESTING CLASSICAL MUSIC TRIALS")
print("=" * 40)

# Load classicalMusic data
classical_bids_path = BIDSPath(
    subject='01',
    task='classicalMusic', 
    datatype='eeg',
    root='./datasets/bcmi/bcmi-fmri'
)

try:
    classical_raw = read_raw_bids(classical_bids_path, verbose=False)
    classical_events_path = classical_bids_path.copy().update(suffix='events', extension='.tsv')
    classical_events_df = pd.read_csv(classical_events_path.fpath, sep='\t')
    
    print(f"Classical music recording:")
    print(f"  Duration: {classical_raw.times[-1]:.1f} seconds")
    print(f"  Channels: {classical_raw.info['nchan']}")
    print(f"  Sampling rate: {classical_raw.info['sfreq']} Hz")
    
    # Find trial start markers (768)
    classical_trial_starts = classical_events_df[classical_events_df['trial_type'] == 768]
    print(f"\nTrial start events (768): {len(classical_trial_starts)}")
    
    if len(classical_trial_starts) > 0:
        print("Trial start events:")
        print(classical_trial_starts[['onset', 'duration', 'trial_type']].head())
        
        # Get unique onsets (removing consecutive duplicates)
        classical_onsets = classical_trial_starts['onset'].values
        classical_unique_onsets = classical_onsets[np.concatenate([[True], np.diff(classical_onsets) > 1])]
        
        print(f"\nUnique trial onsets: {len(classical_unique_onsets)}")
        for i, onset in enumerate(classical_unique_onsets):
            duration_to_end = classical_raw.times[-1] - onset
            print(f"  Trial {i+1}: onset={onset:.3f}s, duration_to_end={duration_to_end:.1f}s")
        
        # Check if there's a music channel in classical music data
        if 'music' in classical_raw.ch_names:
            print(f"\n'music' channel found in classical music data")
            music_idx = classical_raw.ch_names.index('music')
            music_data = classical_raw.get_data(picks=[music_idx])[0]
            
            print(f"  Music channel stats:")
            print(f"    Min: {music_data.min():.6e}")
            print(f"    Max: {music_data.max():.6e}")
            print(f"    Unique values: {len(np.unique(music_data))}")
            
            # Sample at first trial onset
            if len(classical_unique_onsets) > 0:
                first_onset = classical_unique_onsets[0]
                sample_idx = int(first_onset * classical_raw.info['sfreq'])
                music_val = music_data[sample_idx]
                print(f"    Value at first trial onset: {music_val:.6e}")
        else:
            print(f"\nNo 'music' channel in classical music data")
            print(f"Available channels: {classical_raw.ch_names}")
    
except Exception as e:
    print(f"Error loading classical music data: {e}")

print(f"\n✅ Classical music test completed!")
# Out:
# 🎼 TESTING CLASSICAL MUSIC TRIALS
# ========================================
# Classical music recording:
#   Duration: 1915.0 seconds
#   Channels: 47
#   Sampling rate: 1000.0 Hz
#
# Trial start events (768): 12
# Trial start events:
#        onset  duration  trial_type
# 35    31.771     0.001         768
# 246  195.807     0.001         768
# 456  362.010     0.001         768
# 654  517.864     0.001         768
# 842  676.140     0.001         768
#
# Unique trial onsets: 12
#   Trial 1: onset=31.771s, duration_to_end=1883.2s
#   Trial 2: onset=195.807s, duration_to_end=1719.2s
#   Trial 3: onset=362.010s, duration_to_end=1553.0s
#   Trial 4: onset=517.864s, duration_to_end=1397.1s
#   Trial 5: onset=676.140s, duration_to_end=1238.9s
#   Trial 6: onset=841.794s, duration_to_end=1073.2s
#   Trial 7: onset=973.926s, duration_to_end=941.1s
#   Trial 8: onset=1140.532s, duration_to_end=774.5s
#   Trial 9: onset=1296.737s, duration_to_end=618.3s
#   Trial 10: onset=1460.071s, duration_to_end=454.9s
#   Trial 11: onset=1594.423s, duration_to_end=320.6s
#   Trial 12: onset=1758.157s, duration_to_end=156.8s
#
# 'music' channel found in classical music data
# /tmp/ipykernel_147882/1370543555.py:14: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   classical_raw = read_raw_bids(classical_bids_path, verbose=False)
# /tmp/ipykernel_147882/1370543555.py:14: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   classical_raw = read_raw_bids(classical_bids_path, verbose=False)
# /tmp/ipykernel_147882/1370543555.py:14: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   classical_raw = read_raw_bids(classical_bids_path, verbose=False)
# /tmp/ipykernel_147882/1370543555.py:14: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   classical_raw = read_raw_bids(classical_bids_path, verbose=False)
# /tmp/ipykernel_147882/1370543555.py:14: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   classical_raw = read_raw_bids(classical_bids_path, verbose=False)
# /tmp/ipykernel_147882/1370543555.py:14: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   classical_raw = read_raw_bids(classical_bids_path, verbose=False)
# /tmp/ipykernel_147882/1370543555.py:14: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   classical_raw = read_raw_bids(classical_bids_path, verbose=False)
# /tmp/ipykernel_147882/1370543555.py:14: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   classical_raw = read_raw_bids(classical_bids_path, verbose=False)
# /tmp/ipykernel_147882/1370543555.py:14: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   classical_raw = read_raw_bids(classical_bids_path, verbose=False)
# /tmp/ipykernel_147882/1370543555.py:14: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   classical_raw = read_raw_bids(classical_bids_path, verbose=False)
# /tmp/ipykernel_147882/1370543555.py:14: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   classical_raw = read_raw_bids(classical_bids_path, verbose=False)
# /tmp/ipykernel_147882/1370543555.py:14: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   classical_raw = read_raw_bids(classical_bids_path, verbose=False)
# /tmp/ipykernel_147882/1370543555.py:14: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   classical_raw = read_raw_bids(classical_bids_path, verbose=False)
# /tmp/ipykernel_147882/1370543555.py:14: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   classical_raw = read_raw_bids(classical_bids_path, verbose=False)
# /tmp/ipykernel_147882/1370543555.py:14: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   classical_raw = read_raw_bids(classical_bids_path, verbose=False)
# /tmp/ipykernel_147882/1370543555.py:14: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   classical_raw = read_raw_bids(classical_bids_path, verbose=False)
# /tmp/ipykernel_147882/1370543555.py:14: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   classical_raw = read_raw_bids(classical_bids_path, verbose=False)
#   Music channel stats:
#     Min: 0.000000e+00
#     Max: 3.500000e-07
#     Unique values: 5
#     Value at first trial onset: 3.500000e-07
#
# ✅ Classical music test completed!

# %%
# Analyze classical music channel values in detail
print("🔍 CLASSICAL MUSIC CHANNEL ANALYSIS")
print("=" * 40)

music_idx = classical_raw.ch_names.index('music')
music_data = classical_raw.get_data(picks=[music_idx])[0]

# Find unique non-zero values
unique_values = np.unique(music_data)
non_zero_values = unique_values[unique_values > 0]

print(f"Unique music channel values in classical music:")
print(f"  Total unique values: {len(unique_values)}")
print(f"  Non-zero values: {len(non_zero_values)}")

for i, val in enumerate(non_zero_values):
    print(f"    Value {i+1}: {val:.10e}")

# Check values at each trial onset
print(f"\nMusic values at trial onsets:")
for i, onset in enumerate(classical_unique_onsets):
    sample_idx = int(onset * classical_raw.info['sfreq'])
    music_val = music_data[sample_idx]
    
    # Check if this corresponds to any known value
    if music_val > 0:
        value_idx = np.where(non_zero_values == music_val)[0]
        if len(value_idx) > 0:
            value_code = value_idx[0] + 1  # 1-based coding
        else:
            value_code = "unknown"
    else:
        value_code = 0
    
    print(f"  Trial {i+1} (t={onset:.3f}s): {music_val:.10e} -> code {value_code}")

# For classical music, we expect all trials to have the same music file
# The implementation suggests using run name for classical music rather than music channel
print(f"\nClassical music run type: task-classicalMusic")
print("Expected behavior: All trials should reference the same classical music file")
print("The music channel might not be meaningful for classical music trials")
# Out:
# 🔍 CLASSICAL MUSIC CHANNEL ANALYSIS
# ========================================
# Unique music channel values in classical music:
#   Total unique values: 5
#   Non-zero values: 4
#     Value 1: 9.9998474098e-08
#     Value 2: 1.4999771115e-07
#     Value 3: 2.5000152590e-07
#     Value 4: 3.5000000000e-07
#
# Music values at trial onsets:
#   Trial 1 (t=31.771s): 3.5000000000e-07 -> code 4
#   Trial 2 (t=195.807s): 2.5000152590e-07 -> code 3
#   Trial 3 (t=362.010s): 1.4999771115e-07 -> code 2
#   Trial 4 (t=517.864s): 1.4999771115e-07 -> code 2
#   Trial 5 (t=676.140s): 2.5000152590e-07 -> code 3
#   Trial 6 (t=841.794s): 9.9998474098e-08 -> code 1
#   Trial 7 (t=973.926s): 0.0000000000e+00 -> code 0
#   Trial 8 (t=1140.532s): 0.0000000000e+00 -> code 0
#   Trial 9 (t=1296.737s): 3.5000000000e-07 -> code 4
#   Trial 10 (t=1460.071s): 9.9998474098e-08 -> code 1
#   Trial 11 (t=1594.423s): 0.0000000000e+00 -> code 0
#   Trial 12 (t=1758.157s): 0.0000000000e+00 -> code 0
#
# Classical music run type: task-classicalMusic
# Expected behavior: All trials should reference the same classical music file
# The music channel might not be meaningful for classical music trials

# %%
# Test the updated BCMIFMRILoader implementation
print("🚀 TESTING UPDATED BCMIFMRILoader")
print("=" * 50)

# Reload the module to get the updated code
import importlib
import bcmi
importlib.reload(bcmi)

# Test genMusic01 with updated implementation
print("Testing genMusic01:")
try:
    gen_loader = bcmi.BCMIFMRILoader('./datasets/bcmi/bcmi-fmri')
    gen_data = gen_loader.load_subject_data('01', max_runs=1)
    
    # Check if we have any runs loaded
    if '01' in gen_data and gen_data['01']:
        print(f"  ✅ Loaded successfully")
        
        # Look for genMusic runs
        for run_name, run_data in gen_data['01'].items():
            if 'genMusic' in run_name:
                print(f"  Processing {run_name}:")
                print(f"    Recording duration: {run_data['raw'].times[-1]:.1f}s")
                
                # Check fMRI trials
                if 'fmri_trials' in run_data:
                    trials = run_data['fmri_trials']
                    print(f"    Number of trials: {len(trials)}")
                    
                    for trial in trials[:3]:  # Show first 3 trials
                        print(f"      Trial {trial['trial_number']}: onset={trial['onset']:.1f}s, "
                              f"music_code={trial['music_code']}, file={trial['music_file']}")
                else:
                    print("    ❌ No fMRI trials found")
                break
    else:
        print("  ❌ Failed to load data")
        
except Exception as e:
    print(f"  ❌ Error: {e}")
    import traceback
    traceback.print_exc()

print(f"\nTesting classicalMusic:")
try:
    # Load just one run to test classicalMusic
    all_data = gen_loader.load_all_subjects(max_subjects=1, max_runs_per_subject=10)
    
    if '01' in all_data and all_data['01']:
        # Look for classicalMusic run
        for run_name, run_data in all_data['01'].items():
            if 'classicalMusic' in run_name:
                print(f"  ✅ Found {run_name}")
                print(f"    Recording duration: {run_data['raw'].times[-1]:.1f}s")
                
                # Check fMRI trials
                if 'fmri_trials' in run_data:
                    trials = run_data['fmri_trials']
                    print(f"    Number of trials: {len(trials)}")
                    
                    for trial in trials[:3]:  # Show first 3 trials
                        print(f"      Trial {trial['trial_number']}: onset={trial['onset']:.1f}s, "
                              f"music_code={trial['music_code']}, file={trial['music_file']}")
                else:
                    print("    ❌ No fMRI trials found")
                break
        else:
            print("  ❌ No classicalMusic run found")
    else:
        print("  ❌ Failed to load data")
        
except Exception as e:
    print(f"  ❌ Error: {e}")
    import traceback
    traceback.print_exc()

print(f"\n✅ Updated implementation test completed!")
# Out:
# 🚀 TESTING UPDATED BCMIFMRILoader
# ==================================================
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 7
#       5 # Reload the module to get the updated code
#       6 import importlib
# ----> 7 import bcmi
#       8 importlib.reload(bcmi)
#      10 # Test genMusic01 with updated implementation
#
# ModuleNotFoundError: No module named 'bcmi'

# %%
import openneuro as on

# Download entire dataset
on.download(dataset='ds003774', target_dir='./musin_g_data')
# Out:
# 👋 Hello! This is openneuro-py 2025.1.0. Great to see you! 🤗
#
#    👉 Please report problems 🤯 and bugs 🪲 at
#       https://github.com/hoechenberger/openneuro-py/issues
#
# 🌍 Preparing to download ds003774 …
# 📁 Traversing directories for ds003774 : 0 entities [00:00, ? entities/s]
# 📥 Retrieving up to 1840 files (5 concurrent downloads).
# ✅ Finished downloading ds003774.
#
# 🧠 Please enjoy your brains.
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-005/ses-08/eeg/sub-005_ses-08_task-MusicListening_run-8_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-005/ses-08/eeg/sub-005_ses-08_task-MusicListening_run-8_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-005/ses-08/eeg/sub-005_ses-08_task-MusicListening_run-8_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-005/ses-09/eeg/sub-005_ses-09_task-MusicListening_run-9_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-005/ses-08/eeg/sub-005_ses-08_task-MusicListening_run-8_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-005/ses-09/eeg/sub-005_ses-09_task-MusicListening_run-9_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-005/ses-10/eeg/sub-005_ses-10_task-MusicListening_run-10_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-005/ses-11/eeg/sub-005_ses-11_task-MusicListening_run-11_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-005/ses-11/eeg/sub-005_ses-11_task-MusicListening_run-11_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-005/ses-11/eeg/sub-005_ses-11_task-MusicListening_run-11_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-005/ses-10/eeg/sub-005_ses-10_task-MusicListening_run-10_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-005/ses-11/eeg/sub-005_ses-11_task-MusicListening_run-11_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-005/ses-11/eeg/sub-005_ses-11_task-MusicListening_run-11_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-005/ses-11/eeg/sub-005_ses-11_task-MusicListening_run-11_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-006/ses-09/eeg/sub-006_ses-09_task-MusicListening_run-9_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-006/ses-09/eeg/sub-006_ses-09_task-MusicListening_run-9_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-006/ses-09/eeg/sub-006_ses-09_task-MusicListening_run-9_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-006/ses-09/eeg/sub-006_ses-09_task-MusicListening_run-9_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-006/ses-09/eeg/sub-006_ses-09_task-MusicListening_run-9_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-006/ses-09/eeg/sub-006_ses-09_task-MusicListening_run-9_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-006/ses-09/eeg/sub-006_ses-09_task-MusicListening_run-9_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-006/ses-09/eeg/sub-006_ses-09_task-MusicListening_run-9_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-006/ses-12/eeg/sub-006_ses-12_task-MusicListening_run-12_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-006/ses-12/eeg/sub-006_ses-12_task-MusicListening_run-12_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-006/ses-12/eeg/sub-006_ses-12_task-MusicListening_run-12_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-006/ses-12/eeg/sub-006_ses-12_task-MusicListening_run-12_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-006/ses-12/eeg/sub-006_ses-12_task-MusicListening_run-12_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-006/ses-12/eeg/sub-006_ses-12_task-MusicListening_run-12_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-006/ses-12/eeg/sub-006_ses-12_task-MusicListening_run-12_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-006/ses-12/eeg/sub-006_ses-12_task-MusicListening_run-12_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-02/eeg/sub-007_ses-02_task-MusicListening_run-2_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-02/eeg/sub-007_ses-02_task-MusicListening_run-2_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-03/eeg/sub-007_ses-03_task-MusicListening_run-3_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-02/eeg/sub-007_ses-02_task-MusicListening_run-2_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-02/eeg/sub-007_ses-02_task-MusicListening_run-2_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-03/eeg/sub-007_ses-03_task-MusicListening_run-3_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-03/eeg/sub-007_ses-03_task-MusicListening_run-3_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-03/eeg/sub-007_ses-03_task-MusicListening_run-3_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-03/eeg/sub-007_ses-03_task-MusicListening_run-3_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-03/eeg/sub-007_ses-03_task-MusicListening_run-3_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-04/eeg/sub-007_ses-04_task-MusicListening_run-4_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-04/eeg/sub-007_ses-04_task-MusicListening_run-4_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-04/eeg/sub-007_ses-04_task-MusicListening_run-4_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-04/eeg/sub-007_ses-04_task-MusicListening_run-4_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-05/eeg/sub-007_ses-05_task-MusicListening_run-5_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-04/eeg/sub-007_ses-04_task-MusicListening_run-4_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-04/eeg/sub-007_ses-04_task-MusicListening_run-4_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-05/eeg/sub-007_ses-05_task-MusicListening_run-5_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-07/eeg/sub-007_ses-07_task-MusicListening_run-7_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-07/eeg/sub-007_ses-07_task-MusicListening_run-7_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-07/eeg/sub-007_ses-07_task-MusicListening_run-7_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-07/eeg/sub-007_ses-07_task-MusicListening_run-7_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-07/eeg/sub-007_ses-07_task-MusicListening_run-7_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-07/eeg/sub-007_ses-07_task-MusicListening_run-7_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-07/eeg/sub-007_ses-07_task-MusicListening_run-7_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-07/eeg/sub-007_ses-07_task-MusicListening_run-7_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-09/eeg/sub-007_ses-09_task-MusicListening_run-9_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-09/eeg/sub-007_ses-09_task-MusicListening_run-9_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-09/eeg/sub-007_ses-09_task-MusicListening_run-9_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-09/eeg/sub-007_ses-09_task-MusicListening_run-9_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-10/eeg/sub-007_ses-10_task-MusicListening_run-10_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-10/eeg/sub-007_ses-10_task-MusicListening_run-10_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-10/eeg/sub-007_ses-10_task-MusicListening_run-10_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-10/eeg/sub-007_ses-10_task-MusicListening_run-10_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-12/eeg/sub-007_ses-12_task-MusicListening_run-12_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-12/eeg/sub-007_ses-12_task-MusicListening_run-12_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-12/eeg/sub-007_ses-12_task-MusicListening_run-12_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-12/eeg/sub-007_ses-12_task-MusicListening_run-12_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-12/eeg/sub-007_ses-12_task-MusicListening_run-12_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-007/ses-12/eeg/sub-007_ses-12_task-MusicListening_run-12_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-01/eeg/sub-008_ses-01_task-MusicListening_run-1_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-01/eeg/sub-008_ses-01_task-MusicListening_run-1_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-03/eeg/sub-008_ses-03_task-MusicListening_run-3_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-03/eeg/sub-008_ses-03_task-MusicListening_run-3_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-04/eeg/sub-008_ses-04_task-MusicListening_run-4_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-04/eeg/sub-008_ses-04_task-MusicListening_run-4_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-04/eeg/sub-008_ses-04_task-MusicListening_run-4_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-04/eeg/sub-008_ses-04_task-MusicListening_run-4_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-04/eeg/sub-008_ses-04_task-MusicListening_run-4_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-04/eeg/sub-008_ses-04_task-MusicListening_run-4_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-05/eeg/sub-008_ses-05_task-MusicListening_run-5_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-05/eeg/sub-008_ses-05_task-MusicListening_run-5_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-05/eeg/sub-008_ses-05_task-MusicListening_run-5_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-05/eeg/sub-008_ses-05_task-MusicListening_run-5_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-05/eeg/sub-008_ses-05_task-MusicListening_run-5_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-05/eeg/sub-008_ses-05_task-MusicListening_run-5_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-06/eeg/sub-008_ses-06_task-MusicListening_run-6_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-06/eeg/sub-008_ses-06_task-MusicListening_run-6_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-06/eeg/sub-008_ses-06_task-MusicListening_run-6_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-06/eeg/sub-008_ses-06_task-MusicListening_run-6_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-06/eeg/sub-008_ses-06_task-MusicListening_run-6_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-06/eeg/sub-008_ses-06_task-MusicListening_run-6_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-07/eeg/sub-008_ses-07_task-MusicListening_run-7_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-07/eeg/sub-008_ses-07_task-MusicListening_run-7_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-07/eeg/sub-008_ses-07_task-MusicListening_run-7_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-07/eeg/sub-008_ses-07_task-MusicListening_run-7_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-07/eeg/sub-008_ses-07_task-MusicListening_run-7_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-07/eeg/sub-008_ses-07_task-MusicListening_run-7_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-07/eeg/sub-008_ses-07_task-MusicListening_run-7_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-07/eeg/sub-008_ses-07_task-MusicListening_run-7_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-07/eeg/sub-008_ses-07_task-MusicListening_run-7_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-07/eeg/sub-008_ses-07_task-MusicListening_run-7_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-07/eeg/sub-008_ses-07_task-MusicListening_run-7_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-07/eeg/sub-008_ses-07_task-MusicListening_run-7_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-08/eeg/sub-008_ses-08_task-MusicListening_run-8_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-08/eeg/sub-008_ses-08_task-MusicListening_run-8_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-08/eeg/sub-008_ses-08_task-MusicListening_run-8_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-08/eeg/sub-008_ses-08_task-MusicListening_run-8_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-08/eeg/sub-008_ses-08_task-MusicListening_run-8_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-08/eeg/sub-008_ses-08_task-MusicListening_run-8_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-09/eeg/sub-008_ses-09_task-MusicListening_run-9_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-09/eeg/sub-008_ses-09_task-MusicListening_run-9_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-09/eeg/sub-008_ses-09_task-MusicListening_run-9_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-09/eeg/sub-008_ses-09_task-MusicListening_run-9_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-10/eeg/sub-008_ses-10_task-MusicListening_run-10_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-10/eeg/sub-008_ses-10_task-MusicListening_run-10_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-10/eeg/sub-008_ses-10_task-MusicListening_run-10_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-10/eeg/sub-008_ses-10_task-MusicListening_run-10_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-10/eeg/sub-008_ses-10_task-MusicListening_run-10_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-10/eeg/sub-008_ses-10_task-MusicListening_run-10_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-10/eeg/sub-008_ses-10_task-MusicListening_run-10_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-10/eeg/sub-008_ses-10_task-MusicListening_run-10_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-11/eeg/sub-008_ses-11_task-MusicListening_run-11_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-11/eeg/sub-008_ses-11_task-MusicListening_run-11_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-11/eeg/sub-008_ses-11_task-MusicListening_run-11_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-11/eeg/sub-008_ses-11_task-MusicListening_run-11_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-11/eeg/sub-008_ses-11_task-MusicListening_run-11_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-11/eeg/sub-008_ses-11_task-MusicListening_run-11_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-11/eeg/sub-008_ses-11_task-MusicListening_run-11_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-11/eeg/sub-008_ses-11_task-MusicListening_run-11_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-11/eeg/sub-008_ses-11_task-MusicListening_run-11_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-008/ses-11/eeg/sub-008_ses-11_task-MusicListening_run-11_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-009/ses-10/eeg/sub-009_ses-10_task-MusicListening_run-10_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-009/ses-10/eeg/sub-009_ses-10_task-MusicListening_run-10_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-009/ses-10/eeg/sub-009_ses-10_task-MusicListening_run-10_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-009/ses-10/eeg/sub-009_ses-10_task-MusicListening_run-10_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-009/ses-10/eeg/sub-009_ses-10_task-MusicListening_run-10_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-009/ses-10/eeg/sub-009_ses-10_task-MusicListening_run-10_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-009/ses-10/eeg/sub-009_ses-10_task-MusicListening_run-10_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-009/ses-10/eeg/sub-009_ses-10_task-MusicListening_run-10_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-01/eeg/sub-010_ses-01_task-MusicListening_run-1_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-01/eeg/sub-010_ses-01_task-MusicListening_run-1_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-01/eeg/sub-010_ses-01_task-MusicListening_run-1_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-01/eeg/sub-010_ses-01_task-MusicListening_run-1_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-01/eeg/sub-010_ses-01_task-MusicListening_run-1_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-01/eeg/sub-010_ses-01_task-MusicListening_run-1_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-01/eeg/sub-010_ses-01_task-MusicListening_run-1_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-01/eeg/sub-010_ses-01_task-MusicListening_run-1_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-03/eeg/sub-010_ses-03_task-MusicListening_run-3_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-04/eeg/sub-010_ses-04_task-MusicListening_run-4_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-03/eeg/sub-010_ses-03_task-MusicListening_run-3_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-04/eeg/sub-010_ses-04_task-MusicListening_run-4_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-04/eeg/sub-010_ses-04_task-MusicListening_run-4_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-04/eeg/sub-010_ses-04_task-MusicListening_run-4_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-04/eeg/sub-010_ses-04_task-MusicListening_run-4_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-04/eeg/sub-010_ses-04_task-MusicListening_run-4_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-06/eeg/sub-010_ses-06_task-MusicListening_run-6_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-06/eeg/sub-010_ses-06_task-MusicListening_run-6_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-06/eeg/sub-010_ses-06_task-MusicListening_run-6_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-06/eeg/sub-010_ses-06_task-MusicListening_run-6_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-07/eeg/sub-010_ses-07_task-MusicListening_run-7_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-07/eeg/sub-010_ses-07_task-MusicListening_run-7_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-07/eeg/sub-010_ses-07_task-MusicListening_run-7_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-07/eeg/sub-010_ses-07_task-MusicListening_run-7_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-07/eeg/sub-010_ses-07_task-MusicListening_run-7_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-010/ses-07/eeg/sub-010_ses-07_task-MusicListening_run-7_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-10/eeg/sub-012_ses-10_task-MusicListening_run-10_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-10/eeg/sub-012_ses-10_task-MusicListening_run-10_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-017/ses-04/eeg/sub-017_ses-04_task-MusicListening_run-4_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-017/ses-04/eeg/sub-017_ses-04_task-MusicListening_run-4_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-017/ses-04/eeg/sub-017_ses-04_task-MusicListening_run-4_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-017/ses-04/eeg/sub-017_ses-04_task-MusicListening_run-4_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-017/ses-04/eeg/sub-017_ses-04_task-MusicListening_run-4_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-017/ses-04/eeg/sub-017_ses-04_task-MusicListening_run-4_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-017/ses-04/eeg/sub-017_ses-04_task-MusicListening_run-4_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-017/ses-05/eeg/sub-017_ses-05_task-MusicListening_run-5_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-017/ses-04/eeg/sub-017_ses-04_task-MusicListening_run-4_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-017/ses-05/eeg/sub-017_ses-05_task-MusicListening_run-5_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-01/eeg/sub-018_ses-01_task-MusicListening_run-1_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-01/eeg/sub-018_ses-01_task-MusicListening_run-1_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-01/eeg/sub-018_ses-01_task-MusicListening_run-1_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-01/eeg/sub-018_ses-01_task-MusicListening_run-1_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-01/eeg/sub-018_ses-01_task-MusicListening_run-1_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-02/eeg/sub-018_ses-02_task-MusicListening_run-2_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-01/eeg/sub-018_ses-01_task-MusicListening_run-1_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-02/eeg/sub-018_ses-02_task-MusicListening_run-2_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-03/eeg/sub-018_ses-03_task-MusicListening_run-3_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-03/eeg/sub-018_ses-03_task-MusicListening_run-3_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-04/eeg/sub-018_ses-04_task-MusicListening_run-4_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-04/eeg/sub-018_ses-04_task-MusicListening_run-4_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-04/eeg/sub-018_ses-04_task-MusicListening_run-4_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-04/eeg/sub-018_ses-04_task-MusicListening_run-4_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-04/eeg/sub-018_ses-04_task-MusicListening_run-4_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-04/eeg/sub-018_ses-04_task-MusicListening_run-4_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-05/eeg/sub-018_ses-05_task-MusicListening_run-5_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-05/eeg/sub-018_ses-05_task-MusicListening_run-5_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-06/eeg/sub-018_ses-06_task-MusicListening_run-6_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-06/eeg/sub-018_ses-06_task-MusicListening_run-6_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-07/eeg/sub-018_ses-07_task-MusicListening_run-7_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-07/eeg/sub-018_ses-07_task-MusicListening_run-7_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-07/eeg/sub-018_ses-07_task-MusicListening_run-7_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-07/eeg/sub-018_ses-07_task-MusicListening_run-7_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-07/eeg/sub-018_ses-07_task-MusicListening_run-7_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-07/eeg/sub-018_ses-07_task-MusicListening_run-7_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-07/eeg/sub-018_ses-07_task-MusicListening_run-7_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-07/eeg/sub-018_ses-07_task-MusicListening_run-7_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-09/eeg/sub-018_ses-09_task-MusicListening_run-9_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-10/eeg/sub-018_ses-10_task-MusicListening_run-10_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-09/eeg/sub-018_ses-09_task-MusicListening_run-9_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-10/eeg/sub-018_ses-10_task-MusicListening_run-10_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-10/eeg/sub-018_ses-10_task-MusicListening_run-10_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-10/eeg/sub-018_ses-10_task-MusicListening_run-10_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-10/eeg/sub-018_ses-10_task-MusicListening_run-10_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-10/eeg/sub-018_ses-10_task-MusicListening_run-10_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-12/eeg/sub-018_ses-12_task-MusicListening_run-12_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-12/eeg/sub-018_ses-12_task-MusicListening_run-12_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-12/eeg/sub-018_ses-12_task-MusicListening_run-12_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-01/eeg/sub-019_ses-01_task-MusicListening_run-1_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-018/ses-12/eeg/sub-018_ses-12_task-MusicListening_run-12_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-01/eeg/sub-019_ses-01_task-MusicListening_run-1_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-01/eeg/sub-019_ses-01_task-MusicListening_run-1_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-01/eeg/sub-019_ses-01_task-MusicListening_run-1_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-02/eeg/sub-019_ses-02_task-MusicListening_run-2_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-02/eeg/sub-019_ses-02_task-MusicListening_run-2_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-03/eeg/sub-019_ses-03_task-MusicListening_run-3_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-03/eeg/sub-019_ses-03_task-MusicListening_run-3_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-03/eeg/sub-019_ses-03_task-MusicListening_run-3_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-03/eeg/sub-019_ses-03_task-MusicListening_run-3_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-03/eeg/sub-019_ses-03_task-MusicListening_run-3_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-03/eeg/sub-019_ses-03_task-MusicListening_run-3_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-03/eeg/sub-019_ses-03_task-MusicListening_run-3_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-03/eeg/sub-019_ses-03_task-MusicListening_run-3_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-04/eeg/sub-019_ses-04_task-MusicListening_run-4_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-04/eeg/sub-019_ses-04_task-MusicListening_run-4_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-04/eeg/sub-019_ses-04_task-MusicListening_run-4_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-04/eeg/sub-019_ses-04_task-MusicListening_run-4_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-04/eeg/sub-019_ses-04_task-MusicListening_run-4_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-04/eeg/sub-019_ses-04_task-MusicListening_run-4_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-04/eeg/sub-019_ses-04_task-MusicListening_run-4_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-04/eeg/sub-019_ses-04_task-MusicListening_run-4_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-06/eeg/sub-019_ses-06_task-MusicListening_run-6_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-06/eeg/sub-019_ses-06_task-MusicListening_run-6_electrodes.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-06/eeg/sub-019_ses-06_task-MusicListening_run-6_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-06/eeg/sub-019_ses-06_task-MusicListening_run-6_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-06/eeg/sub-019_ses-06_task-MusicListening_run-6_events.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-06/eeg/sub-019_ses-06_task-MusicListening_run-6_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-07/eeg/sub-019_ses-07_task-MusicListening_run-7_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-07/eeg/sub-019_ses-07_task-MusicListening_run-7_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-07/eeg/sub-019_ses-07_task-MusicListening_run-7_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-07/eeg/sub-019_ses-07_task-MusicListening_run-7_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-07/eeg/sub-019_ses-07_task-MusicListening_run-7_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-08/eeg/sub-019_ses-08_task-MusicListening_run-8_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-08/eeg/sub-019_ses-08_task-MusicListening_run-8_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-08/eeg/sub-019_ses-08_task-MusicListening_run-8_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-08/eeg/sub-019_ses-08_task-MusicListening_run-8_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-07/eeg/sub-019_ses-07_task-MusicListening_run-7_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-08/eeg/sub-019_ses-08_task-MusicListening_run-8_channels.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-08/eeg/sub-019_ses-08_task-MusicListening_run-8_coordsystem.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-08/eeg/sub-019_ses-08_task-MusicListening_run-8_eeg.json, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-08/eeg/sub-019_ses-08_task-MusicListening_run-8_eeg.set, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-08/eeg/sub-019_ses-08_task-MusicListening_run-8_electrodes.tsv, retrying in 0.5 sec …
# ...
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-020/ses-02/eeg/sub-020_ses-02_task-MusicListening_run-2_events.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-020/ses-02/eeg/sub-020_ses-02_task-MusicListening_run-2_events.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-020/ses-03/eeg/sub-020_ses-03_task-MusicListening_run-3_eeg.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-020/ses-03/eeg/sub-020_ses-03_task-MusicListening_run-3_electrodes.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-020/ses-04/eeg/sub-020_ses-04_task-MusicListening_run-4_channels.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-020/ses-04/eeg/sub-020_ses-04_task-MusicListening_run-4_coordsystem.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-020/ses-04/eeg/sub-020_ses-04_task-MusicListening_run-4_eeg.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-020/ses-04/eeg/sub-020_ses-04_task-MusicListening_run-4_eeg.set, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-020/ses-04/eeg/sub-020_ses-04_task-MusicListening_run-4_electrodes.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-020/ses-04/eeg/sub-020_ses-04_task-MusicListening_run-4_events.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-020/ses-05/eeg/sub-020_ses-05_task-MusicListening_run-5_channels.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-020/ses-05/eeg/sub-020_ses-05_task-MusicListening_run-5_coordsystem.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-020/ses-05/eeg/sub-020_ses-05_task-MusicListening_run-5_eeg.set, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-020/ses-05/eeg/sub-020_ses-05_task-MusicListening_run-5_electrodes.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-020/ses-05/eeg/sub-020_ses-05_task-MusicListening_run-5_events.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-004/ses-07/eeg/sub-004_ses-07_task-MusicListening_run-7_channels.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-004/ses-07/eeg/sub-004_ses-07_task-MusicListening_run-7_coordsystem.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-011/ses-09/eeg/sub-011_ses-09_task-MusicListening_run-9_eeg.set, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-011/ses-09/eeg/sub-011_ses-09_task-MusicListening_run-9_events.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-011/ses-10/eeg/sub-011_ses-10_task-MusicListening_run-10_eeg.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-011/ses-10/eeg/sub-011_ses-10_task-MusicListening_run-10_eeg.set, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-011/ses-11/eeg/sub-011_ses-11_task-MusicListening_run-11_eeg.set, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-011/ses-10/eeg/sub-011_ses-10_task-MusicListening_run-10_events.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-011/ses-11/eeg/sub-011_ses-11_task-MusicListening_run-11_events.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-011/ses-11/eeg/sub-011_ses-11_task-MusicListening_run-11_eeg.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-011/ses-10/eeg/sub-011_ses-10_task-MusicListening_run-10_events.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-011/ses-10/eeg/sub-011_ses-10_task-MusicListening_run-10_electrodes.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-011/ses-11/eeg/sub-011_ses-11_task-MusicListening_run-11_events.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-011/ses-11/eeg/sub-011_ses-11_task-MusicListening_run-11_electrodes.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-01/eeg/sub-012_ses-01_task-MusicListening_run-1_electrodes.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-01/eeg/sub-012_ses-01_task-MusicListening_run-1_events.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-011/ses-11/eeg/sub-011_ses-11_task-MusicListening_run-11_channels.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-011/ses-12/eeg/sub-011_ses-12_task-MusicListening_run-12_events.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-01/eeg/sub-012_ses-01_task-MusicListening_run-1_coordsystem.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-011/ses-12/eeg/sub-011_ses-12_task-MusicListening_run-12_events.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-011/ses-12/eeg/sub-011_ses-12_task-MusicListening_run-12_eeg.set, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-011/ses-12/eeg/sub-011_ses-12_task-MusicListening_run-12_electrodes.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-01/eeg/sub-012_ses-01_task-MusicListening_run-1_events.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-02/eeg/sub-012_ses-02_task-MusicListening_run-2_coordsystem.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-01/eeg/sub-012_ses-01_task-MusicListening_run-1_eeg.set, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-02/eeg/sub-012_ses-02_task-MusicListening_run-2_events.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-02/eeg/sub-012_ses-02_task-MusicListening_run-2_eeg.set, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-03/eeg/sub-012_ses-03_task-MusicListening_run-3_electrodes.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-03/eeg/sub-012_ses-03_task-MusicListening_run-3_eeg.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-02/eeg/sub-012_ses-02_task-MusicListening_run-2_eeg.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-03/eeg/sub-012_ses-03_task-MusicListening_run-3_eeg.set, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-03/eeg/sub-012_ses-03_task-MusicListening_run-3_channels.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-03/eeg/sub-012_ses-03_task-MusicListening_run-3_coordsystem.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-04/eeg/sub-012_ses-04_task-MusicListening_run-4_eeg.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-02/eeg/sub-012_ses-02_task-MusicListening_run-2_electrodes.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-04/eeg/sub-012_ses-04_task-MusicListening_run-4_channels.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-04/eeg/sub-012_ses-04_task-MusicListening_run-4_coordsystem.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-05/eeg/sub-012_ses-05_task-MusicListening_run-5_eeg.set, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-04/eeg/sub-012_ses-04_task-MusicListening_run-4_electrodes.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-05/eeg/sub-012_ses-05_task-MusicListening_run-5_electrodes.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-05/eeg/sub-012_ses-05_task-MusicListening_run-5_channels.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-02/eeg/sub-012_ses-02_task-MusicListening_run-2_events.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-03/eeg/sub-012_ses-03_task-MusicListening_run-3_events.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-04/eeg/sub-012_ses-04_task-MusicListening_run-4_events.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-04/eeg/sub-012_ses-04_task-MusicListening_run-4_eeg.set, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-05/eeg/sub-012_ses-05_task-MusicListening_run-5_events.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-05/eeg/sub-012_ses-05_task-MusicListening_run-5_events.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-04/eeg/sub-012_ses-04_task-MusicListening_run-4_events.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-06/eeg/sub-012_ses-06_task-MusicListening_run-6_events.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-03/eeg/sub-012_ses-03_task-MusicListening_run-3_events.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-05/eeg/sub-012_ses-05_task-MusicListening_run-5_coordsystem.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-06/eeg/sub-012_ses-06_task-MusicListening_run-6_electrodes.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-06/eeg/sub-012_ses-06_task-MusicListening_run-6_coordsystem.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-07/eeg/sub-012_ses-07_task-MusicListening_run-7_channels.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-08/eeg/sub-012_ses-08_task-MusicListening_run-8_eeg.set, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-09/eeg/sub-012_ses-09_task-MusicListening_run-9_channels.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-07/eeg/sub-012_ses-07_task-MusicListening_run-7_coordsystem.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-07/eeg/sub-012_ses-07_task-MusicListening_run-7_eeg.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-06/eeg/sub-012_ses-06_task-MusicListening_run-6_events.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-09/eeg/sub-012_ses-09_task-MusicListening_run-9_coordsystem.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-08/eeg/sub-012_ses-08_task-MusicListening_run-8_events.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-11/eeg/sub-012_ses-11_task-MusicListening_run-11_events.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-12/eeg/sub-012_ses-12_task-MusicListening_run-12_events.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-11/eeg/sub-012_ses-11_task-MusicListening_run-11_electrodes.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-012/ses-11/eeg/sub-012_ses-11_task-MusicListening_run-11_events.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-013/ses-08/eeg/sub-013_ses-08_task-MusicListening_run-8_coordsystem.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-014/ses-03/eeg/sub-014_ses-03_task-MusicListening_run-3_events.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-015/ses-12/eeg/sub-015_ses-12_task-MusicListening_run-12_coordsystem.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-015/ses-12/eeg/sub-015_ses-12_task-MusicListening_run-12_channels.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-014/ses-04/eeg/sub-014_ses-04_task-MusicListening_run-4_eeg.json, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-015/ses-12/eeg/sub-015_ses-12_task-MusicListening_run-12_electrodes.tsv, retrying in 8.0 sec …
# 🔄 Request timed out while downloading /home/zmrocze/studia/uwr/magisterka/musin_g_data/sub-019/ses-01/eeg/sub-019_ses-01_task-MusicListening_run-1_eeg.json, retrying in 8.0 sec …

# %%
# %load_ext autoreload
# %autoreload 2

from nmed_t import NMEDTLoader, main

main("./datasets/nmed-t")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# === NMED-T Dataset Summary ===
# Dataset: Naturalistic Music EEG Dataset - Tempo (NMED-T)
# Participants: 20
# Songs: 10
# Electrodes (cleaned): 125
# Sampling rate (cleaned): 125 Hz
#
# === Loading Cleaned EEG Data ===
# Loaded song 1: First Fires - Shape: (125, 34795, 20)
# Loaded song 1: First Fires - Shape: (125, 34795, 20)
# Loaded song 2: Oino - Shape: (125, 33891, 20)
# Loaded song 2: Oino - Shape: (125, 33891, 20)
# Loaded song 3: Tiptoes - Shape: (125, 34469, 20)
# Song 1: First Fires by Bonobo
#   Tempo: 55.97 BPM
#   EEG shape: (125, 34795, 20) - (electrodes=125, time_samples, participants=20)
#   Sampling rate: 125 Hz
# Song 2: Oino by LA Priest
#   Tempo: 69.44 BPM
#   EEG shape: (125, 33891, 20) - (electrodes=125, time_samples, participants=20)
#   Sampling rate: 125 Hz
# Song 3: Tiptoes by Daedelus
#   Tempo: 74.26 BPM
#   EEG shape: (125, 34469, 20) - (electrodes=125, time_samples, participants=20)
#   Sampling rate: 125 Hz
#
# === Loading Behavioral Data ===
# Behavioral ratings shape: (20, 10, 2)
# Questions: ['familiarity', 'enjoyment']
# Rating scale: 1-9 scale
#
# === Loading Participant Demographics ===
# Available demographic fields:
#   age: Age in years
#   nYearsTraining: Years of musical training
#   weeklyListening: Weekly music listening hours
#   id: Participant identifier
#
# === Loading Raw EEG Data ===
# Loaded song 3: Tiptoes - Shape: (125, 34469, 20)
# Song 1: First Fires by Bonobo
#   Tempo: 55.97 BPM
#   EEG shape: (125, 34795, 20) - (electrodes=125, time_samples, participants=20)
#   Sampling rate: 125 Hz
# Song 2: Oino by LA Priest
#   Tempo: 69.44 BPM
#   EEG shape: (125, 33891, 20) - (electrodes=125, time_samples, participants=20)
#   Sampling rate: 125 Hz
# Song 3: Tiptoes by Daedelus
#   Tempo: 74.26 BPM
#   EEG shape: (125, 34469, 20) - (electrodes=125, time_samples, participants=20)
#   Sampling rate: 125 Hz
#
# === Loading Behavioral Data ===
# Behavioral ratings shape: (20, 10, 2)
# Questions: ['familiarity', 'enjoyment']
# Rating scale: 1-9 scale
#
# === Loading Participant Demographics ===
# Available demographic fields:
#   age: Age in years
#   nYearsTraining: Years of musical training
#   weeklyListening: Weekly music listening hours
#   id: Participant identifier
#
# === Loading Raw EEG Data ===
# Error loading raw data for participant 2, session 1: 'DIN 1'
# Error loading raw data for participant 2, session 1: 'DIN 1'
# Error loading raw data for participant 3, session 1: 'DIN 1'
# Error loading raw data for participant 3, session 1: 'DIN 1'

# %%
# Comprehensive MUSIN-G Dataset Loader Based on Research
# Dataset described in: Miyapuram et al. (2022), Data in Brief, doi:10.1016/j.dib.2022.108663

import mne
import mne_bids
from mne_bids import BIDSPath, read_raw_bids, get_entity_vals
import pandas as pd
import numpy as np
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

print("🎵 MUSIN-G Dataset: Complete Import and Description")
print("=" * 70)
print("Based on: Miyapuram et al. (2022) - Electroencephalography (EEG) dataset")
print("during naturalistic music listening comprising different genres")
print("🔗 https://openneuro.org/datasets/ds003774")
print()

# Dataset paths
# EXPERIMENTAL PROTOCOL (from research)
print("🧪 EXPERIMENTAL PROTOCOL:")
print("• Participants: 20 Indian participants (16 male, 4 female, avg age 25.3±3.38)")
print("• EEG System: 128-channel Hydrocel Geodesic Sensor Net (HCGSN)")
print("• Recording: NetStation 5.4, referenced to Cz, 250Hz sampling")
print("• Location: Indian Institute of Technology Gandhinagar, India")
print()

print("📋 EXPERIMENTAL PROCEDURE:")
print("1. Single beep → Participant closes eyes")
print("2. Song plays (~2 minutes) → EEG recorded with eyes closed")
print("3. Double beep → Participant opens eyes")
print("4. Ratings collected: Familiarity & Enjoyment (1-5 scale)")
print("   - 1 = Most familiar/enjoyable, 5 = Least familiar/enjoyable")
print("5. Repeat for all 12 songs")
print()

bids_root = '/home/zmrocze/studia/uwr/magisterka/datasets/musin_g_data'
# Load behavioral data

from musing import MUSINGDataset

# Initialize and demonstrate
print("🚀 Initializing Complete MUSIN-G Dataset Loader...")
complete_dataset = MUSINGDataset(bids_root)


behavioral_data = complete_dataset.behavioral_data
print("📊 BEHAVIORAL DATA SUMMARY:")
print(f"• Total ratings: {len(behavioral_data)} (20 subjects × 12 songs)")
print(f"• Enjoyment range: {behavioral_data['Enjoyment'].min()}-{behavioral_data['Enjoyment'].max()}")
print(f"• Familiarity range: {behavioral_data['Familiarity'].min()}-{behavioral_data['Familiarity'].max()}")
print(f"• Mean enjoyment: {behavioral_data['Enjoyment'].mean():.2f}±{behavioral_data['Enjoyment'].std():.2f}")
print(f"• Mean familiarity: {behavioral_data['Familiarity'].mean():.2f}±{behavioral_data['Familiarity'].std():.2f}")
print()

print(f"\n🎯 Dataset ready for complete loading!")
print(f"• Use: complete_dataset.load_complete_dataset(max_subjects=5) for demo")
print(f"• Use: complete_dataset.load_complete_dataset() for full dataset")
musin_data = complete_dataset.load_complete_dataset()
complete_dataset.get_dataset_statistics()
print(f"• Use: complete_dataset.get_dataset_statistics() for analysis")
# Out:
# 🎵 MUSIN-G Dataset: Complete Import and Description
# ======================================================================
# Based on: Miyapuram et al. (2022) - Electroencephalography (EEG) dataset
# during naturalistic music listening comprising different genres
# 🔗 https://openneuro.org/datasets/ds003774
#
# 🧪 EXPERIMENTAL PROTOCOL:
# • Participants: 20 Indian participants (16 male, 4 female, avg age 25.3±3.38)
# • EEG System: 128-channel Hydrocel Geodesic Sensor Net (HCGSN)
# • Recording: NetStation 5.4, referenced to Cz, 250Hz sampling
# • Location: Indian Institute of Technology Gandhinagar, India
#
# 📋 EXPERIMENTAL PROCEDURE:
# 1. Single beep → Participant closes eyes
# 2. Song plays (~2 minutes) → EEG recorded with eyes closed
# 3. Double beep → Participant opens eyes
# 4. Ratings collected: Familiarity & Enjoyment (1-5 scale)
#    - 1 = Most familiar/enjoyable, 5 = Least familiar/enjoyable
# 5. Repeat for all 12 songs
#
# 🚀 Initializing Complete MUSIN-G Dataset Loader...
# 📊 BEHAVIORAL DATA SUMMARY:
# • Total ratings: 240 (20 subjects × 12 songs)
# • Enjoyment range: nan-nan
# • Familiarity range: 1-5
# • Mean enjoyment: nan±nan
# • Mean familiarity: 3.59±1.20
#
#
# 🎯 Dataset ready for complete loading!
# • Use: complete_dataset.load_complete_dataset(max_subjects=5) for demo
# • Use: complete_dataset.load_complete_dataset() for full dataset
# 🔄 Loading complete MUSIN-G dataset...
# 📦 Subjects to load: 20 of 20
#
# Subject 001 (1/20):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# Subject 002 (2/20):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# Subject 003 (3/20):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# Subject 004 (4/20):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# Subject 005 (5/20):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# Subject 006 (6/20):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# Subject 007 (7/20):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# Subject 008 (8/20):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# Subject 009 (9/20):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# Subject 010 (10/20):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# Subject 011 (11/20):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# Subject 012 (12/20):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# Subject 013 (13/20):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# Subject 014 (14/20):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# Subject 015 (15/20):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# Subject 016 (16/20):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# Subject 017 (17/20):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# Subject 018 (18/20):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# Subject 019 (19/20):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# Subject 020 (20/20):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# 📈 DATASET STATISTICS:
# • Total expected files: 20 × 12 = 240
# • Successfully loaded: 240/240
# • Success rate: 100.0%
#
# 🎭 GENRE-WISE BEHAVIORAL STATISTICS:
# • Use: complete_dataset.get_dataset_statistics() for analysis

# %%
# Iterate over all subjects and sessions in complete_dataset
for subject_id, subject_data in complete_dataset.all_data.items():
  # print(f"Subject: {subject_id}")
  for session_id, session_data in subject_data.items():
    song_name = session_data['song_info']['name']
    enjoyment = session_data['enjoyment']
    familiarity = session_data['familiarity']
    # print(f"  Session: {session_id} | Song: {song_name} | Enjoyment: {enjoyment} | Familiarity: {familiarity}")

# %%
# Demonstration: Load subset and perform analyses
print("🔍 DEMONSTRATION: Loading subset of MUSIN-G dataset")
print("=" * 60)

# Load first 3 subjects as demonstration (to avoid overwhelming output)
demo_data = complete_dataset.load_complete_dataset(max_subjects=3, verbose=True)

# Get dataset statistics
complete_dataset.get_dataset_statistics()

print("\n" + "="*60)
print("📊 EXAMPLE ANALYSES")
print("="*60)

# Example 1: Genre preference analysis
print("\n1️⃣ GENRE PREFERENCE ANALYSIS (Demo subjects):")
genre_enjoyment = {}
genre_familiarity = {}

for subject in demo_data:
    for session in demo_data[subject]:
        data_point = demo_data[subject][session]
        genre = data_point['song_info']['genre']
        enjoyment = data_point['enjoyment']
        familiarity = data_point['familiarity']
        
        if genre not in genre_enjoyment:
            genre_enjoyment[genre] = []
            genre_familiarity[genre] = []
        
        if enjoyment is not None:
            genre_enjoyment[genre].append(enjoyment)
        if familiarity is not None:
            genre_familiarity[genre].append(familiarity)

for genre in genre_enjoyment:
    if genre_enjoyment[genre]:
        mean_enjoy = np.mean(genre_enjoyment[genre])
        mean_familiar = np.mean(genre_familiarity[genre])
        print(f"  {genre:25} | Enjoy: {mean_enjoy:.1f}/5 | Familiar: {mean_familiar:.1f}/5")

# Example 2: EEG data quality check
print(f"\n2️⃣ EEG DATA QUALITY CHECK:")
for subject in list(demo_data.keys())[:2]:  # Check first 2 subjects
    print(f"\nSubject {subject}:")
    for session in ['01', '07', '12']:  # Sample: Electronic, Classical, Rock
        if session in demo_data[subject]:
            raw = demo_data[subject][session]['raw']
            song_name = demo_data[subject][session]['song_info']['name']
            
            # Basic quality metrics
            duration = raw.times[-1]
            n_channels = raw.info['nchan']
            sfreq = raw.info['sfreq']
            
            # Check for bad channels (simple amplitude check)
            data = raw.get_data()
            channel_std = np.std(data, axis=1)
            outlier_channels = np.sum(channel_std > 3 * np.median(channel_std))
            
            print(f"  Song {session} ({song_name[:20]}...)")
            print(f"    Duration: {duration:.1f}s | Channels: {n_channels} | Freq: {sfreq}Hz")
            print(f"    Potential bad channels: {outlier_channels}")

# Example 3: Cross-cultural music analysis setup
print(f"\n3️⃣ CROSS-CULTURAL MUSIC CATEGORIES:")
categories = {
    'Western_Electronic': ['Deep House', 'Electronics', 'Electronic Dance', 'Ambient'],
    'Western_Traditional': ['Indie', 'New Age', 'Soft Jazz', 'Goth Rock', 'Progressive Instrumental Rock'],
    'Indian_Traditional': ['Hindustani Classical', 'Indian Semi-Classical', 'Indian Folk']
}

for category, genres in categories.items():
    matching_songs = [s for s in songs_info_enhanced.values() if s['genre'] in genres]
    print(f"  {category}: {len(matching_songs)} songs")
    for song in matching_songs:
        print(f"    - {song['name']} ({song['genre']})")

print(f"\n🎯 READY FOR ADVANCED ANALYSES:")
print(f"• Genre classification from EEG")
print(f"• Cross-cultural music perception")
print(f"• Individual vs. group music preferences")
print(f"• Temporal dynamics of music listening")
print(f"• Familiarity vs. enjoyment neural correlates")

print(f"\n💡 NEXT STEPS:")
print(f"# Load complete dataset:")
print(f"# all_data = complete_dataset.load_complete_dataset()")
print(f"# ")
print(f"# Access specific data:")
print(f"# subject_001_data = complete_dataset.get_subject_data('001')")
print(f"# classical_song_data = complete_dataset.get_song_data_across_subjects('07')")
print(f"# ")
print(f"# Access song metadata from Raw object:")
print(f"# raw = subject_001_data['01']['raw']")
print(f"# metadata = complete_dataset.get_song_metadata(raw)")
print(f"# print(metadata['genre'], metadata['enjoyment_rating'])")
# Out:
# 🔍 DEMONSTRATION: Loading subset of MUSIN-G dataset
# ============================================================
# 🔄 Loading complete MUSIN-G dataset...
# 📦 Subjects to load: 3 of 20
#
# Subject 001 (1/3):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# Subject 002 (2/3):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# Subject 003 (3/3):
#   ✓ Song 01: Trip to the lonely planet (Deep House) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 02: Sail (Indie) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 03: Concept 15 (Electronics) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 04: Aurore (New Age) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 05: Proof (Electronic Dance) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 06: Glider (Ambient) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 07: Raag Bihag (Hindustani Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 08: Albela sajan (Indian Semi-Classical) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 09: Mor Bani Thanghat Kare (Indian Folk) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 10: Fallin (Soft Jazz) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 11: Master of Running (Goth Rock) | Enjoy: None/5, Familiar: None/5
#   ✓ Song 12: JB (Progressive Instrumental Rock) | Enjoy: None/5, Familiar: None/5
#
# 📈 DATASET STATISTICS:
# • Total expected files: 20 × 12 = 240
# • Successfully loaded: 240/240
# • Success rate: 100.0%
#
# 🎭 GENRE-WISE BEHAVIORAL STATISTICS:
#
# ============================================================
# 📊 EXAMPLE ANALYSES
# ============================================================
#
# 1️⃣ GENRE PREFERENCE ANALYSIS (Demo subjects):
#
# 2️⃣ EEG DATA QUALITY CHECK:
#
# Subject 001:
#   Song 01 (Trip to the lonely p...)
#     Duration: 136.0s | Channels: 129 | Freq: 250.0Hz
#     Potential bad channels: 16
#   Song 07 (Raag Bihag...)
#     Duration: 126.5s | Channels: 129 | Freq: 250.0Hz
#     Potential bad channels: 7
#   Song 12 (JB...)
#     Duration: 127.8s | Channels: 129 | Freq: 250.0Hz
#     Potential bad channels: 10
#
# Subject 002:
#   Song 01 (Trip to the lonely p...)
#     Duration: 136.0s | Channels: 129 | Freq: 1000.0Hz
#     Potential bad channels: 11
#   Song 07 (Raag Bihag...)
#     Duration: 126.5s | Channels: 129 | Freq: 1000.0Hz
#     Potential bad channels: 8
#   Song 12 (JB...)
#     Duration: 127.8s | Channels: 129 | Freq: 1000.0Hz
#     Potential bad channels: 12
#
# 3️⃣ CROSS-CULTURAL MUSIC CATEGORIES:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 74
#      67 categories = {
#      68     'Western_Electronic': ['Deep House', 'Electronics', 'Electronic Dance', 'Ambient'],
#      69     'Western_Traditional': ['Indie', 'New Age', 'Soft Jazz', 'Goth Rock', 'Progressive Instrumental Rock'],
#      70     'Indian_Traditional': ['Hindustani Classical', 'Indian Semi-Classical', 'Indian Folk']
#      71 }
#      73 for category, genres in categories.items():
# ---> 74     matching_songs = [s for s in songs_info_enhanced.values() if s['genre'] in genres]
#      75     print(f"  {category}: {len(matching_songs)} songs")
#      76     for song in matching_songs:
#
# NameError: name 'songs_info_enhanced' is not defined

# %%
from openmiir import main as openmiir_main
openmiir_main()
# Out:
# 🎵 OpenMIIR Dataset Loader
# ==================================================
# Available subjects: ['01', '02', '03', '04', '05']... (showing first 5)
#
# 📦 Loading first 3 subjects (2 runs each)...
# 🔄 Loading OpenMIIR dataset...
# 📦 Subjects to load: 3 of 19
# 🏃 Runs per subject: 2
#
# Loading subject 01:
#   ✓ Run 1: 859.0s, 36 events, 18 trials
#   ✓ Run 2: 841.0s, 36 events, 18 trials
# Loading subject 02:
#   ✓ Run 1: 1025.0s, 36 events, 18 trials
#   ✓ Run 2: 979.0s, 36 events, 18 trials
# Loading subject 03:
#   ✓ Run 1: 865.0s, 36 events, 18 trials
#   ✓ Run 2: 828.0s, 36 events, 18 trials
#
# 📊 LOADING SUMMARY:
# • Successfully loaded: 3 subjects
# • Failed to load: 0 subjects
# • Success rate: 100.0%
# 📈 DATASET STATISTICS:
# • Loaded subjects: 3
# • Total runs loaded: 6
# • Total trials: 108
#
# 🎭 EMOTIONAL CONDITION DISTRIBUTION:
#   Condition 1:   6 trials
#   Condition 2:  18 trials
#   Condition 3:  10 trials
#   Condition 4:  20 trials
#   Condition 5:  18 trials
#   Condition 6:  12 trials
#   Condition 7:  12 trials
#   Condition 9:  12 trials
#
# ⚙️  TECHNICAL SPECIFICATIONS:
# • Sampling rate: 1000.0 Hz
# • Channels per recording: 37
# • Run duration: ~859 seconds
#
# 💡 USAGE EXAMPLES:
# # Load all subjects:
# # loader.load_all_subjects()
# #
# # Load specific subject:
# # subject_data = loader.load_subject_data('01')
# #
# # Get trials for specific emotion:
# # happy_trials = loader.get_condition_trials(1)  # High valence, high arousal
# #
# # Access raw EEG data:
# # raw = loader.data['01']['1']['raw']  # Subject 01, Run 1
# # events = loader.data['01']['1']['processed_events']['condition_events']
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: Invalid measurement date encountered in the header.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: No BIDS -> MNE mapping found for channel type "UserReport". Type of channel "VA1" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: No BIDS -> MNE mapping found for channel type "UserReport". Type of channel "VA2" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: No BIDS -> MNE mapping found for channel type "MetaData". Type of channel "VAtarg" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: Invalid measurement date encountered in the header.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: No BIDS -> MNE mapping found for channel type "UserReport". Type of channel "VA1" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: No BIDS -> MNE mapping found for channel type "UserReport". Type of channel "VA2" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: No BIDS -> MNE mapping found for channel type "MetaData". Type of channel "VAtarg" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: Invalid measurement date encountered in the header.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: No BIDS -> MNE mapping found for channel type "UserReport". Type of channel "VA1" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: No BIDS -> MNE mapping found for channel type "UserReport". Type of channel "VA2" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: No BIDS -> MNE mapping found for channel type "MetaData". Type of channel "VAtarg" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: Invalid measurement date encountered in the header.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: No BIDS -> MNE mapping found for channel type "UserReport". Type of channel "VA1" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: No BIDS -> MNE mapping found for channel type "UserReport". Type of channel "VA2" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: No BIDS -> MNE mapping found for channel type "MetaData". Type of channel "VAtarg" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: Invalid measurement date encountered in the header.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: No BIDS -> MNE mapping found for channel type "UserReport". Type of channel "VA1" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: No BIDS -> MNE mapping found for channel type "UserReport". Type of channel "VA2" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: No BIDS -> MNE mapping found for channel type "MetaData". Type of channel "VAtarg" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: Invalid measurement date encountered in the header.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: No BIDS -> MNE mapping found for channel type "UserReport". Type of channel "VA1" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: No BIDS -> MNE mapping found for channel type "UserReport". Type of channel "VA2" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/openmiir.py:53: RuntimeWarning: No BIDS -> MNE mapping found for channel type "MetaData". Type of channel "VAtarg" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)

# %% [markdown]
# # 🎵 Music EEG Datasets Summary
#
# ## Successfully Imported Datasets
#
# ### 1. MUSIN-G Dataset (Naturalistic Music Listening)
# - **Source**: Miyapuram et al. (2022), OpenNeuro ds003774
# - **Participants**: 20 Indian participants
# - **EEG**: 128-channel Hydrocel Geodesic Sensor Net, 250Hz
# - **Music**: 12 real songs across genres (Indian classical, Western electronic, etc.)
# - **Design**: Naturalistic listening with eyes closed, ~2 minutes per song
# - **Behavioral**: Familiarity & enjoyment ratings (1-5 scale)
# - **Use cases**: Genre classification, cross-cultural music perception, preference analysis
#
# ### 2. OpenMIIR Dataset (Affective Music BCI)
# - **Source**: Daly et al. (2018), OpenNeuro ds002722
# - **Participants**: 19 healthy adults from University of Reading
# - **EEG**: 32-channel system + ECG + GSR, 1000Hz sampling
# - **Music**: Synthetic music clips (40 seconds each)
# - **Design**: 3×3 factorial (valence × arousal) = 9 emotional conditions
# - **Structure**: 5 runs × 18 trials = 90 trials per participant
# - **Use cases**: Emotion classification, valence/arousal analysis, affective BCI
#
# ## Key Differences
#
# | Aspect | MUSIN-G | OpenMIIR |
# |--------|---------|----------|
# | Music Type | Real songs | Synthetic clips |
# | Duration | ~2 minutes | 40 seconds |
# | Focus | Genre/Cultural | Emotional states |
# | EEG Channels | 128 | 32 (+ECG/GSR) |
# | Sampling Rate | 250 Hz | 1000 Hz |
# | Behavioral | Ratings | Valence/Arousal |
#
# Both datasets are now successfully loaded and ready for analysis!

# %%
from bcmi import create_bcmi_loader
loader = create_bcmi_loader('./datasets/bcmi/bcmi-training')
data = loader.load_all_subjects()
loader.get_dataset_statistics()

# Load specific subjects and runs
subject_data = loader.load_subject_data('01', max_runs=3)

exp_info = loader._get_experimental_info()
print(exp_info)

# Get trials for specific emotional states
happy_trials = loader.get_condition_trials(1)  # High valence, high arousal
calm_trials = loader.get_condition_trials(8)   # Neutral valence, low arousal

subjects = loader.get_available_subjects()

# Access raw EEG data and events
raw_eeg = loader.data[subjects[0]]['3']
events = loader.data[subjects[0]]['3']['1']['processed_events']

# Load all BCMI datasets at once
# from bcmi import load_all_bcmi_datasets
# all_loaders = load_all_bcmi_datasets('./datasets/bcmi', max_subjects_per_dataset=3)

# # Compare across datasets
# for name, loader in all_loaders.items():
#     print(f"{name}: {len(loader.data)} subjects")
#     loader.get_dataset_statistics()
# Out:
# Loading subject 08 (bcmi-training):
#   ✓ Run 1 ses-3: 1008.0s, 36 events, 36 trials
#   ✓ Run 2 ses-3: 1005.0s, 36 events, 36 trials
#   ✓ Run 3 ses-3: 1010.0s, 36 events, 36 trials
#   ✓ Run 4 ses-3: 1011.0s, 36 events, 36 trials
# Loading subject 09 (bcmi-training):
#   ✓ Run 1 ses-3: 1038.0s, 36 events, 36 trials
#   ✓ Run 2 ses-3: 1052.0s, 36 events, 36 trials
#   ✓ Run 3 ses-3: 1034.0s, 36 events, 36 trials
#   ✓ Run 4 ses-3: 1036.0s, 36 events, 36 trials
#   ✓ Run 1 ses-1: 1045.0s, 36 events, 36 trials
#   ✓ Run 2 ses-1: 1033.0s, 36 events, 36 trials
#   ✓ Run 3 ses-1: 1034.0s, 36 events, 36 trials
#   ✓ Run 4 ses-1: 1031.0s, 36 events, 36 trials
#   ✓ Run 1 ses-2: 1036.0s, 36 events, 36 trials
#   ✓ Run 2 ses-2: 1032.0s, 36 events, 36 trials
#   ✓ Run 3 ses-2: 1016.0s, 36 events, 36 trials
#   ✓ Run 4 ses-2: 1026.0s, 36 events, 36 trials
# Loading subject 10 (bcmi-training):
#   ✓ Run 1 ses-3: 1095.0s, 36 events, 36 trials
#   ✓ Run 2 ses-3: 1115.0s, 36 events, 36 trials
#   ✓ Run 3 ses-3: 1151.0s, 36 events, 36 trials
#   ✓ Run 4 ses-3: 1068.0s, 36 events, 36 trials
#   ✓ Run 1 ses-1: 1130.0s, 36 events, 36 trials
#   ✓ Run 2 ses-1: 1108.0s, 36 events, 36 trials
#   ✓ Run 3 ses-1: 1134.0s, 36 events, 36 trials
#   ✓ Run 4 ses-1: 1069.0s, 36 events, 36 trials
#   ✓ Run 1 ses-2: 1112.0s, 36 events, 36 trials
#   ✓ Run 2 ses-2: 1128.0s, 36 events, 36 trials
#   ✓ Run 3 ses-2: 1105.0s, 36 events, 36 trials
#   ✓ Run 4 ses-2: 1053.0s, 36 events, 36 trials
# Loading subject 11 (bcmi-training):
#   ✓ Run 1 ses-3: 1089.0s, 36 events, 36 trials
#   ✓ Run 2 ses-3: 1131.0s, 36 events, 36 trials
#   ✓ Run 3 ses-3: 1122.0s, 36 events, 36 trials
#   ✓ Run 4 ses-3: 1080.0s, 36 events, 36 trials
#   ✓ Run 1 ses-1: 1245.0s, 36 events, 36 trials
#   ✓ Run 2 ses-1: 1226.0s, 36 events, 36 trials
#   ✓ Run 3 ses-1: 1188.0s, 36 events, 36 trials
#   ✓ Run 4 ses-1: 1148.0s, 36 events, 36 trials
#   ✓ Run 1 ses-2: 1169.0s, 36 events, 36 trials
#   ✓ Run 2 ses-2: 1162.0s, 36 events, 36 trials
#   ✓ Run 3 ses-2: 1111.0s, 36 events, 36 trials
#   ✓ Run 4 ses-2: 1136.0s, 36 events, 36 trials
# Loading subject 12 (bcmi-training):
#   ✓ Run 1 ses-3: 1052.0s, 36 events, 36 trials
#   ✓ Run 2 ses-3: 1035.0s, 36 events, 36 trials
#   ✓ Run 3 ses-3: 1065.0s, 36 events, 36 trials
#   ✓ Run 4 ses-3: 1044.0s, 36 events, 36 trials
#   ✓ Run 1 ses-1: 1089.0s, 36 events, 36 trials
#   ✓ Run 2 ses-1: 1072.0s, 36 events, 36 trials
#   ✓ Run 3 ses-1: 1046.0s, 36 events, 36 trials
#   ✓ Run 4 ses-1: 1051.0s, 36 events, 36 trials
#   ✓ Run 1 ses-2: 1066.0s, 36 events, 36 trials
#   ✓ Run 2 ses-2: 1092.0s, 36 events, 36 trials
#   ✓ Run 3 ses-2: 1053.0s, 36 events, 36 trials
#   ✓ Run 4 ses-2: 1070.0s, 36 events, 36 trials
# Loading subject 13 (bcmi-training):
#   ✓ Run 1 ses-3: 1035.0s, 36 events, 36 trials
#   ✓ Run 2 ses-3: 1041.0s, 36 events, 36 trials
#   ✓ Run 3 ses-3: 1028.0s, 36 events, 36 trials
#   ✓ Run 4 ses-3: 1035.0s, 36 events, 36 trials
#   ✓ Run 1 ses-1: 1057.0s, 36 events, 36 trials
#   ✓ Run 2 ses-1: 1059.0s, 36 events, 36 trials
#   ✓ Run 3 ses-1: 1032.0s, 36 events, 36 trials
#   ✓ Run 4 ses-1: 1030.0s, 36 events, 36 trials
#   ✓ Run 1 ses-2: 1048.0s, 36 events, 36 trials
#   ✓ Run 2 ses-2: 1051.0s, 36 events, 36 trials
#   ✓ Run 3 ses-2: 1031.0s, 36 events, 36 trials
#   ✓ Run 4 ses-2: 1023.0s, 36 events, 36 trials
# Loading subject 14 (bcmi-training):
#   ✓ Run 1 ses-1: 1202.0s, 36 events, 36 trials
#   ✓ Run 2 ses-1: 1079.0s, 36 events, 36 trials
#   ✓ Run 3 ses-1: 1167.0s, 36 events, 36 trials
#   ✓ Run 4 ses-1: 1182.0s, 36 events, 36 trials
#   ✓ Run 1 ses-2: 1067.0s, 36 events, 36 trials
#   ✓ Run 2 ses-2: 1068.0s, 36 events, 36 trials
#   ✓ Run 3 ses-2: 1055.0s, 36 events, 36 trials
#   ✓ Run 4 ses-2: 1031.0s, 36 events, 36 trials
# Loading subject 15 (bcmi-training):
#   ✓ Run 1 ses-3: 1084.0s, 36 events, 36 trials
#   ✓ Run 2 ses-3: 1072.0s, 36 events, 36 trials
#   ✓ Run 3 ses-3: 1075.0s, 36 events, 36 trials
#   ✓ Run 4 ses-3: 1074.0s, 36 events, 36 trials
#   ✓ Run 1 ses-1: 1093.0s, 36 events, 36 trials
#   ✓ Run 2 ses-1: 1080.0s, 36 events, 36 trials
#   ✓ Run 3 ses-1: 1069.0s, 36 events, 36 trials
#   ✓ Run 4 ses-1: 1053.0s, 36 events, 36 trials
#   ✓ Run 1 ses-2: 1075.0s, 36 events, 36 trials
#   ✓ Run 2 ses-2: 1080.0s, 36 events, 36 trials
#   ✓ Run 3 ses-2: 1075.0s, 36 events, 36 trials
#   ✓ Run 4 ses-2: 1080.0s, 36 events, 36 trials
# Loading subject 16 (bcmi-training):
#   ✓ Run 1 ses-1: 1057.0s, 36 events, 36 trials
#   ✓ Run 2 ses-1: 1037.0s, 36 events, 36 trials
#   ✓ Run 3 ses-1: 1038.0s, 36 events, 36 trials
#   ✓ Run 4 ses-1: 1038.0s, 36 events, 36 trials
#   ✓ Run 1 ses-2: 1068.0s, 36 events, 36 trials
#   ✓ Run 2 ses-2: 1054.0s, 36 events, 36 trials
#   ✓ Run 3 ses-2: 1031.0s, 36 events, 36 trials
#   ✓ Run 4 ses-2: 1035.0s, 36 events, 36 trials
# Loading subject 17 (bcmi-training):
#   ✓ Run 1 ses-1: 1049.0s, 36 events, 36 trials
#   ✓ Run 2 ses-1: 1038.0s, 36 events, 36 trials
#   ✓ Run 3 ses-1: 1034.0s, 36 events, 36 trials
#   ✓ Run 4 ses-1: 1031.0s, 36 events, 36 trials
# 📈 BCMI-TRAINING DATASET STATISTICS:
# • Loaded subjects: 10
# • Total sessions: 24
# • Total runs: 96
# • Total trials: 3456
#
# 🎵 EXPERIMENTAL PARADIGM:
# • Type: Training
# • Trial structure: 40s total (20s + 20s targeting different affects)
# • Music type: Synthetic generated
#
# 🎭 EMOTIONAL CONDITION DISTRIBUTION:
#   Condition 1 (Excited/Happy): 383 trials
#   Condition 2 (Peaceful/Content): 388 trials
#   Condition 3 (Positive/Pleasant): 381 trials
#   Condition 4 (Angry/Agitated): 389 trials
#   Condition 5 (Sad/Depressed): 381 trials
#   Condition 6 (Negative/Unpleasant): 386 trials
#   Condition 7 (Alert/Activated): 386 trials
#   Condition 8 (Calm/Relaxed): 381 trials
#   Condition 9 (Neutral/Balanced): 381 trials
#
# ⚙️  TECHNICAL SPECIFICATIONS:
# • Sampling rate: 1000.0 Hz
# • Channels per recording: 37
# • Average run duration: ~1008 seconds
# Loading subject 01 (bcmi-training):
#   ✗ Run 1: [Errno 2] No such file or directory: 'datasets/bcm...
#   ✗ Run 2: [Errno 2] No such file or directory: 'datasets/bcm...
#   ✗ Run 3: [Errno 2] No such file or directory: 'datasets/bcm...
# {'paradigm_type': 'Training', 'trial_structure': '40s total (20s + 20s targeting different affects)', 'music_type': 'Synthetic generated', 'sessions_per_subject': 'Variable', 'description': 'Training sessions for dual-affective state targeting'}

# %%
loader = create_bcmi_loader('./datasets/bcmi/bcmi-training')
data = loader.load_all_subjects()
# Out:
# Loading subject 08 (bcmi-training):
#   ✓ Run 1 ses-3: 1008.0s, 36 events, 36 trials
#   ✓ Run 2 ses-3: 1005.0s, 36 events, 36 trials
#   ✓ Run 3 ses-3: 1010.0s, 36 events, 36 trials
#   ✓ Run 4 ses-3: 1011.0s, 36 events, 36 trials
# Loading subject 09 (bcmi-training):
#   ✓ Run 1 ses-3: 1038.0s, 36 events, 36 trials
#   ✓ Run 2 ses-3: 1052.0s, 36 events, 36 trials
#   ✓ Run 3 ses-3: 1034.0s, 36 events, 36 trials
#   ✓ Run 4 ses-3: 1036.0s, 36 events, 36 trials
#   ✓ Run 1 ses-1: 1045.0s, 36 events, 36 trials
#   ✓ Run 2 ses-1: 1033.0s, 36 events, 36 trials
#   ✓ Run 3 ses-1: 1034.0s, 36 events, 36 trials
#   ✓ Run 4 ses-1: 1031.0s, 36 events, 36 trials
#   ✓ Run 1 ses-2: 1036.0s, 36 events, 36 trials
#   ✓ Run 2 ses-2: 1032.0s, 36 events, 36 trials
#   ✓ Run 3 ses-2: 1016.0s, 36 events, 36 trials
#   ✓ Run 4 ses-2: 1026.0s, 36 events, 36 trials
# Loading subject 10 (bcmi-training):
#   ✓ Run 1 ses-3: 1095.0s, 36 events, 36 trials
#   ✓ Run 2 ses-3: 1115.0s, 36 events, 36 trials
#   ✓ Run 3 ses-3: 1151.0s, 36 events, 36 trials
#   ✓ Run 4 ses-3: 1068.0s, 36 events, 36 trials
#   ✓ Run 1 ses-1: 1130.0s, 36 events, 36 trials
#   ✓ Run 2 ses-1: 1108.0s, 36 events, 36 trials
#   ✓ Run 3 ses-1: 1134.0s, 36 events, 36 trials
#   ✓ Run 4 ses-1: 1069.0s, 36 events, 36 trials
#   ✓ Run 1 ses-2: 1112.0s, 36 events, 36 trials
#   ✓ Run 2 ses-2: 1128.0s, 36 events, 36 trials
#   ✓ Run 3 ses-2: 1105.0s, 36 events, 36 trials
#   ✓ Run 4 ses-2: 1053.0s, 36 events, 36 trials
# Loading subject 11 (bcmi-training):
#   ✓ Run 1 ses-3: 1089.0s, 36 events, 36 trials
#   ✓ Run 2 ses-3: 1131.0s, 36 events, 36 trials
#   ✓ Run 3 ses-3: 1122.0s, 36 events, 36 trials
#   ✓ Run 4 ses-3: 1080.0s, 36 events, 36 trials
#   ✓ Run 1 ses-1: 1245.0s, 36 events, 36 trials
#   ✓ Run 2 ses-1: 1226.0s, 36 events, 36 trials
#   ✓ Run 3 ses-1: 1188.0s, 36 events, 36 trials
#   ✓ Run 4 ses-1: 1148.0s, 36 events, 36 trials
#   ✓ Run 1 ses-2: 1169.0s, 36 events, 36 trials
#   ✓ Run 2 ses-2: 1162.0s, 36 events, 36 trials
#   ✓ Run 3 ses-2: 1111.0s, 36 events, 36 trials
#   ✓ Run 4 ses-2: 1136.0s, 36 events, 36 trials
# Loading subject 12 (bcmi-training):
#   ✓ Run 1 ses-3: 1052.0s, 36 events, 36 trials
#   ✓ Run 2 ses-3: 1035.0s, 36 events, 36 trials
#   ✓ Run 3 ses-3: 1065.0s, 36 events, 36 trials
#   ✓ Run 4 ses-3: 1044.0s, 36 events, 36 trials
#   ✓ Run 1 ses-1: 1089.0s, 36 events, 36 trials
#   ✓ Run 2 ses-1: 1072.0s, 36 events, 36 trials
#   ✓ Run 3 ses-1: 1046.0s, 36 events, 36 trials
#   ✓ Run 4 ses-1: 1051.0s, 36 events, 36 trials
#   ✓ Run 1 ses-2: 1066.0s, 36 events, 36 trials
#   ✓ Run 2 ses-2: 1092.0s, 36 events, 36 trials
#   ✓ Run 3 ses-2: 1053.0s, 36 events, 36 trials
#   ✓ Run 4 ses-2: 1070.0s, 36 events, 36 trials
# Loading subject 13 (bcmi-training):
#   ✓ Run 1 ses-3: 1035.0s, 36 events, 36 trials
#   ✓ Run 2 ses-3: 1041.0s, 36 events, 36 trials
#   ✓ Run 3 ses-3: 1028.0s, 36 events, 36 trials
#   ✓ Run 4 ses-3: 1035.0s, 36 events, 36 trials
#   ✓ Run 1 ses-1: 1057.0s, 36 events, 36 trials
#   ✓ Run 2 ses-1: 1059.0s, 36 events, 36 trials
#   ✓ Run 3 ses-1: 1032.0s, 36 events, 36 trials
#   ✓ Run 4 ses-1: 1030.0s, 36 events, 36 trials
#   ✓ Run 1 ses-2: 1048.0s, 36 events, 36 trials
#   ✓ Run 2 ses-2: 1051.0s, 36 events, 36 trials
#   ✓ Run 3 ses-2: 1031.0s, 36 events, 36 trials
#   ✓ Run 4 ses-2: 1023.0s, 36 events, 36 trials
# Loading subject 14 (bcmi-training):
#   ✓ Run 1 ses-1: 1202.0s, 36 events, 36 trials
#   ✓ Run 2 ses-1: 1079.0s, 36 events, 36 trials
#   ✓ Run 3 ses-1: 1167.0s, 36 events, 36 trials
#   ✓ Run 4 ses-1: 1182.0s, 36 events, 36 trials
#   ✓ Run 1 ses-2: 1067.0s, 36 events, 36 trials
#   ✓ Run 2 ses-2: 1068.0s, 36 events, 36 trials
#   ✓ Run 3 ses-2: 1055.0s, 36 events, 36 trials
#   ✓ Run 4 ses-2: 1031.0s, 36 events, 36 trials
# Loading subject 15 (bcmi-training):
#   ✓ Run 1 ses-3: 1084.0s, 36 events, 36 trials
#   ✓ Run 2 ses-3: 1072.0s, 36 events, 36 trials
#   ✓ Run 3 ses-3: 1075.0s, 36 events, 36 trials
#   ✓ Run 4 ses-3: 1074.0s, 36 events, 36 trials
#   ✓ Run 1 ses-1: 1093.0s, 36 events, 36 trials
#   ✓ Run 2 ses-1: 1080.0s, 36 events, 36 trials
#   ✓ Run 3 ses-1: 1069.0s, 36 events, 36 trials
#   ✓ Run 4 ses-1: 1053.0s, 36 events, 36 trials
#   ✓ Run 1 ses-2: 1075.0s, 36 events, 36 trials
#   ✓ Run 2 ses-2: 1080.0s, 36 events, 36 trials
#   ✓ Run 3 ses-2: 1075.0s, 36 events, 36 trials
#   ✓ Run 4 ses-2: 1080.0s, 36 events, 36 trials
# Loading subject 16 (bcmi-training):
#   ✓ Run 1 ses-1: 1057.0s, 36 events, 36 trials
#   ✓ Run 2 ses-1: 1037.0s, 36 events, 36 trials
#   ✓ Run 3 ses-1: 1038.0s, 36 events, 36 trials
#   ✓ Run 4 ses-1: 1038.0s, 36 events, 36 trials
#   ✓ Run 1 ses-2: 1068.0s, 36 events, 36 trials
#   ✓ Run 2 ses-2: 1054.0s, 36 events, 36 trials
#   ✓ Run 3 ses-2: 1031.0s, 36 events, 36 trials
#   ✓ Run 4 ses-2: 1035.0s, 36 events, 36 trials
# Loading subject 17 (bcmi-training):
#   ✓ Run 1 ses-1: 1049.0s, 36 events, 36 trials
#   ✓ Run 2 ses-1: 1038.0s, 36 events, 36 trials
#   ✓ Run 3 ses-1: 1034.0s, 36 events, 36 trials
#   ✓ Run 4 ses-1: 1031.0s, 36 events, 36 trials

# %%
import numpy as np
import mne
from bcmi import create_bcmi_loader
# raw1 = loader.data[subjects[0]]['3']['1']['raw']
# events = loader.data[subjects[0]]['3']['1']['events']
# loader = create_bcmi_loader('./datasets/bcmi/bcmi-training')
loader = create_bcmi_loader('./datasets/bcmi/bcmi-calibration')
data = loader.load_all_subjects()
loader.get_dataset_statistics()
# Out:
# Loading subject 01 (bcmi-calibration):
#   ✓ Run 1: 859.0s, 36 events, 18 trials
#   ✓ Run 2: 841.0s, 36 events, 18 trials
#   ✓ Run 3: 844.0s, 36 events, 18 trials
#   ✓ Run 4: 832.0s, 36 events, 18 trials
#   ✓ Run 5: 815.0s, 36 events, 18 trials
# Loading subject 02 (bcmi-calibration):
#   ✓ Run 1: 1025.0s, 36 events, 18 trials
#   ✓ Run 2: 979.0s, 36 events, 18 trials
#   ✓ Run 3: 963.0s, 36 events, 18 trials
#   ✓ Run 4: 919.0s, 36 events, 18 trials
#   ✓ Run 5: 886.0s, 36 events, 18 trials
# Loading subject 03 (bcmi-calibration):
#   ✓ Run 1: 865.0s, 36 events, 18 trials
#   ✓ Run 2: 828.0s, 36 events, 18 trials
#   ✓ Run 3: 820.0s, 36 events, 18 trials
#   ✓ Run 4: 811.0s, 36 events, 18 trials
#   ✓ Run 5: 817.0s, 36 events, 18 trials
# Loading subject 04 (bcmi-calibration):
#   ✓ Run 1: 984.0s, 36 events, 18 trials
#   ✓ Run 2: 935.0s, 36 events, 18 trials
#   ✓ Run 3: 868.0s, 36 events, 18 trials
#   ✓ Run 4: 831.0s, 36 events, 18 trials
#   ✓ Run 5: 800.0s, 36 events, 18 trials
# Loading subject 05 (bcmi-calibration):
#   ✓ Run 1: 886.0s, 36 events, 18 trials
#   ✓ Run 2: 881.0s, 36 events, 18 trials
#   ✓ Run 3: 857.0s, 36 events, 18 trials
#   ✓ Run 4: 878.0s, 36 events, 18 trials
#   ✓ Run 5: 833.0s, 36 events, 18 trials
# Loading subject 06 (bcmi-calibration):
#   ✓ Run 1: 845.0s, 18 events, 18 trials
#   ✓ Run 2: 836.0s, 36 events, 18 trials
#   ✓ Run 3: 838.0s, 36 events, 18 trials
#   ✓ Run 4: 809.0s, 36 events, 18 trials
#   ✗ Run 5: File does not exist:
# datasets/bcmi/bcmi-calibratio...
# Loading subject 07 (bcmi-calibration):
#   ✓ Run 1: 856.0s, 36 events, 18 trials
#   ✓ Run 2: 845.0s, 36 events, 18 trials
#   ✓ Run 3: 847.0s, 36 events, 18 trials
#   ✓ Run 4: 816.0s, 36 events, 18 trials
#   ✓ Run 5: 796.0s, 36 events, 18 trials
# Loading subject 08 (bcmi-calibration):
#   ✓ Run 1: 897.0s, 36 events, 18 trials
#   ✓ Run 2: 845.0s, 36 events, 18 trials
#   ✓ Run 3: 835.0s, 36 events, 18 trials
#   ✓ Run 4: 822.0s, 36 events, 18 trials
#   ✓ Run 5: 818.0s, 36 events, 18 trials
# Loading subject 09 (bcmi-calibration):
#   ✓ Run 1: 875.0s, 36 events, 18 trials
#   ✓ Run 2: 838.0s, 36 events, 18 trials
#   ✓ Run 3: 835.0s, 36 events, 18 trials
#   ✓ Run 4: 817.0s, 36 events, 18 trials
#   ✓ Run 5: 834.0s, 36 events, 18 trials
# Loading subject 10 (bcmi-calibration):
#   ✓ Run 1: 890.0s, 36 events, 18 trials
#   ✓ Run 2: 921.0s, 36 events, 18 trials
#   ✓ Run 3: 970.0s, 36 events, 18 trials
#   ✓ Run 4: 981.0s, 36 events, 18 trials
#   ✓ Run 5: 936.0s, 36 events, 18 trials
# Loading subject 11 (bcmi-calibration):
#   ✓ Run 1: 1128.0s, 36 events, 18 trials
#   ✓ Run 2: 1007.0s, 36 events, 18 trials
#   ✓ Run 3: 935.0s, 36 events, 18 trials
#   ✓ Run 4: 978.0s, 36 events, 18 trials
#   ✓ Run 5: 931.0s, 36 events, 18 trials
# Loading subject 12 (bcmi-calibration):
#   ✓ Run 1: 891.0s, 36 events, 18 trials
#   ✓ Run 2: 862.0s, 36 events, 18 trials
#   ✓ Run 3: 883.0s, 36 events, 18 trials
#   ✓ Run 4: 885.0s, 36 events, 18 trials
#   ✓ Run 5: 883.0s, 36 events, 18 trials
# Loading subject 13 (bcmi-calibration):
#   ✓ Run 1: 838.0s, 36 events, 18 trials
#   ✓ Run 2: 843.0s, 36 events, 18 trials
#   ✓ Run 3: 834.0s, 36 events, 18 trials
#   ✓ Run 4: 838.0s, 36 events, 18 trials
#   ✓ Run 5: 824.0s, 36 events, 18 trials
# Loading subject 14 (bcmi-calibration):
#   ✓ Run 1: 986.0s, 36 events, 18 trials
#   ✓ Run 2: 946.0s, 36 events, 18 trials
#   ✓ Run 3: 898.0s, 36 events, 18 trials
#   ✓ Run 4: 842.0s, 36 events, 18 trials
#   ✓ Run 5: 829.0s, 36 events, 18 trials
# Loading subject 15 (bcmi-calibration):
#   ✓ Run 1: 949.0s, 36 events, 18 trials
#   ✓ Run 2: 875.0s, 36 events, 18 trials
#   ✓ Run 3: 868.0s, 36 events, 18 trials
#   ✓ Run 4: 843.0s, 36 events, 18 trials
#   ✓ Run 5: 845.0s, 36 events, 18 trials
# Loading subject 16 (bcmi-calibration):
#   ✓ Run 1: 927.0s, 36 events, 18 trials
#   ✓ Run 2: 868.0s, 36 events, 18 trials
#   ✓ Run 3: 852.0s, 36 events, 18 trials
#   ✓ Run 4: 823.0s, 36 events, 18 trials
#   ✓ Run 5: 836.0s, 36 events, 18 trials
# Loading subject 17 (bcmi-calibration):
#   ✓ Run 1: 954.0s, 36 events, 18 trials
#   ✓ Run 2: 829.0s, 36 events, 18 trials
#   ✓ Run 3: 861.0s, 36 events, 18 trials
#   ✓ Run 4: 840.0s, 36 events, 18 trials
#   ✓ Run 5: 830.0s, 36 events, 18 trials
# Loading subject 18 (bcmi-calibration):
#   ✓ Run 1: 961.0s, 36 events, 18 trials
#   ✓ Run 2: 895.0s, 36 events, 18 trials
#   ✓ Run 3: 847.0s, 36 events, 18 trials
#   ✓ Run 4: 847.0s, 36 events, 18 trials
#   ✓ Run 5: 830.0s, 36 events, 18 trials
# Loading subject 19 (bcmi-calibration):
#   ✓ Run 1: 960.0s, 36 events, 18 trials
#   ✓ Run 2: 964.0s, 36 events, 18 trials
#   ✓ Run 3: 869.0s, 36 events, 18 trials
#   ✓ Run 4: 856.0s, 36 events, 18 trials
#   ✓ Run 5: 853.0s, 36 events, 18 trials
# 📈 BCMI-CALIBRATION DATASET STATISTICS:
# • Loaded subjects: 19
# • Total sessions: 19
# • Total runs: 94
# • Total trials: 1692
#
# 🎵 EXPERIMENTAL PARADIGM:
# • Type: Calibration
# • Trial structure: 40s total (20s state1 + 20s state2)
# • Music type: Synthetic real-time generated
#
# 🎭 EMOTIONAL CONDITION DISTRIBUTION:
#   Condition 1 (Excited/Happy): 125 trials
#   Condition 2 (Peaceful/Content): 188 trials
#   Condition 3 (Positive/Pleasant): 148 trials
#   Condition 4 (Angry/Agitated): 205 trials
#   Condition 5 (Sad/Depressed): 205 trials
#   Condition 6 (Negative/Unpleasant): 195 trials
#   Condition 7 (Alert/Activated): 258 trials
#   Condition 9 (Neutral/Balanced): 368 trials
#
# ⚙️  TECHNICAL SPECIFICATIONS:
# • Sampling rate: 1000.0 Hz
# • Channels per recording: 37
# • Average run duration: ~859 seconds

# %%
# durations
# epochs = mne.Epochs(
#     raw1,
#     events,
#     event_id={'stimulus_onset': 1},
#     tmin=-0.2,      # Pre-stimulus baseline
#     tmax=0.8,       # Post-stimulus window  
#     baseline=(-0.2, 0),
#     preload=True
# )
# session = '3'
# for x in loader.data[subjects[0]][session]['1']['processed_events']['training_pairs']:
#   i,j = x['affect_1']['code'], x['affect_2']['code']
#   assert  x['affect_2']['onset'] - x['affect_1']['onset'] == 20_000

def onset_secs_to_samples(onset_secs, sfreq):
  return round(onset_secs * sfreq)

def loader_data_iter(data):
  for subject in data.keys():
    for session in data[subject].keys():
      for run in data[subject][session].keys():
        r = data[subject][session][run]
        yield subject, session, run, r

for subject, session, run, r in loader_data_iter(loader.data):
  for x in r['processed_events']['training_pairs']:
    i,j = x['affect_1']['code'], x['affect_2']['code']
    # music: i-j_session
    # print(x['affect_2']['onset'] - x['affect_1']['onset'])
    assert onset_secs_to_samples(x['affect_2']['onset'] - x['affect_1']['onset'], sfreq=r['raw'].info['sfreq']) == 20_000

# %%
loader.data["08"]['3']['1']
# Out:
# {'raw': <RawEDF | sub-08_ses-3_task-run1_eeg.edf, 37 x 1008000 (1008.0 s), ~33 KiB, data not loaded>,
#  'events':       onset  duration  trial_type
#  0     8.865        21           1
#  1    28.865        21           6
#  2    66.732        21           9
#  3    86.732        21           6
#  4   122.835        21           9
#  5   142.835        21           3
#  6   177.397        21           3
#  7   197.397        21           6
#  8   232.831        21           3
#  9   252.831        21           4
#  10  288.196        21           9
#  11  308.196        21           8
#  12  343.341        21           1
#  13  363.341        21           2
#  14  397.975        21           1
#  15  417.975        21           8
#  16  455.042        21           8
#  17  475.042        21           7
#  18  510.600        21           1
#  19  530.600        21           9
#  20  567.530        21           6
#  21  587.530        21           8
#  22  622.195        21           1
#  23  642.195        21           3
#  24  677.602        21           4
#  25  697.602        21           6
#  26  733.998        21           5
#  27  753.998        21           6
#  28  789.371        21           9
#  29  809.371        21           4
#  30  844.254        21           4
#  31  864.254        21           7
#  32  900.932        21           1
#  33  920.932        21           5
#  34  955.946        21           1
#  35  975.946        21           4,
#  'processed_events': {'emotion_events':       onset  duration  trial_type  emotion_description  valence  arousal
#   0     8.865        21           1        Excited/Happy     High     High
#   1    28.865        21           6  Negative/Unpleasant      Low  Neutral
#   2    66.732        21           9     Neutral/Balanced  Neutral  Neutral
#   3    86.732        21           6  Negative/Unpleasant      Low  Neutral
#   4   122.835        21           9     Neutral/Balanced  Neutral  Neutral
#   5   142.835        21           3    Positive/Pleasant     High  Neutral
#   6   177.397        21           3    Positive/Pleasant     High  Neutral
#   7   197.397        21           6  Negative/Unpleasant      Low  Neutral
#   8   232.831        21           3    Positive/Pleasant     High  Neutral
#   9   252.831        21           4       Angry/Agitated      Low     High
#   10  288.196        21           9     Neutral/Balanced  Neutral  Neutral
#   11  308.196        21           8         Calm/Relaxed  Neutral      Low
#   12  343.341        21           1        Excited/Happy     High     High
#   13  363.341        21           2     Peaceful/Content     High      Low
#   14  397.975        21           1        Excited/Happy     High     High
#   15  417.975        21           8         Calm/Relaxed  Neutral      Low
#   16  455.042        21           8         Calm/Relaxed  Neutral      Low
#   17  475.042        21           7      Alert/Activated  Neutral     High
#   18  510.600        21           1        Excited/Happy     High     High
#   19  530.600        21           9     Neutral/Balanced  Neutral  Neutral
#   20  567.530        21           6  Negative/Unpleasant      Low  Neutral
#   21  587.530        21           8         Calm/Relaxed  Neutral      Low
#   22  622.195        21           1        Excited/Happy     High     High
#   23  642.195        21           3    Positive/Pleasant     High  Neutral
#   24  677.602        21           4       Angry/Agitated      Low     High
#   25  697.602        21           6  Negative/Unpleasant      Low  Neutral
#   26  733.998        21           5        Sad/Depressed      Low      Low
#   27  753.998        21           6  Negative/Unpleasant      Low  Neutral
#   28  789.371        21           9     Neutral/Balanced  Neutral  Neutral
#   29  809.371        21           4       Angry/Agitated      Low     High
#   30  844.254        21           4       Angry/Agitated      Low     High
#   31  864.254        21           7      Alert/Activated  Neutral     High
#   32  900.932        21           1        Excited/Happy     High     High
#   33  920.932        21           5        Sad/Depressed      Low      Low
#   34  955.946        21           1        Excited/Happy     High     High
#   35  975.946        21           4       Angry/Agitated      Low     High,
#   'marker_events': Empty DataFrame
#   Columns: [onset, duration, trial_type]
#   Index: [],
#   'all_events':       onset  duration  trial_type
#   0     8.865        21           1
#   1    28.865        21           6
#   2    66.732        21           9
#   3    86.732        21           6
#   4   122.835        21           9
#   5   142.835        21           3
#   6   177.397        21           3
#   7   197.397        21           6
#   8   232.831        21           3
#   9   252.831        21           4
#   10  288.196        21           9
#   11  308.196        21           8
#   12  343.341        21           1
#   13  363.341        21           2
#   14  397.975        21           1
#   15  417.975        21           8
#   16  455.042        21           8
#   17  475.042        21           7
#   18  510.600        21           1
#   19  530.600        21           9
#   20  567.530        21           6
#   21  587.530        21           8
#   22  622.195        21           1
#   23  642.195        21           3
#   24  677.602        21           4
#   25  697.602        21           6
#   26  733.998        21           5
#   27  753.998        21           6
#   28  789.371        21           9
#   29  809.371        21           4
#   30  844.254        21           4
#   31  864.254        21           7
#   32  900.932        21           1
#   33  920.932        21           5
#   34  955.946        21           1
#   35  975.946        21           4,
#   'training_pairs': [{'pair_number': 1,
#     'affect_1': {'code': np.int64(1),
#      'onset': np.float64(8.865),
#      'description': 'Excited/Happy'},
#     'affect_2': {'code': np.int64(6),
#      'onset': np.float64(28.865),
#      'description': 'Negative/Unpleasant'},
#     'contrast': 'Excited/Happy → Negative/Unpleasant'},
#    {'pair_number': 2,
#     'affect_1': {'code': np.int64(9),
#      'onset': np.float64(66.732),
#      'description': 'Neutral/Balanced'},
#     'affect_2': {'code': np.int64(6),
#      'onset': np.float64(86.732),
#      'description': 'Negative/Unpleasant'},
#     'contrast': 'Neutral/Balanced → Negative/Unpleasant'},
#    {'pair_number': 3,
#     'affect_1': {'code': np.int64(9),
#      'onset': np.float64(122.835),
#      'description': 'Neutral/Balanced'},
#     'affect_2': {'code': np.int64(3),
#      'onset': np.float64(142.835),
#      'description': 'Positive/Pleasant'},
#     'contrast': 'Neutral/Balanced → Positive/Pleasant'},
#    {'pair_number': 4,
#     'affect_1': {'code': np.int64(3),
#      'onset': np.float64(177.397),
#      'description': 'Positive/Pleasant'},
#     'affect_2': {'code': np.int64(6),
#      'onset': np.float64(197.397),
#      'description': 'Negative/Unpleasant'},
#     'contrast': 'Positive/Pleasant → Negative/Unpleasant'},
#    {'pair_number': 5,
#     'affect_1': {'code': np.int64(3),
#      'onset': np.float64(232.831),
#      'description': 'Positive/Pleasant'},
#     'affect_2': {'code': np.int64(4),
#      'onset': np.float64(252.831),
#      'description': 'Angry/Agitated'},
#     'contrast': 'Positive/Pleasant → Angry/Agitated'},
#    {'pair_number': 6,
#     'affect_1': {'code': np.int64(9),
#      'onset': np.float64(288.196),
#      'description': 'Neutral/Balanced'},
#     'affect_2': {'code': np.int64(8),
#      'onset': np.float64(308.196),
#      'description': 'Calm/Relaxed'},
#     'contrast': 'Neutral/Balanced → Calm/Relaxed'},
#    {'pair_number': 7,
#     'affect_1': {'code': np.int64(1),
#      'onset': np.float64(343.341),
#      'description': 'Excited/Happy'},
#     'affect_2': {'code': np.int64(2),
#      'onset': np.float64(363.341),
#      'description': 'Peaceful/Content'},
#     'contrast': 'Excited/Happy → Peaceful/Content'},
#    {'pair_number': 8,
#     'affect_1': {'code': np.int64(1),
#      'onset': np.float64(397.975),
#      'description': 'Excited/Happy'},
#     'affect_2': {'code': np.int64(8),
#      'onset': np.float64(417.975),
#      'description': 'Calm/Relaxed'},
#     'contrast': 'Excited/Happy → Calm/Relaxed'},
#    {'pair_number': 9,
#     'affect_1': {'code': np.int64(8),
#      'onset': np.float64(455.042),
#      'description': 'Calm/Relaxed'},
#     'affect_2': {'code': np.int64(7),
#      'onset': np.float64(475.042),
#      'description': 'Alert/Activated'},
#     'contrast': 'Calm/Relaxed → Alert/Activated'},
#    {'pair_number': 10,
#     'affect_1': {'code': np.int64(1),
#      'onset': np.float64(510.6),
#      'description': 'Excited/Happy'},
#     'affect_2': {'code': np.int64(9),
#      'onset': np.float64(530.6),
#      'description': 'Neutral/Balanced'},
#     'contrast': 'Excited/Happy → Neutral/Balanced'},
#    {'pair_number': 11,
#     'affect_1': {'code': np.int64(6),
#      'onset': np.float64(567.53),
#      'description': 'Negative/Unpleasant'},
#     'affect_2': {'code': np.int64(8),
#      'onset': np.float64(587.53),
#      'description': 'Calm/Relaxed'},
#     'contrast': 'Negative/Unpleasant → Calm/Relaxed'},
#    {'pair_number': 12,
#     'affect_1': {'code': np.int64(1),
#      'onset': np.float64(622.195),
#      'description': 'Excited/Happy'},
#     'affect_2': {'code': np.int64(3),
#      'onset': np.float64(642.195),
#      'description': 'Positive/Pleasant'},
#     'contrast': 'Excited/Happy → Positive/Pleasant'},
#    {'pair_number': 13,
#     'affect_1': {'code': np.int64(4),
#      'onset': np.float64(677.602),
#      'description': 'Angry/Agitated'},
#     'affect_2': {'code': np.int64(6),
#      'onset': np.float64(697.602),
#      'description': 'Negative/Unpleasant'},
#     'contrast': 'Angry/Agitated → Negative/Unpleasant'},
#    {'pair_number': 14,
#     'affect_1': {'code': np.int64(5),
#      'onset': np.float64(733.998),
#      'description': 'Sad/Depressed'},
#     'affect_2': {'code': np.int64(6),
#      'onset': np.float64(753.998),
#      'description': 'Negative/Unpleasant'},
#     'contrast': 'Sad/Depressed → Negative/Unpleasant'},
#    {'pair_number': 15,
#     'affect_1': {'code': np.int64(9),
#      'onset': np.float64(789.371),
#      'description': 'Neutral/Balanced'},
#     'affect_2': {'code': np.int64(4),
#      'onset': np.float64(809.371),
#      'description': 'Angry/Agitated'},
#     'contrast': 'Neutral/Balanced → Angry/Agitated'},
#    {'pair_number': 16,
#     'affect_1': {'code': np.int64(4),
#      'onset': np.float64(844.254),
#      'description': 'Angry/Agitated'},
#     'affect_2': {'code': np.int64(7),
#      'onset': np.float64(864.254),
#      'description': 'Alert/Activated'},
#     'contrast': 'Angry/Agitated → Alert/Activated'},
#    {'pair_number': 17,
#     'affect_1': {'code': np.int64(1),
#      'onset': np.float64(900.932),
#      'description': 'Excited/Happy'},
#     'affect_2': {'code': np.int64(5),
#      'onset': np.float64(920.932),
#      'description': 'Sad/Depressed'},
#     'contrast': 'Excited/Happy → Sad/Depressed'},
#    {'pair_number': 18,
#     'affect_1': {'code': np.int64(1),
#      'onset': np.float64(955.946),
#      'description': 'Excited/Happy'},
#     'affect_2': {'code': np.int64(4),
#      'onset': np.float64(975.946),
#      'description': 'Angry/Agitated'},
#     'contrast': 'Excited/Happy → Angry/Agitated'}]},
#  'duration': np.float64(1008.0),
#  'n_channels': 37,
#  'sfreq': 1000.0,
#  'experimental_info': {'paradigm_type': 'Training',
#   'trial_structure': '40s total (20s + 20s targeting different affects)',
#   'music_type': 'Synthetic generated',
#   'sessions_per_subject': 'Variable',
#   'description': 'Training sessions for dual-affective state targeting',
#   'task_name': 'run1'},
#  'bids_path': BIDSPath(
#  root: datasets/bcmi/bcmi-training
#  datatype: eeg
#  basename: sub-08_ses-3_task-run1),
#  'n_trials': 36}

# %%
wav_filenames_ordered = [
  'hvha1.wav', 'hvha10.wav', 'hvha11.wav', 'hvha12.wav', 'hvha2.wav', 'hvha3.wav', 'hvha4.wav', 
  'hvha5.wav', 'hvha6.wav', 'hvha7.wav', 'hvha8.wav', 'hvha9.wav', 'hvla1.wav', 'hvla10.wav', 
  'hvla11.wav', 'hvla12.wav', 'hvla2.wav', 'hvla3.wav', 'hvla4.wav', 'hvla5.wav', 'hvla6.wav',
  'hvla7.wav', 'hvla8.wav', 'hvla9.wav', 'hvna1.wav', 'hvna10.wav', 'hvna11.wav', 'hvna12.wav',
  'hvna2.wav', 'hvna3.wav', 'hvna4.wav', 'hvna5.wav', 'hvna6.wav', 'hvna7.wav' , 'hvna8.wav',
  'hvna9.wav', 'lvha1.wav', 'lvha10.wav', 'lvha11.wav', 'lvha12.wav', 'lvha2.wav', 'lvha3.wav',
  'lvha4.wav', 'lvha5.wav','lvha6.wav', 'lvha7.wav', 'lvha8.wav', 'lvha9.wav', 'lvla1.wav',
  'lvla10.wav', 'lvla11.wav', 'lvla12.wav', 'lvla2.wav', 'lvla3.wav', 'lvla4.wav', 'lvla5.wav',
  'lvla6.wav', 'lvla7.wav', 'lvla8.wav' , 'lvla9.wav', 'lvna1.wav', 'lvna10.wav', 'lvna11.wav',
  'lvna12.wav', 'lvna2.wav', 'lvna3.wav', 'lvna4.wav', 'lvna5.wav', 'lvna6.wav', 'lvna7.wav',
  'lvna8.wav', 'lvna9.wav', 'nvha1.wav', 'nvha10.wav', 'nvha11.wav', 'nvha12.wav', 'nvha2.wav',
  'nvha3.wav', 'nvha4.wav', 'nvha5.wav', 'nvha6.wav', 'nvha7.wav', 'nvha8.wav', 'nvha9.wav',
  'nvla1.wav', 'nvla10.wav', 'nvla11.wav', 'nvla12.wav', 'nvla2.wav', 'nvla3.wav', 'nvla4.wav',
  'nvla5.wav', 'nvla6.wav', 'nvla7.wav', 'nvla8.wav', 'nvla9.wav', 'nvna1.wav', 'nvna10.wav',
  'nvna11.wav', 'nvna12.wav', 'nvna2.wav', 'nvna3.wav', 'nvna4.wav', 'nvna5.wav', 'nvna6.wav', 
  'nvna7.wav', 'nvna8.wav', 'nvna9.wav'
]

duration = 21000
for subject, session, run, r in loader.loader_data_iter():
  # print(r['processed_events']['marker_events'])
  for _, marker in r['processed_events']['marker_events'].iterrows():
    # print(r['processed_events']['marker_events'])
    print(marker)
    onset = marker['onset']
    music_file = wav_filenames_ordered[ round(marker['trial_type']) - 100 ]
    print(f"Onset (samples): {onset}, Music file: {music_file}, emotion: {marker}")
# Out:
# onset           9.643
# duration       21.000
# trial_type    104.000
# Name: 1, dtype: float64
# Onset (samples): 9.643, Music file: hvha2.wav, emotion: onset           9.643
# duration       21.000
# trial_type    104.000
# Name: 1, dtype: float64
# onset          63.82
# duration       21.00
# trial_type    163.00
# Name: 3, dtype: float64
# Onset (samples): 63.82, Music file: lvna12.wav, emotion: onset          63.82
# duration       21.00
# trial_type    163.00
# Name: 3, dtype: float64
# onset         115.429
# duration       21.000
# trial_type    173.000
# Name: 5, dtype: float64
# Onset (samples): 115.429, Music file: nvha10.wav, emotion: onset         115.429
# duration       21.000
# trial_type    173.000
# Name: 5, dtype: float64
# onset         163.065
# duration       21.000
# trial_type    205.000
# Name: 7, dtype: float64
# Onset (samples): 163.065, Music file: nvna7.wav, emotion: onset         163.065
# duration       21.000
# trial_type    205.000
# Name: 7, dtype: float64
# onset         209.917
# duration       21.000
# trial_type    202.000
# Name: 9, dtype: float64
# Onset (samples): 209.917, Music file: nvna4.wav, emotion: onset         209.917
# duration       21.000
# trial_type    202.000
# Name: 9, dtype: float64
# onset         257.556
# duration       21.000
# trial_type    109.000
# Name: 11, dtype: float64
# Onset (samples): 257.556, Music file: hvha7.wav, emotion: onset         257.556
# duration       21.000
# trial_type    109.000
# Name: 11, dtype: float64
# onset         304.066
# duration       21.000
# trial_type    150.000
# Name: 13, dtype: float64
# Onset (samples): 304.066, Music file: lvla11.wav, emotion: onset         304.066
# duration       21.000
# trial_type    150.000
# Name: 13, dtype: float64
# onset         349.865
# duration       21.000
# trial_type    176.000
# Name: 15, dtype: float64
# Onset (samples): 349.865, Music file: nvha2.wav, emotion: onset         349.865
# duration       21.000
# trial_type    176.000
# Name: 15, dtype: float64
# onset         395.778
# duration       21.000
# trial_type    165.000
# Name: 17, dtype: float64
# Onset (samples): 395.778, Music file: lvna3.wav, emotion: onset         395.778
# duration       21.000
# trial_type    165.000
# Name: 17, dtype: float64
# onset         442.602
# duration       21.000
# trial_type    182.000
# Name: 19, dtype: float64
# Onset (samples): 442.602, Music file: nvha8.wav, emotion: onset         442.602
# duration       21.000
# trial_type    182.000
# Name: 19, dtype: float64
# onset         487.551
# duration       21.000
# trial_type    206.000
# Name: 21, dtype: float64
# Onset (samples): 487.551, Music file: nvna8.wav, emotion: onset         487.551
# duration       21.000
# trial_type    206.000
# Name: 21, dtype: float64
# onset         534.583
# duration       21.000
# trial_type    134.000
# Name: 23, dtype: float64
# Onset (samples): 534.583, Music file: hvna8.wav, emotion: onset         534.583
# duration       21.000
# trial_type    134.000
# Name: 23, dtype: float64
# onset         583.932
# duration       21.000
# trial_type    201.000
# Name: 25, dtype: float64
# Onset (samples): 583.932, Music file: nvna3.wav, emotion: onset         583.932
# duration       21.000
# trial_type    201.000
# Name: 25, dtype: float64
# onset         630.474
# duration       21.000
# trial_type    153.000
# Name: 27, dtype: float64
# Onset (samples): 630.474, Music file: lvla3.wav, emotion: onset         630.474
# duration       21.000
# trial_type    153.000
# Name: 27, dtype: float64
# onset         676.77
# duration       21.00
# trial_type    185.00
# Name: 29, dtype: float64
# Onset (samples): 676.77, Music file: nvla10.wav, emotion: onset         676.77
# duration       21.00
# trial_type    185.00
# Name: 29, dtype: float64
# onset         723.479
# duration       21.000
# trial_type    194.000
# Name: 31, dtype: float64
# Onset (samples): 723.479, Music file: nvla8.wav, emotion: onset         723.479
# duration       21.000
# trial_type    194.000
# Name: 31, dtype: float64
# onset         769.392
# duration       21.000
# trial_type    186.000
# Name: 33, dtype: float64
# Onset (samples): 769.392, Music file: nvla11.wav, emotion: onset         769.392
# duration       21.000
# trial_type    186.000
# Name: 33, dtype: float64
# onset         816.118
# duration       21.000
# trial_type    193.000
# Name: 35, dtype: float64
# Onset (samples): 816.118, Music file: nvla7.wav, emotion: onset         816.118
# duration       21.000
# trial_type    193.000
# Name: 35, dtype: float64
# onset           9.018
# duration       21.000
# trial_type    139.000
# Name: 1, dtype: float64
# Onset (samples): 9.018, Music file: lvha12.wav, emotion: onset           9.018
# duration       21.000
# trial_type    139.000
# Name: 1, dtype: float64
# onset          56.029
# duration       21.000
# trial_type    191.000
# Name: 3, dtype: float64
# Onset (samples): 56.029, Music file: nvla5.wav, emotion: onset          56.029
# duration       21.000
# trial_type    191.000
# Name: 3, dtype: float64
# onset         101.177
# duration       21.000
# trial_type    140.000
# Name: 5, dtype: float64
# Onset (samples): 101.177, Music file: lvha2.wav, emotion: onset         101.177
# duration       21.000
# trial_type    140.000
# Name: 5, dtype: float64
# onset         150.683
# duration       21.000
# trial_type    197.000
# Name: 7, dtype: float64
# Onset (samples): 150.683, Music file: nvna10.wav, emotion: onset         150.683
# duration       21.000
# trial_type    197.000
# Name: 7, dtype: float64
# onset         194.944
# duration       21.000
# trial_type    131.000
# Name: 9, dtype: float64
# Onset (samples): 194.944, Music file: hvna5.wav, emotion: onset         194.944
# duration       21.000
# trial_type    131.000
# Name: 9, dtype: float64
# onset         239.8
# duration       21.0
# trial_type    128.0
# Name: 11, dtype: float64
# Onset (samples): 239.8, Music file: hvna2.wav, emotion: onset         239.8
# duration       21.0
# trial_type    128.0
# Name: 11, dtype: float64
# onset         284.966
# duration       21.000
# trial_type    155.000
# Name: 13, dtype: float64
# Onset (samples): 284.966, Music file: lvla5.wav, emotion: onset         284.966
# duration       21.000
# trial_type    155.000
# Name: 13, dtype: float64
# onset         331.745
# duration       21.000
# trial_type    177.000
# Name: 15, dtype: float64
# Onset (samples): 331.745, Music file: nvha3.wav, emotion: onset         331.745
# duration       21.000
# trial_type    177.000
# Name: 15, dtype: float64
# onset         379.566
# duration       21.000
# trial_type    108.000
# Name: 17, dtype: float64
# Onset (samples): 379.566, Music file: hvha6.wav, emotion: onset         379.566
# duration       21.000
# trial_type    108.000
# Name: 17, dtype: float64
# onset         425.783
# duration       21.000
# trial_type    164.000
# Name: 19, dtype: float64
# Onset (samples): 425.783, Music file: lvna2.wav, emotion: onset         425.783
# duration       21.000
# trial_type    164.000
# Name: 19, dtype: float64
# onset         471.556
# duration       21.000
# trial_type    189.000
# Name: 21, dtype: float64
# Onset (samples): 471.556, Music file: nvla3.wav, emotion: onset         471.556
# duration       21.000
# trial_type    189.000
# Name: 21, dtype: float64
# onset         516.958
# duration       21.000
# trial_type    115.000
# Name: 23, dtype: float64
# Onset (samples): 516.958, Music file: hvla12.wav, emotion: onset         516.958
# duration       21.000
# trial_type    115.000
# Name: 23, dtype: float64
# onset         562.533
# duration       21.000
# trial_type    132.000
# Name: 25, dtype: float64
# Onset (samples): 562.533, Music file: hvna6.wav, emotion: onset         562.533
# duration       21.000
# trial_type    132.000
# Name: 25, dtype: float64
# onset         609.215
# duration       21.000
# trial_type    181.000
# Name: 27, dtype: float64
# Onset (samples): 609.215, Music file: nvha7.wav, emotion: onset         609.215
# duration       21.000
# trial_type    181.000
# Name: 27, dtype: float64
# onset         655.638
# duration       21.000
# trial_type    146.000
# Name: 29, dtype: float64
# Onset (samples): 655.638, Music file: lvha8.wav, emotion: onset         655.638
# duration       21.000
# trial_type    146.000
# Name: 29, dtype: float64
# onset         701.208
# duration       21.000
# trial_type    107.000
# Name: 31, dtype: float64
# Onset (samples): 701.208, Music file: hvha5.wav, emotion: onset         701.208
# duration       21.000
# trial_type    107.000
# Name: 31, dtype: float64
# onset         750.524
# duration       21.000
# trial_type    170.000
# Name: 33, dtype: float64
# Onset (samples): 750.524, Music file: lvna8.wav, emotion: onset         750.524
# duration       21.000
# trial_type    170.000
# Name: 33, dtype: float64
# onset         795.024
# duration       21.000
# trial_type    120.000
# Name: 35, dtype: float64
# Onset (samples): 795.024, Music file: hvla6.wav, emotion: onset         795.024
# duration       21.000
# trial_type    120.000
# Name: 35, dtype: float64
# onset           9.876
# duration       21.000
# trial_type    151.000
# Name: 1, dtype: float64
# Onset (samples): 9.876, Music file: lvla12.wav, emotion: onset           9.876
# duration       21.000
# trial_type    151.000
# Name: 1, dtype: float64
# onset          57.431
# duration       21.000
# trial_type    167.000
# Name: 3, dtype: float64
# Onset (samples): 57.431, Music file: lvna5.wav, emotion: onset          57.431
# duration       21.000
# trial_type    167.000
# Name: 3, dtype: float64
# onset         105.528
# duration       21.000
# trial_type    130.000
# Name: 5, dtype: float64
# Onset (samples): 105.528, Music file: hvna4.wav, emotion: onset         105.528
# duration       21.000
# trial_type    130.000
# Name: 5, dtype: float64
# onset         149.96
# duration       21.00
# trial_type    187.00
# Name: 7, dtype: float64
# Onset (samples): 149.96, Music file: nvla12.wav, emotion: onset         149.96
# duration       21.00
# trial_type    187.00
# Name: 7, dtype: float64
# onset         194.814
# duration       21.000
# trial_type    154.000
# Name: 9, dtype: float64
# Onset (samples): 194.814, Music file: lvla4.wav, emotion: onset         194.814
# duration       21.000
# trial_type    154.000
# Name: 9, dtype: float64
# onset         238.729
# duration       21.000
# trial_type    199.000
# Name: 11, dtype: float64
# Onset (samples): 238.729, Music file: nvna12.wav, emotion: onset         238.729
# duration       21.000
# trial_type    199.000
# Name: 11, dtype: float64
# onset         288.431
# duration       21.000
# trial_type    179.000
# Name: 13, dtype: float64
# Onset (samples): 288.431, Music file: nvha5.wav, emotion: onset         288.431
# duration       21.000
# trial_type    179.000
# Name: 13, dtype: float64
# onset         334.427
# duration       21.000
# trial_type    180.000
# Name: 15, dtype: float64
# Onset (samples): 334.427, Music file: nvha6.wav, emotion: onset         334.427
# duration       21.000
# trial_type    180.000
# Name: 15, dtype: float64
# onset         378.252
# duration       21.000
# trial_type    102.000
# Name: 17, dtype: float64
# Onset (samples): 378.252, Music file: hvha11.wav, emotion: onset         378.252
# duration       21.000
# trial_type    102.000
# Name: 17, dtype: float64
# onset         422.02
# duration       21.00
# trial_type    188.00
# Name: 19, dtype: float64
# Onset (samples): 422.02, Music file: nvla2.wav, emotion: onset         422.02
# duration       21.00
# trial_type    188.00
# Name: 19, dtype: float64
# onset         469.068
# duration       21.000
# trial_type    162.000
# Name: 21, dtype: float64
# Onset (samples): 469.068, Music file: lvna11.wav, emotion: onset         469.068
# duration       21.000
# trial_type    162.000
# Name: 21, dtype: float64
# onset         517.941
# duration       21.000
# trial_type    105.000
# Name: 23, dtype: float64
# Onset (samples): 517.941, Music file: hvha3.wav, emotion: onset         517.941
# duration       21.000
# trial_type    105.000
# Name: 23, dtype: float64
# onset         563.921
# duration       21.000
# trial_type    117.000
# Name: 25, dtype: float64
# Onset (samples): 563.921, Music file: hvla3.wav, emotion: onset         563.921
# duration       21.000
# trial_type    117.000
# Name: 25, dtype: float64
# onset         608.431
# duration       21.000
# trial_type    200.000
# Name: 27, dtype: float64
# Onset (samples): 608.431, Music file: nvna2.wav, emotion: onset         608.431
# duration       21.000
# trial_type    200.000
# Name: 27, dtype: float64
# onset         653.997
# duration       21.000
# trial_type    103.000
# Name: 29, dtype: float64
# Onset (samples): 653.997, Music file: hvha12.wav, emotion: onset         653.997
# duration       21.000
# trial_type    103.000
# Name: 29, dtype: float64
# onset         703.571
# duration       21.000
# trial_type    122.000
# Name: 31, dtype: float64
# Onset (samples): 703.571, Music file: hvla8.wav, emotion: onset         703.571
# duration       21.000
# trial_type    122.000
# Name: 31, dtype: float64
# onset         748.44
# duration       21.00
# trial_type    175.00
# Name: 33, dtype: float64
# Onset (samples): 748.44, Music file: nvha12.wav, emotion: onset         748.44
# duration       21.00
# trial_type    175.00
# Name: 33, dtype: float64
# onset         795.31
# duration       21.00
# trial_type    144.00
# Name: 35, dtype: float64
# Onset (samples): 795.31, Music file: lvha6.wav, emotion: onset         795.31
# duration       21.00
# trial_type    144.00
# Name: 35, dtype: float64
# onset           9.929
# duration       21.000
# trial_type    125.000
# Name: 1, dtype: float64
# Onset (samples): 9.929, Music file: hvna10.wav, emotion: onset           9.929
# duration       21.000
# trial_type    125.000
# Name: 1, dtype: float64
# onset          54.769
# duration       21.000
# trial_type    119.000
# Name: 3, dtype: float64
# Onset (samples): 54.769, Music file: hvla5.wav, emotion: onset          54.769
# duration       21.000
# trial_type    119.000
# Name: 3, dtype: float64
# onset         100.444
# duration       21.000
# trial_type    203.000
# Name: 5, dtype: float64
# Onset (samples): 100.444, Music file: nvna5.wav, emotion: onset         100.444
# duration       21.000
# trial_type    203.000
# Name: 5, dtype: float64
# onset         149.134
# duration       21.000
# trial_type    169.000
# Name: 7, dtype: float64
# Onset (samples): 149.134, Music file: lvna7.wav, emotion: onset         149.134
# duration       21.000
# trial_type    169.000
# Name: 7, dtype: float64
# onset         197.771
# duration       21.000
# trial_type    192.000
# Name: 9, dtype: float64
# Onset (samples): 197.771, Music file: nvla6.wav, emotion: onset         197.771
# duration       21.000
# trial_type    192.000
# Name: 9, dtype: float64
# onset         243.471
# duration       21.000
# trial_type    110.000
# Name: 11, dtype: float64
# Onset (samples): 243.471, Music file: hvha8.wav, emotion: onset         243.471
# duration       21.000
# trial_type    110.000
# Name: 11, dtype: float64
# onset         288.164
# duration       21.000
# trial_type    116.000
# Name: 13, dtype: float64
# Onset (samples): 288.164, Music file: hvla2.wav, emotion: onset         288.164
# duration       21.000
# trial_type    116.000
# Name: 13, dtype: float64
# onset         334.402
# duration       21.000
# trial_type    157.000
# Name: 15, dtype: float64
# Onset (samples): 334.402, Music file: lvla7.wav, emotion: onset         334.402
# duration       21.000
# trial_type    157.000
# Name: 15, dtype: float64
# onset         380.415
# duration       21.000
# trial_type    114.000
# Name: 17, dtype: float64
# Onset (samples): 380.415, Music file: hvla11.wav, emotion: onset         380.415
# duration       21.000
# trial_type    114.000
# Name: 17, dtype: float64
# onset         424.667
# duration       21.000
# trial_type    133.000
# Name: 19, dtype: float64
# Onset (samples): 424.667, Music file: hvna7.wav, emotion: onset         424.667
# duration       21.000
# trial_type    133.000
# Name: 19, dtype: float64
# onset         468.853
# duration       21.000
# trial_type    126.000
# Name: 21, dtype: float64
# Onset (samples): 468.853, Music file: hvna11.wav, emotion: onset         468.853
# duration       21.000
# trial_type    126.000
# Name: 21, dtype: float64
# onset         515.186
# duration       21.000
# trial_type    129.000
# Name: 23, dtype: float64
# Onset (samples): 515.186, Music file: hvna3.wav, emotion: onset         515.186
# duration       21.000
# trial_type    129.000
# Name: 23, dtype: float64
# onset         560.177
# duration       21.000
# trial_type    152.000
# Name: 25, dtype: float64
# Onset (samples): 560.177, Music file: lvla2.wav, emotion: onset         560.177
# duration       21.000
# trial_type    152.000
# Name: 25, dtype: float64
# onset         604.891
# duration       21.000
# trial_type    118.000
# Name: 27, dtype: float64
# Onset (samples): 604.891, Music file: hvla4.wav, emotion: onset         604.891
# duration       21.000
# trial_type    118.000
# Name: 27, dtype: float64
# onset         649.484
# duration       21.000
# trial_type    142.000
# Name: 29, dtype: float64
# Onset (samples): 649.484, Music file: lvha4.wav, emotion: onset         649.484
# duration       21.000
# trial_type    142.000
# Name: 29, dtype: float64
# onset         697.503
# duration       21.000
# trial_type    143.000
# Name: 31, dtype: float64
# Onset (samples): 697.503, Music file: lvha5.wav, emotion: onset         697.503
# duration       21.000
# trial_type    143.000
# Name: 31, dtype: float64
# onset         744.506
# duration       21.000
# trial_type    156.000
# Name: 33, dtype: float64
# Onset (samples): 744.506, Music file: lvla6.wav, emotion: onset         744.506
# duration       21.000
# trial_type    156.000
# Name: 33, dtype: float64
# onset         789.051
# duration       21.000
# trial_type    198.000
# Name: 35, dtype: float64
# Onset (samples): 789.051, Music file: nvna11.wav, emotion: onset         789.051
# duration       21.000
# trial_type    198.000
# Name: 35, dtype: float64
# onset           9.643
# duration       21.000
# trial_type    145.000
# Name: 1, dtype: float64
# Onset (samples): 9.643, Music file: lvha7.wav, emotion: onset           9.643
# duration       21.000
# trial_type    145.000
# Name: 1, dtype: float64
# onset          54.687
# duration       21.000
# trial_type    149.000
# Name: 3, dtype: float64
# Onset (samples): 54.687, Music file: lvla10.wav, emotion: onset          54.687
# duration       21.000
# trial_type    149.000
# Name: 3, dtype: float64
# onset          98.958
# duration       21.000
# trial_type    127.000
# Name: 5, dtype: float64
# Onset (samples): 98.958, Music file: hvna12.wav, emotion: onset          98.958
# duration       21.000
# trial_type    127.000
# Name: 5, dtype: float64
# onset         143.632
# duration       21.000
# trial_type    178.000
# Name: 7, dtype: float64
# Onset (samples): 143.632, Music file: nvha4.wav, emotion: onset         143.632
# duration       21.000
# trial_type    178.000
# Name: 7, dtype: float64
# onset         188.6
# duration       21.0
# trial_type    168.0
# Name: 9, dtype: float64
# Onset (samples): 188.6, Music file: lvna6.wav, emotion: onset         188.6
# duration       21.0
# trial_type    168.0
# Name: 9, dtype: float64
# onset         233.065
# duration       21.000
# trial_type    106.000
# Name: 11, dtype: float64
# Onset (samples): 233.065, Music file: hvha4.wav, emotion: onset         233.065
# duration       21.000
# trial_type    106.000
# Name: 11, dtype: float64
# onset         276.922
# duration       21.000
# trial_type    190.000
# Name: 13, dtype: float64
# Onset (samples): 276.922, Music file: nvla4.wav, emotion: onset         276.922
# duration       21.000
# trial_type    190.000
# Name: 13, dtype: float64
# onset         321.686
# duration       21.000
# trial_type    101.000
# Name: 15, dtype: float64
# Onset (samples): 321.686, Music file: hvha10.wav, emotion: onset         321.686
# duration       21.000
# trial_type    101.000
# Name: 15, dtype: float64
# onset         366.287
# duration       21.000
# trial_type    161.000
# Name: 17, dtype: float64
# Onset (samples): 366.287, Music file: lvna10.wav, emotion: onset         366.287
# duration       21.000
# trial_type    161.000
# Name: 17, dtype: float64
# onset         411.14
# duration       21.00
# trial_type    121.00
# Name: 19, dtype: float64
# Onset (samples): 411.14, Music file: hvla7.wav, emotion: onset         411.14
# duration       21.00
# trial_type    121.00
# Name: 19, dtype: float64
# onset         458.219
# duration       21.000
# trial_type    174.000
# Name: 21, dtype: float64
# Onset (samples): 458.219, Music file: nvha11.wav, emotion: onset         458.219
# duration       21.000
# trial_type    174.000
# Name: 21, dtype: float64
# onset         502.724
# duration       21.000
# trial_type    138.000
# Name: 23, dtype: float64
# Onset (samples): 502.724, Music file: lvha11.wav, emotion: onset         502.724
# duration       21.000
# trial_type    138.000
# Name: 23, dtype: float64
# onset         549.855
# duration       21.000
# trial_type    137.000
# Name: 25, dtype: float64
# Onset (samples): 549.855, Music file: lvha10.wav, emotion: onset         549.855
# duration       21.000
# trial_type    137.000
# Name: 25, dtype: float64
# onset         594.14
# duration       21.00
# trial_type    204.00
# Name: 27, dtype: float64
# Onset (samples): 594.14, Music file: nvna6.wav, emotion: onset         594.14
# duration       21.00
# trial_type    204.00
# Name: 27, dtype: float64
# onset         638.334
# duration       21.000
# trial_type    158.000
# Name: 29, dtype: float64
# Onset (samples): 638.334, Music file: lvla8.wav, emotion: onset         638.334
# duration       21.000
# trial_type    158.000
# Name: 29, dtype: float64
# onset         682.78
# duration       21.00
# trial_type    113.00
# Name: 31, dtype: float64
# Onset (samples): 682.78, Music file: hvla10.wav, emotion: onset         682.78
# duration       21.00
# trial_type    113.00
# Name: 31, dtype: float64
# onset         727.575
# duration       21.000
# trial_type    166.000
# Name: 33, dtype: float64
# Onset (samples): 727.575, Music file: lvna4.wav, emotion: onset         727.575
# duration       21.000
# trial_type    166.000
# Name: 33, dtype: float64
# onset         773.765
# duration       21.000
# trial_type    141.000
# Name: 35, dtype: float64
# Onset (samples): 773.765, Music file: lvha3.wav, emotion: onset         773.765
# duration       21.000
# trial_type    141.000
# Name: 35, dtype: float64
# onset           9.932
# duration       21.000
# trial_type    166.000
# Name: 1, dtype: float64
# Onset (samples): 9.932, Music file: lvna4.wav, emotion: onset           9.932
# duration       21.000
# trial_type    166.000
# Name: 1, dtype: float64
# onset          72.619
# duration       21.000
# trial_type    163.000
# Name: 3, dtype: float64
# Onset (samples): 72.619, Music file: lvna12.wav, emotion: onset          72.619
# duration       21.000
# trial_type    163.000
# Name: 3, dtype: float64
# onset         135.041
# duration       21.000
# trial_type    117.000
# Name: 5, dtype: float64
# Onset (samples): 135.041, Music file: hvla3.wav, emotion: onset         135.041
# duration       21.000
# trial_type    117.000
# Name: 5, dtype: float64
# onset         184.071
# duration       21.000
# trial_type    176.000
# Name: 7, dtype: float64
# Onset (samples): 184.071, Music file: nvha2.wav, emotion: onset         184.071
# duration       21.000
# trial_type    176.000
# Name: 7, dtype: float64
# onset         236.164
# duration       21.000
# trial_type    143.000
# Name: 9, dtype: float64
# Onset (samples): 236.164, Music file: lvha5.wav, emotion: onset         236.164
# duration       21.000
# trial_type    143.000
# Name: 9, dtype: float64
# onset         291.163
# duration       21.000
# trial_type    175.000
# Name: 11, dtype: float64
# Onset (samples): 291.163, Music file: nvha12.wav, emotion: onset         291.163
# duration       21.000
# trial_type    175.000
# Name: 11, dtype: float64
# onset         351.598
# duration       21.000
# trial_type    204.000
# Name: 13, dtype: float64
# Onset (samples): 351.598, Music file: nvna6.wav, emotion: onset         351.598
# duration       21.000
# trial_type    204.000
# Name: 13, dtype: float64
# onset         409.924
# duration       21.000
# trial_type    128.000
# Name: 15, dtype: float64
# Onset (samples): 409.924, Music file: hvna2.wav, emotion: onset         409.924
# duration       21.000
# trial_type    128.000
# Name: 15, dtype: float64
# onset         461.681
# duration       21.000
# trial_type    113.000
# Name: 17, dtype: float64
# Onset (samples): 461.681, Music file: hvla10.wav, emotion: onset         461.681
# duration       21.000
# trial_type    113.000
# Name: 17, dtype: float64
# onset         510.999
# duration       21.000
# trial_type    190.000
# Name: 19, dtype: float64
# Onset (samples): 510.999, Music file: nvla4.wav, emotion: onset         510.999
# duration       21.000
# trial_type    190.000
# Name: 19, dtype: float64
# onset         561.279
# duration       21.000
# trial_type    202.000
# Name: 21, dtype: float64
# Onset (samples): 561.279, Music file: nvna4.wav, emotion: onset         561.279
# duration       21.000
# trial_type    202.000
# Name: 21, dtype: float64
# onset         623.246
# duration       21.000
# trial_type    169.000
# Name: 23, dtype: float64
# Onset (samples): 623.246, Music file: lvna7.wav, emotion: onset         623.246
# duration       21.000
# trial_type    169.000
# Name: 23, dtype: float64
# onset         682.409
# duration       21.000
# trial_type    170.000
# Name: 25, dtype: float64
# Onset (samples): 682.409, Music file: lvna8.wav, emotion: onset         682.409
# duration       21.000
# trial_type    170.000
# Name: 25, dtype: float64
# onset         738.621
# duration       21.000
# trial_type    119.000
# Name: 27, dtype: float64
# Onset (samples): 738.621, Music file: hvla5.wav, emotion: onset         738.621
# duration       21.000
# trial_type    119.000
# Name: 27, dtype: float64
# onset         795.034
# duration       21.000
# trial_type    157.000
# Name: 29, dtype: float64
# Onset (samples): 795.034, Music file: lvla7.wav, emotion: onset         795.034
# duration       21.000
# trial_type    157.000
# Name: 29, dtype: float64
# onset         849.836
# duration       21.000
# trial_type    168.000
# Name: 31, dtype: float64
# Onset (samples): 849.836, Music file: lvna6.wav, emotion: onset         849.836
# duration       21.000
# trial_type    168.000
# Name: 31, dtype: float64
# onset         901.635
# duration       21.000
# trial_type    186.000
# Name: 33, dtype: float64
# Onset (samples): 901.635, Music file: nvla11.wav, emotion: onset         901.635
# duration       21.000
# trial_type    186.000
# Name: 33, dtype: float64
# onset         950.775
# duration       21.000
# trial_type    187.000
# Name: 35, dtype: float64
# Onset (samples): 950.775, Music file: nvla12.wav, emotion: onset         950.775
# duration       21.000
# trial_type    187.000
# Name: 35, dtype: float64
# onset           9.598
# duration       21.000
# trial_type    177.000
# Name: 1, dtype: float64
# Onset (samples): 9.598, Music file: nvha3.wav, emotion: onset           9.598
# duration       21.000
# trial_type    177.000
# Name: 1, dtype: float64
# onset          72.55
# duration       21.00
# trial_type    126.00
# Name: 3, dtype: float64
# Onset (samples): 72.55, Music file: hvna11.wav, emotion: onset          72.55
# duration       21.00
# trial_type    126.00
# Name: 3, dtype: float64
# onset         124.869
# duration       21.000
# trial_type    197.000
# Name: 5, dtype: float64
# Onset (samples): 124.869, Music file: nvna10.wav, emotion: onset         124.869
# duration       21.000
# trial_type    197.000
# Name: 5, dtype: float64
# onset         171.7
# duration       21.0
# trial_type    200.0
# Name: 7, dtype: float64
# Onset (samples): 171.7, Music file: nvna2.wav, emotion: onset         171.7
# duration       21.0
# trial_type    200.0
# Name: 7, dtype: float64
# onset         239.931
# duration       21.000
# trial_type    206.000
# Name: 9, dtype: float64
# Onset (samples): 239.931, Music file: nvna8.wav, emotion: onset         239.931
# duration       21.000
# trial_type    206.000
# Name: 9, dtype: float64
# onset         285.959
# duration       21.000
# trial_type    120.000
# Name: 11, dtype: float64
# Onset (samples): 285.959, Music file: hvla6.wav, emotion: onset         285.959
# duration       21.000
# trial_type    120.000
# Name: 11, dtype: float64
# onset         336.001
# duration       21.000
# trial_type    133.000
# Name: 13, dtype: float64
# Onset (samples): 336.001, Music file: hvna7.wav, emotion: onset         336.001
# duration       21.000
# trial_type    133.000
# Name: 13, dtype: float64
# onset         389.908
# duration       21.000
# trial_type    155.000
# Name: 15, dtype: float64
# Onset (samples): 389.908, Music file: lvla5.wav, emotion: onset         389.908
# duration       21.000
# trial_type    155.000
# Name: 15, dtype: float64
# onset         442.943
# duration       21.000
# trial_type    150.000
# Name: 17, dtype: float64
# Onset (samples): 442.943, Music file: lvla11.wav, emotion: onset         442.943
# duration       21.000
# trial_type    150.000
# Name: 17, dtype: float64
# onset         511.448
# duration       21.000
# trial_type    110.000
# Name: 19, dtype: float64
# Onset (samples): 511.448, Music file: hvha8.wav, emotion: onset         511.448
# duration       21.000
# trial_type    110.000
# Name: 19, dtype: float64
# onset         561.487
# duration       21.000
# trial_type    188.000
# Name: 21, dtype: float64
# Onset (samples): 561.487, Music file: nvla2.wav, emotion: onset         561.487
# duration       21.000
# trial_type    188.000
# Name: 21, dtype: float64
# onset         615.591
# duration       21.000
# trial_type    193.000
# Name: 23, dtype: float64
# Onset (samples): 615.591, Music file: nvla7.wav, emotion: onset         615.591
# duration       21.000
# trial_type    193.000
# Name: 23, dtype: float64
# onset         662.854
# duration       21.000
# trial_type    114.000
# Name: 25, dtype: float64
# Onset (samples): 662.854, Music file: hvla11.wav, emotion: onset         662.854
# duration       21.000
# trial_type    114.000
# Name: 25, dtype: float64
# onset         708.84
# duration       21.00
# trial_type    141.00
# Name: 27, dtype: float64
# Onset (samples): 708.84, Music file: lvha3.wav, emotion: onset         708.84
# duration       21.00
# trial_type    141.00
# Name: 27, dtype: float64
# onset         761.286
# duration       21.000
# trial_type    101.000
# Name: 29, dtype: float64
# Onset (samples): 761.286, Music file: hvha10.wav, emotion: onset         761.286
# duration       21.000
# trial_type    101.000
# Name: 29, dtype: float64
# onset         829.198
# duration       21.000
# trial_type    132.000
# Name: 31, dtype: float64
# Onset (samples): 829.198, Music file: hvna6.wav, emotion: onset         829.198
# duration       21.000
# trial_type    132.000
# Name: 31, dtype: float64
# onset         880.571
# duration       21.000
# trial_type    182.000
# Name: 33, dtype: float64
# Onset (samples): 880.571, Music file: nvha8.wav, emotion: onset         880.571
# duration       21.000
# trial_type    182.000
# Name: 33, dtype: float64
# onset         927.622
# duration       21.000
# trial_type    122.000
# Name: 35, dtype: float64
# Onset (samples): 927.622, Music file: hvla8.wav, emotion: onset         927.622
# duration       21.000
# trial_type    122.000
# Name: 35, dtype: float64
# onset           9.274
# duration       21.000
# trial_type    205.000
# Name: 1, dtype: float64
# Onset (samples): 9.274, Music file: nvna7.wav, emotion: onset           9.274
# duration       21.000
# trial_type    205.000
# Name: 1, dtype: float64
# onset          57.172
# duration       21.000
# trial_type    181.000
# Name: 3, dtype: float64
# Onset (samples): 57.172, Music file: nvha7.wav, emotion: onset          57.172
# duration       21.000
# trial_type    181.000
# Name: 3, dtype: float64
# onset         108.175
# duration       21.000
# trial_type    162.000
# Name: 5, dtype: float64
# Onset (samples): 108.175, Music file: lvna11.wav, emotion: onset         108.175
# duration       21.000
# trial_type    162.000
# Name: 5, dtype: float64
# onset         163.586
# duration       21.000
# trial_type    192.000
# Name: 7, dtype: float64
# Onset (samples): 163.586, Music file: nvla6.wav, emotion: onset         163.586
# duration       21.000
# trial_type    192.000
# Name: 7, dtype: float64
# onset         214.362
# duration       21.000
# trial_type    144.000
# Name: 9, dtype: float64
# Onset (samples): 214.362, Music file: lvha6.wav, emotion: onset         214.362
# duration       21.000
# trial_type    144.000
# Name: 9, dtype: float64
# onset         263.112
# duration       21.000
# trial_type    105.000
# Name: 11, dtype: float64
# Onset (samples): 263.112, Music file: hvha3.wav, emotion: onset         263.112
# duration       21.000
# trial_type    105.000
# Name: 11, dtype: float64
# onset         322.994
# duration       21.000
# trial_type    106.000
# Name: 13, dtype: float64
# Onset (samples): 322.994, Music file: hvha4.wav, emotion: onset         322.994
# duration       21.000
# trial_type    106.000
# Name: 13, dtype: float64
# onset         373.027
# duration       21.000
# trial_type    108.000
# Name: 15, dtype: float64
# Onset (samples): 373.027, Music file: hvha6.wav, emotion: onset         373.027
# duration       21.000
# trial_type    108.000
# Name: 15, dtype: float64
# onset         436.314
# duration       21.000
# trial_type    199.000
# Name: 17, dtype: float64
# Onset (samples): 436.314, Music file: nvna12.wav, emotion: onset         436.314
# duration       21.000
# trial_type    199.000
# Name: 17, dtype: float64
# onset         487.55
# duration       21.00
# trial_type    118.00
# Name: 19, dtype: float64
# Onset (samples): 487.55, Music file: hvla4.wav, emotion: onset         487.55
# duration       21.00
# trial_type    118.00
# Name: 19, dtype: float64
# onset         531.359
# duration       21.000
# trial_type    178.000
# Name: 21, dtype: float64
# Onset (samples): 531.359, Music file: nvha4.wav, emotion: onset         531.359
# duration       21.000
# trial_type    178.000
# Name: 21, dtype: float64
# onset         584.341
# duration       21.000
# trial_type    179.000
# Name: 23, dtype: float64
# Onset (samples): 584.341, Music file: nvha5.wav, emotion: onset         584.341
# duration       21.000
# trial_type    179.000
# Name: 23, dtype: float64
# onset         636.524
# duration       21.000
# trial_type    203.000
# Name: 25, dtype: float64
# Onset (samples): 636.524, Music file: nvna5.wav, emotion: onset         636.524
# duration       21.000
# trial_type    203.000
# Name: 25, dtype: float64
# onset         688.503
# duration       21.000
# trial_type    152.000
# Name: 27, dtype: float64
# Onset (samples): 688.503, Music file: lvla2.wav, emotion: onset         688.503
# duration       21.000
# trial_type    152.000
# Name: 27, dtype: float64
# onset         740.312
# duration       21.000
# trial_type    139.000
# Name: 29, dtype: float64
# Onset (samples): 740.312, Music file: lvha12.wav, emotion: onset         740.312
# duration       21.000
# trial_type    139.000
# Name: 29, dtype: float64
# onset         792.073
# duration       21.000
# trial_type    142.000
# Name: 31, dtype: float64
# Onset (samples): 792.073, Music file: lvha4.wav, emotion: onset         792.073
# duration       21.000
# trial_type    142.000
# Name: 31, dtype: float64
# onset         843.278
# duration       21.000
# trial_type    103.000
# Name: 33, dtype: float64
# Onset (samples): 843.278, Music file: hvha12.wav, emotion: onset         843.278
# duration       21.000
# trial_type    103.000
# Name: 33, dtype: float64
# onset         920.173
# duration       21.000
# trial_type    140.000
# Name: 35, dtype: float64
# Onset (samples): 920.173, Music file: lvha2.wav, emotion: onset         920.173
# duration       21.000
# trial_type    140.000
# Name: 35, dtype: float64
# onset           9.792
# duration       21.000
# trial_type    127.000
# Name: 1, dtype: float64
# Onset (samples): 9.792, Music file: hvna12.wav, emotion: onset           9.792
# duration       21.000
# trial_type    127.000
# Name: 1, dtype: float64
# onset          56.534
# duration       21.000
# trial_type    167.000
# Name: 3, dtype: float64
# Onset (samples): 56.534, Music file: lvna5.wav, emotion: onset          56.534
# duration       21.000
# trial_type    167.000
# Name: 3, dtype: float64
# onset         106.118
# duration       21.000
# trial_type    164.000
# Name: 5, dtype: float64
# Onset (samples): 106.118, Music file: lvna2.wav, emotion: onset         106.118
# duration       21.000
# trial_type    164.000
# Name: 5, dtype: float64
# onset         164.211
# duration       21.000
# trial_type    153.000
# Name: 7, dtype: float64
# Onset (samples): 164.211, Music file: lvla3.wav, emotion: onset         164.211
# duration       21.000
# trial_type    153.000
# Name: 7, dtype: float64
# onset         224.059
# duration       21.000
# trial_type    149.000
# Name: 9, dtype: float64
# Onset (samples): 224.059, Music file: lvla10.wav, emotion: onset         224.059
# duration       21.000
# trial_type    149.000
# Name: 9, dtype: float64
# onset         273.588
# duration       21.000
# trial_type    102.000
# Name: 11, dtype: float64
# Onset (samples): 273.588, Music file: hvha11.wav, emotion: onset         273.588
# duration       21.000
# trial_type    102.000
# Name: 11, dtype: float64
# onset         318.832
# duration       21.000
# trial_type    165.000
# Name: 13, dtype: float64
# Onset (samples): 318.832, Music file: lvna3.wav, emotion: onset         318.832
# duration       21.000
# trial_type    165.000
# Name: 13, dtype: float64
# onset         368.386
# duration       21.000
# trial_type    158.000
# Name: 15, dtype: float64
# Onset (samples): 368.386, Music file: lvla8.wav, emotion: onset         368.386
# duration       21.000
# trial_type    158.000
# Name: 15, dtype: float64
# onset         415.611
# duration       21.000
# trial_type    129.000
# Name: 17, dtype: float64
# Onset (samples): 415.611, Music file: hvna3.wav, emotion: onset         415.611
# duration       21.000
# trial_type    129.000
# Name: 17, dtype: float64
# onset         474.856
# duration       21.000
# trial_type    109.000
# Name: 19, dtype: float64
# Onset (samples): 474.856, Music file: hvha7.wav, emotion: onset         474.856
# duration       21.000
# trial_type    109.000
# Name: 19, dtype: float64
# onset         521.278
# duration       21.000
# trial_type    185.000
# Name: 21, dtype: float64
# Onset (samples): 521.278, Music file: nvla10.wav, emotion: onset         521.278
# duration       21.000
# trial_type    185.000
# Name: 21, dtype: float64
# onset         575.335
# duration       21.000
# trial_type    138.000
# Name: 23, dtype: float64
# Onset (samples): 575.335, Music file: lvha11.wav, emotion: onset         575.335
# duration       21.000
# trial_type    138.000
# Name: 23, dtype: float64
# onset         621.98
# duration       21.00
# trial_type    107.00
# Name: 25, dtype: float64
# Onset (samples): 621.98, Music file: hvha5.wav, emotion: onset         621.98
# duration       21.00
# trial_type    107.00
# Name: 25, dtype: float64
# onset         670.373
# duration       21.000
# trial_type    134.000
# Name: 27, dtype: float64
# Onset (samples): 670.373, Music file: hvna8.wav, emotion: onset         670.373
# duration       21.000
# trial_type    134.000
# Name: 27, dtype: float64
# onset         722.221
# duration       21.000
# trial_type    130.000
# Name: 29, dtype: float64
# Onset (samples): 722.221, Music file: hvna4.wav, emotion: onset         722.221
# duration       21.000
# trial_type    130.000
# Name: 29, dtype: float64
# onset         772.019
# duration       21.000
# trial_type    173.000
# Name: 31, dtype: float64
# Onset (samples): 772.019, Music file: nvha10.wav, emotion: onset         772.019
# duration       21.000
# trial_type    173.000
# Name: 31, dtype: float64
# onset         818.588
# duration       21.000
# trial_type    194.000
# Name: 33, dtype: float64
# Onset (samples): 818.588, Music file: nvla8.wav, emotion: onset         818.588
# duration       21.000
# trial_type    194.000
# Name: 33, dtype: float64
# onset         867.783
# duration       21.000
# trial_type    180.000
# Name: 35, dtype: float64
# Onset (samples): 867.783, Music file: nvha6.wav, emotion: onset         867.783
# duration       21.000
# trial_type    180.000
# Name: 35, dtype: float64
# onset           9.193
# duration       21.000
# trial_type    174.000
# Name: 1, dtype: float64
# Onset (samples): 9.193, Music file: nvha11.wav, emotion: onset           9.193
# duration       21.000
# trial_type    174.000
# Name: 1, dtype: float64
# onset          68.027
# duration       21.000
# trial_type    121.000
# Name: 3, dtype: float64
# Onset (samples): 68.027, Music file: hvla7.wav, emotion: onset          68.027
# duration       21.000
# trial_type    121.000
# Name: 3, dtype: float64
# onset         115.209
# duration       21.000
# trial_type    146.000
# Name: 5, dtype: float64
# Onset (samples): 115.209, Music file: lvha8.wav, emotion: onset         115.209
# duration       21.000
# trial_type    146.000
# Name: 5, dtype: float64
# onset         169.37
# duration       21.00
# trial_type    154.00
# Name: 7, dtype: float64
# Onset (samples): 169.37, Music file: lvla4.wav, emotion: onset         169.37
# duration       21.00
# trial_type    154.00
# Name: 7, dtype: float64
# onset         216.531
# duration       21.000
# trial_type    156.000
# Name: 9, dtype: float64
# Onset (samples): 216.531, Music file: lvla6.wav, emotion: onset         216.531
# duration       21.000
# trial_type    156.000
# Name: 9, dtype: float64
# onset         265.368
# duration       21.000
# trial_type    116.000
# Name: 11, dtype: float64
# Onset (samples): 265.368, Music file: hvla2.wav, emotion: onset         265.368
# duration       21.000
# trial_type    116.000
# Name: 11, dtype: float64
# onset         317.053
# duration       21.000
# trial_type    191.000
# Name: 13, dtype: float64
# Onset (samples): 317.053, Music file: nvla5.wav, emotion: onset         317.053
# duration       21.000
# trial_type    191.000
# Name: 13, dtype: float64
# onset         362.011
# duration       21.000
# trial_type    145.000
# Name: 15, dtype: float64
# Onset (samples): 362.011, Music file: lvha7.wav, emotion: onset         362.011
# duration       21.000
# trial_type    145.000
# Name: 15, dtype: float64
# onset         418.751
# duration       21.000
# trial_type    137.000
# Name: 17, dtype: float64
# Onset (samples): 418.751, Music file: lvha10.wav, emotion: onset         418.751
# duration       21.000
# trial_type    137.000
# Name: 17, dtype: float64
# onset         464.675
# duration       21.000
# trial_type    125.000
# Name: 19, dtype: float64
# Onset (samples): 464.675, Music file: hvna10.wav, emotion: onset         464.675
# duration       21.000
# trial_type    125.000
# Name: 19, dtype: float64
# onset         509.584
# duration       21.000
# trial_type    104.000
# Name: 21, dtype: float64
# Onset (samples): 509.584, Music file: hvha2.wav, emotion: onset         509.584
# duration       21.000
# trial_type    104.000
# Name: 21, dtype: float64
# onset         555.094
# duration       21.000
# trial_type    201.000
# Name: 23, dtype: float64
# Onset (samples): 555.094, Music file: nvna3.wav, emotion: onset         555.094
# duration       21.000
# trial_type    201.000
# Name: 23, dtype: float64
# onset         601.886
# duration       21.000
# trial_type    115.000
# Name: 25, dtype: float64
# Onset (samples): 601.886, Music file: hvla12.wav, emotion: onset         601.886
# duration       21.000
# trial_type    115.000
# Name: 25, dtype: float64
# onset         650.059
# duration       21.000
# trial_type    161.000
# Name: 27, dtype: float64
# Onset (samples): 650.059, Music file: lvna10.wav, emotion: onset         650.059
# duration       21.000
# trial_type    161.000
# Name: 27, dtype: float64
# onset         695.583
# duration       21.000
# trial_type    189.000
# Name: 29, dtype: float64
# Onset (samples): 695.583, Music file: nvla3.wav, emotion: onset         695.583
# duration       21.000
# trial_type    189.000
# Name: 29, dtype: float64
# onset         744.688
# duration       21.000
# trial_type    198.000
# Name: 31, dtype: float64
# Onset (samples): 744.688, Music file: nvna11.wav, emotion: onset         744.688
# duration       21.000
# trial_type    198.000
# Name: 31, dtype: float64
# onset         789.512
# duration       21.000
# trial_type    131.000
# Name: 33, dtype: float64
# Onset (samples): 789.512, Music file: hvna5.wav, emotion: onset         789.512
# duration       21.000
# trial_type    131.000
# Name: 33, dtype: float64
# onset         837.541
# duration       21.000
# trial_type    151.000
# Name: 35, dtype: float64
# Onset (samples): 837.541, Music file: lvla12.wav, emotion: onset         837.541
# duration       21.000
# trial_type    151.000
# Name: 35, dtype: float64
# onset           9.983
# duration       21.000
# trial_type    140.000
# Name: 1, dtype: float64
# Onset (samples): 9.983, Music file: lvha2.wav, emotion: onset           9.983
# duration       21.000
# trial_type    140.000
# Name: 1, dtype: float64
# onset          75.512
# duration       21.000
# trial_type    141.000
# Name: 3, dtype: float64
# Onset (samples): 75.512, Music file: lvha3.wav, emotion: onset          75.512
# duration       21.000
# trial_type    141.000
# Name: 3, dtype: float64
# onset         123.348
# duration       21.000
# trial_type    168.000
# Name: 5, dtype: float64
# Onset (samples): 123.348, Music file: lvna6.wav, emotion: onset         123.348
# duration       21.000
# trial_type    168.000
# Name: 5, dtype: float64
# onset         172.715
# duration       21.000
# trial_type    146.000
# Name: 7, dtype: float64
# Onset (samples): 172.715, Music file: lvha8.wav, emotion: onset         172.715
# duration       21.000
# trial_type    146.000
# Name: 7, dtype: float64
# onset         221.798
# duration       21.000
# trial_type    164.000
# Name: 9, dtype: float64
# Onset (samples): 221.798, Music file: lvna2.wav, emotion: onset         221.798
# duration       21.000
# trial_type    164.000
# Name: 9, dtype: float64
# onset         266.778
# duration       21.000
# trial_type    143.000
# Name: 11, dtype: float64
# Onset (samples): 266.778, Music file: lvha5.wav, emotion: onset         266.778
# duration       21.000
# trial_type    143.000
# Name: 11, dtype: float64
# onset         312.528
# duration       21.000
# trial_type    198.000
# Name: 13, dtype: float64
# Onset (samples): 312.528, Music file: nvna11.wav, emotion: onset         312.528
# duration       21.000
# trial_type    198.000
# Name: 13, dtype: float64
# onset         358.917
# duration       21.000
# trial_type    170.000
# Name: 15, dtype: float64
# Onset (samples): 358.917, Music file: lvna8.wav, emotion: onset         358.917
# duration       21.000
# trial_type    170.000
# Name: 15, dtype: float64
# onset         403.574
# duration       21.000
# trial_type    205.000
# Name: 17, dtype: float64
# Onset (samples): 403.574, Music file: nvna7.wav, emotion: onset         403.574
# duration       21.000
# trial_type    205.000
# Name: 17, dtype: float64
# onset         451.79
# duration       21.00
# trial_type    121.00
# Name: 19, dtype: float64
# Onset (samples): 451.79, Music file: hvla7.wav, emotion: onset         451.79
# duration       21.00
# trial_type    121.00
# Name: 19, dtype: float64
# onset         497.173
# duration       21.000
# trial_type    145.000
# Name: 21, dtype: float64
# Onset (samples): 497.173, Music file: lvha7.wav, emotion: onset         497.173
# duration       21.000
# trial_type    145.000
# Name: 21, dtype: float64
# onset         541.933
# duration       21.000
# trial_type    117.000
# Name: 23, dtype: float64
# Onset (samples): 541.933, Music file: hvla3.wav, emotion: onset         541.933
# duration       21.000
# trial_type    117.000
# Name: 23, dtype: float64
# onset         592.778
# duration       21.000
# trial_type    110.000
# Name: 25, dtype: float64
# Onset (samples): 592.778, Music file: hvha8.wav, emotion: onset         592.778
# duration       21.000
# trial_type    110.000
# Name: 25, dtype: float64
# onset         637.568
# duration       21.000
# trial_type    179.000
# Name: 27, dtype: float64
# Onset (samples): 637.568, Music file: nvha5.wav, emotion: onset         637.568
# duration       21.000
# trial_type    179.000
# Name: 27, dtype: float64
# onset         681.859
# duration       21.000
# trial_type    188.000
# Name: 29, dtype: float64
# Onset (samples): 681.859, Music file: nvla2.wav, emotion: onset         681.859
# duration       21.000
# trial_type    188.000
# Name: 29, dtype: float64
# onset         726.73
# duration       21.00
# trial_type    201.00
# Name: 31, dtype: float64
# Onset (samples): 726.73, Music file: nvna3.wav, emotion: onset         726.73
# duration       21.00
# trial_type    201.00
# Name: 31, dtype: float64
# onset         773.073
# duration       21.000
# trial_type    189.000
# Name: 33, dtype: float64
# Onset (samples): 773.073, Music file: nvla3.wav, emotion: onset         773.073
# duration       21.000
# trial_type    189.000
# Name: 33, dtype: float64
# onset         823.494
# duration       21.000
# trial_type    103.000
# Name: 35, dtype: float64
# Onset (samples): 823.494, Music file: hvha12.wav, emotion: onset         823.494
# duration       21.000
# trial_type    103.000
# Name: 35, dtype: float64
# onset           9.249
# duration       21.000
# trial_type    149.000
# Name: 1, dtype: float64
# Onset (samples): 9.249, Music file: lvla10.wav, emotion: onset           9.249
# duration       21.000
# trial_type    149.000
# Name: 1, dtype: float64
# onset          56.677
# duration       21.000
# trial_type    166.000
# Name: 3, dtype: float64
# Onset (samples): 56.677, Music file: lvna4.wav, emotion: onset          56.677
# duration       21.000
# trial_type    166.000
# Name: 3, dtype: float64
# onset         102.308
# duration       21.000
# trial_type    144.000
# Name: 5, dtype: float64
# Onset (samples): 102.308, Music file: lvha6.wav, emotion: onset         102.308
# duration       21.000
# trial_type    144.000
# Name: 5, dtype: float64
# ...
# trial_type    117.0
# Name: 11, dtype: float64
# Onset (samples): 253.8, Music file: hvla3.wav, emotion: onset         253.8
# duration       21.0
# trial_type    117.0
# Name: 11, dtype: float64
# onset         303.046
# duration       21.000
# trial_type    202.000
# Name: 13, dtype: float64
# Onset (samples): 303.046, Music file: nvna4.wav, emotion: onset         303.046
# duration       21.000
# trial_type    202.000
# Name: 13, dtype: float64
# onset         359.074
# duration       21.000
# trial_type    151.000
# Name: 15, dtype: float64
# Onset (samples): 359.074, Music file: lvla12.wav, emotion: onset         359.074
# duration       21.000
# trial_type    151.000
# Name: 15, dtype: float64
# onset         405.159
# duration       21.000
# trial_type    169.000
# Name: 17, dtype: float64
# Onset (samples): 405.159, Music file: lvna7.wav, emotion: onset         405.159
# duration       21.000
# trial_type    169.000
# Name: 17, dtype: float64
# onset         455.158
# duration       21.000
# trial_type    127.000
# Name: 19, dtype: float64
# Onset (samples): 455.158, Music file: hvna12.wav, emotion: onset         455.158
# duration       21.000
# trial_type    127.000
# Name: 19, dtype: float64
# onset         546.789
# duration       21.000
# trial_type    197.000
# Name: 21, dtype: float64
# Onset (samples): 546.789, Music file: nvna10.wav, emotion: onset         546.789
# duration       21.000
# trial_type    197.000
# Name: 21, dtype: float64
# onset         615.358
# duration       21.000
# trial_type    167.000
# Name: 23, dtype: float64
# Onset (samples): 615.358, Music file: lvna5.wav, emotion: onset         615.358
# duration       21.000
# trial_type    167.000
# Name: 23, dtype: float64
# onset         661.473
# duration       21.000
# trial_type    170.000
# Name: 25, dtype: float64
# Onset (samples): 661.473, Music file: lvna8.wav, emotion: onset         661.473
# duration       21.000
# trial_type    170.000
# Name: 25, dtype: float64
# onset         727.372
# duration       21.000
# trial_type    187.000
# Name: 27, dtype: float64
# Onset (samples): 727.372, Music file: nvla12.wav, emotion: onset         727.372
# duration       21.000
# trial_type    187.000
# Name: 27, dtype: float64
# onset         774.367
# duration       21.000
# trial_type    145.000
# Name: 29, dtype: float64
# Onset (samples): 774.367, Music file: lvha7.wav, emotion: onset         774.367
# duration       21.000
# trial_type    145.000
# Name: 29, dtype: float64
# onset         821.881
# duration       21.000
# trial_type    119.000
# Name: 31, dtype: float64
# Onset (samples): 821.881, Music file: hvla5.wav, emotion: onset         821.881
# duration       21.000
# trial_type    119.000
# Name: 31, dtype: float64
# onset         870.821
# duration       21.000
# trial_type    152.000
# Name: 33, dtype: float64
# Onset (samples): 870.821, Music file: lvla2.wav, emotion: onset         870.821
# duration       21.000
# trial_type    152.000
# Name: 33, dtype: float64
# onset         922.65
# duration       21.00
# trial_type    115.00
# Name: 35, dtype: float64
# Onset (samples): 922.65, Music file: hvla12.wav, emotion: onset         922.65
# duration       21.00
# trial_type    115.00
# Name: 35, dtype: float64
# onset           9.876
# duration       21.000
# trial_type    110.000
# Name: 1, dtype: float64
# Onset (samples): 9.876, Music file: hvha8.wav, emotion: onset           9.876
# duration       21.000
# trial_type    110.000
# Name: 1, dtype: float64
# onset          58.645
# duration       21.000
# trial_type    179.000
# Name: 3, dtype: float64
# Onset (samples): 58.645, Music file: nvha5.wav, emotion: onset          58.645
# duration       21.000
# trial_type    179.000
# Name: 3, dtype: float64
# onset         107.081
# duration       21.000
# trial_type    163.000
# Name: 5, dtype: float64
# Onset (samples): 107.081, Music file: lvna12.wav, emotion: onset         107.081
# duration       21.000
# trial_type    163.000
# Name: 5, dtype: float64
# onset         154.279
# duration       21.000
# trial_type    198.000
# Name: 7, dtype: float64
# Onset (samples): 154.279, Music file: nvna11.wav, emotion: onset         154.279
# duration       21.000
# trial_type    198.000
# Name: 7, dtype: float64
# onset         207.254
# duration       21.000
# trial_type    181.000
# Name: 9, dtype: float64
# Onset (samples): 207.254, Music file: nvha7.wav, emotion: onset         207.254
# duration       21.000
# trial_type    181.000
# Name: 9, dtype: float64
# onset         251.999
# duration       21.000
# trial_type    186.000
# Name: 11, dtype: float64
# Onset (samples): 251.999, Music file: nvla11.wav, emotion: onset         251.999
# duration       21.000
# trial_type    186.000
# Name: 11, dtype: float64
# onset         304.831
# duration       21.000
# trial_type    144.000
# Name: 13, dtype: float64
# Onset (samples): 304.831, Music file: lvha6.wav, emotion: onset         304.831
# duration       21.000
# trial_type    144.000
# Name: 13, dtype: float64
# onset         351.408
# duration       21.000
# trial_type    165.000
# Name: 15, dtype: float64
# Onset (samples): 351.408, Music file: lvna3.wav, emotion: onset         351.408
# duration       21.000
# trial_type    165.000
# Name: 15, dtype: float64
# onset         396.932
# duration       21.000
# trial_type    188.000
# Name: 17, dtype: float64
# Onset (samples): 396.932, Music file: nvla2.wav, emotion: onset         396.932
# duration       21.000
# trial_type    188.000
# Name: 17, dtype: float64
# onset         448.273
# duration       21.000
# trial_type    173.000
# Name: 19, dtype: float64
# Onset (samples): 448.273, Music file: nvha10.wav, emotion: onset         448.273
# duration       21.000
# trial_type    173.000
# Name: 19, dtype: float64
# onset         493.723
# duration       21.000
# trial_type    149.000
# Name: 21, dtype: float64
# Onset (samples): 493.723, Music file: lvla10.wav, emotion: onset         493.723
# duration       21.000
# trial_type    149.000
# Name: 21, dtype: float64
# onset         540.177
# duration       21.000
# trial_type    134.000
# Name: 23, dtype: float64
# Onset (samples): 540.177, Music file: hvna8.wav, emotion: onset         540.177
# duration       21.000
# trial_type    134.000
# Name: 23, dtype: float64
# onset         585.807
# duration       21.000
# trial_type    125.000
# Name: 25, dtype: float64
# Onset (samples): 585.807, Music file: hvna10.wav, emotion: onset         585.807
# duration       21.000
# trial_type    125.000
# Name: 25, dtype: float64
# onset         631.781
# duration       21.000
# trial_type    206.000
# Name: 27, dtype: float64
# Onset (samples): 631.781, Music file: nvna8.wav, emotion: onset         631.781
# duration       21.000
# trial_type    206.000
# Name: 27, dtype: float64
# onset         680.844
# duration       21.000
# trial_type    108.000
# Name: 29, dtype: float64
# Onset (samples): 680.844, Music file: hvha6.wav, emotion: onset         680.844
# duration       21.000
# trial_type    108.000
# Name: 29, dtype: float64
# onset         729.598
# duration       21.000
# trial_type    178.000
# Name: 31, dtype: float64
# Onset (samples): 729.598, Music file: nvha4.wav, emotion: onset         729.598
# duration       21.000
# trial_type    178.000
# Name: 31, dtype: float64
# onset         777.884
# duration       21.000
# trial_type    177.000
# Name: 33, dtype: float64
# Onset (samples): 777.884, Music file: nvha3.wav, emotion: onset         777.884
# duration       21.000
# trial_type    177.000
# Name: 33, dtype: float64
# onset         825.304
# duration       21.000
# trial_type    164.000
# Name: 35, dtype: float64
# Onset (samples): 825.304, Music file: lvna2.wav, emotion: onset         825.304
# duration       21.000
# trial_type    164.000
# Name: 35, dtype: float64
# onset           9.929
# duration       21.000
# trial_type    116.000
# Name: 1, dtype: float64
# Onset (samples): 9.929, Music file: hvla2.wav, emotion: onset           9.929
# duration       21.000
# trial_type    116.000
# Name: 1, dtype: float64
# onset          55.516
# duration       21.000
# trial_type    103.000
# Name: 3, dtype: float64
# Onset (samples): 55.516, Music file: hvha12.wav, emotion: onset          55.516
# duration       21.000
# trial_type    103.000
# Name: 3, dtype: float64
# onset         102.884
# duration       21.000
# trial_type    131.000
# Name: 5, dtype: float64
# Onset (samples): 102.884, Music file: hvna5.wav, emotion: onset         102.884
# duration       21.000
# trial_type    131.000
# Name: 5, dtype: float64
# onset         149.274
# duration       21.000
# trial_type    157.000
# Name: 7, dtype: float64
# Onset (samples): 149.274, Music file: lvla7.wav, emotion: onset         149.274
# duration       21.000
# trial_type    157.000
# Name: 7, dtype: float64
# onset         195.837
# duration       21.000
# trial_type    107.000
# Name: 9, dtype: float64
# Onset (samples): 195.837, Music file: hvha5.wav, emotion: onset         195.837
# duration       21.000
# trial_type    107.000
# Name: 9, dtype: float64
# onset         243.861
# duration       21.000
# trial_type    193.000
# Name: 11, dtype: float64
# Onset (samples): 243.861, Music file: nvla7.wav, emotion: onset         243.861
# duration       21.000
# trial_type    193.000
# Name: 11, dtype: float64
# onset         293.964
# duration       21.000
# trial_type    156.000
# Name: 13, dtype: float64
# Onset (samples): 293.964, Music file: lvla6.wav, emotion: onset         293.964
# duration       21.000
# trial_type    156.000
# Name: 13, dtype: float64
# onset         341.071
# duration       21.000
# trial_type    118.000
# Name: 15, dtype: float64
# Onset (samples): 341.071, Music file: hvla4.wav, emotion: onset         341.071
# duration       21.000
# trial_type    118.000
# Name: 15, dtype: float64
# onset         386.956
# duration       21.000
# trial_type    162.000
# Name: 17, dtype: float64
# Onset (samples): 386.956, Music file: lvna11.wav, emotion: onset         386.956
# duration       21.000
# trial_type    162.000
# Name: 17, dtype: float64
# onset         432.005
# duration       21.000
# trial_type    205.000
# Name: 19, dtype: float64
# Onset (samples): 432.005, Music file: nvna7.wav, emotion: onset         432.005
# duration       21.000
# trial_type    205.000
# Name: 19, dtype: float64
# onset         477.271
# duration       21.000
# trial_type    203.000
# Name: 21, dtype: float64
# Onset (samples): 477.271, Music file: nvna5.wav, emotion: onset         477.271
# duration       21.000
# trial_type    203.000
# Name: 21, dtype: float64
# onset         521.002
# duration       21.000
# trial_type    120.000
# Name: 23, dtype: float64
# Onset (samples): 521.002, Music file: hvla6.wav, emotion: onset         521.002
# duration       21.000
# trial_type    120.000
# Name: 23, dtype: float64
# onset         566.654
# duration       21.000
# trial_type    121.000
# Name: 25, dtype: float64
# Onset (samples): 566.654, Music file: hvla7.wav, emotion: onset         566.654
# duration       21.000
# trial_type    121.000
# Name: 25, dtype: float64
# onset         610.711
# duration       21.000
# trial_type    204.000
# Name: 27, dtype: float64
# Onset (samples): 610.711, Music file: nvna6.wav, emotion: onset         610.711
# duration       21.000
# trial_type    204.000
# Name: 27, dtype: float64
# onset         663.152
# duration       21.000
# trial_type    122.000
# Name: 29, dtype: float64
# Onset (samples): 663.152, Music file: hvla8.wav, emotion: onset         663.152
# duration       21.000
# trial_type    122.000
# Name: 29, dtype: float64
# onset         710.903
# duration       21.000
# trial_type    140.000
# Name: 31, dtype: float64
# Onset (samples): 710.903, Music file: lvha2.wav, emotion: onset         710.903
# duration       21.000
# trial_type    140.000
# Name: 31, dtype: float64
# onset         762.652
# duration       21.000
# trial_type    104.000
# Name: 33, dtype: float64
# Onset (samples): 762.652, Music file: hvha2.wav, emotion: onset         762.652
# duration       21.000
# trial_type    104.000
# Name: 33, dtype: float64
# onset         809.643
# duration       21.000
# trial_type    185.000
# Name: 35, dtype: float64
# Onset (samples): 809.643, Music file: nvla10.wav, emotion: onset         809.643
# duration       21.000
# trial_type    185.000
# Name: 35, dtype: float64
# onset           9.643
# duration       21.000
# trial_type    114.000
# Name: 1, dtype: float64
# Onset (samples): 9.643, Music file: hvla11.wav, emotion: onset           9.643
# duration       21.000
# trial_type    114.000
# Name: 1, dtype: float64
# onset          57.576
# duration       21.000
# trial_type    146.000
# Name: 3, dtype: float64
# Onset (samples): 57.576, Music file: lvha8.wav, emotion: onset          57.576
# duration       21.000
# trial_type    146.000
# Name: 3, dtype: float64
# onset         100.813
# duration       21.000
# trial_type    141.000
# Name: 5, dtype: float64
# Onset (samples): 100.813, Music file: lvha3.wav, emotion: onset         100.813
# duration       21.000
# trial_type    141.000
# Name: 5, dtype: float64
# onset         146.359
# duration       21.000
# trial_type    199.000
# Name: 7, dtype: float64
# Onset (samples): 146.359, Music file: nvna12.wav, emotion: onset         146.359
# duration       21.000
# trial_type    199.000
# Name: 7, dtype: float64
# onset         194.543
# duration       21.000
# trial_type    130.000
# Name: 9, dtype: float64
# Onset (samples): 194.543, Music file: hvna4.wav, emotion: onset         194.543
# duration       21.000
# trial_type    130.000
# Name: 9, dtype: float64
# onset         240.535
# duration       21.000
# trial_type    161.000
# Name: 11, dtype: float64
# Onset (samples): 240.535, Music file: lvna10.wav, emotion: onset         240.535
# duration       21.000
# trial_type    161.000
# Name: 11, dtype: float64
# onset         291.042
# duration       21.000
# trial_type    142.000
# Name: 13, dtype: float64
# Onset (samples): 291.042, Music file: lvha4.wav, emotion: onset         291.042
# duration       21.000
# trial_type    142.000
# Name: 13, dtype: float64
# onset         338.766
# duration       21.000
# trial_type    155.000
# Name: 15, dtype: float64
# Onset (samples): 338.766, Music file: lvla5.wav, emotion: onset         338.766
# duration       21.000
# trial_type    155.000
# Name: 15, dtype: float64
# onset         388.164
# duration       21.000
# trial_type    180.000
# Name: 17, dtype: float64
# Onset (samples): 388.164, Music file: nvha6.wav, emotion: onset         388.164
# duration       21.000
# trial_type    180.000
# Name: 17, dtype: float64
# onset         432.685
# duration       21.000
# trial_type    175.000
# Name: 19, dtype: float64
# Onset (samples): 432.685, Music file: nvha12.wav, emotion: onset         432.685
# duration       21.000
# trial_type    175.000
# Name: 19, dtype: float64
# onset         477.614
# duration       21.000
# trial_type    150.000
# Name: 21, dtype: float64
# Onset (samples): 477.614, Music file: lvla11.wav, emotion: onset         477.614
# duration       21.000
# trial_type    150.000
# Name: 21, dtype: float64
# onset         522.518
# duration       21.000
# trial_type    128.000
# Name: 23, dtype: float64
# Onset (samples): 522.518, Music file: hvna2.wav, emotion: onset         522.518
# duration       21.000
# trial_type    128.000
# Name: 23, dtype: float64
# onset         575.888
# duration       21.000
# trial_type    105.000
# Name: 25, dtype: float64
# Onset (samples): 575.888, Music file: hvha3.wav, emotion: onset         575.888
# duration       21.000
# trial_type    105.000
# Name: 25, dtype: float64
# onset         622.039
# duration       21.000
# trial_type    191.000
# Name: 27, dtype: float64
# Onset (samples): 622.039, Music file: nvla5.wav, emotion: onset         622.039
# duration       21.000
# trial_type    191.000
# Name: 27, dtype: float64
# onset         669.248
# duration       21.000
# trial_type    176.000
# Name: 29, dtype: float64
# Onset (samples): 669.248, Music file: nvha2.wav, emotion: onset         669.248
# duration       21.000
# trial_type    176.000
# Name: 29, dtype: float64
# onset         716.252
# duration       21.000
# trial_type    192.000
# Name: 31, dtype: float64
# Onset (samples): 716.252, Music file: nvla6.wav, emotion: onset         716.252
# duration       21.000
# trial_type    192.000
# Name: 31, dtype: float64
# onset         761.355
# duration       21.000
# trial_type    138.000
# Name: 33, dtype: float64
# Onset (samples): 761.355, Music file: lvha11.wav, emotion: onset         761.355
# duration       21.000
# trial_type    138.000
# Name: 33, dtype: float64
# onset         808.005
# duration       21.000
# trial_type    132.000
# Name: 35, dtype: float64
# Onset (samples): 808.005, Music file: hvna6.wav, emotion: onset         808.005
# duration       21.000
# trial_type    132.000
# Name: 35, dtype: float64

# %%
loader = create_bcmi_loader('./datasets/bcmi/bcmi-fmri')
loader.load_all_subjects()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 loader = create_bcmi_loader('./datasets/bcmi/bcmi-fmri')
#       2 loader.load_all_subjects()
#
# NameError: name 'create_bcmi_loader' is not defined

# %%
# Test the updated BCMIFMRILoader
from bcmi import create_bcmi_loader
import pandas as pd

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 120)

# Load the fMRI dataset
fmri_loader = create_bcmi_loader('./datasets/bcmi/bcmi-fmri')
fmri_loader.load_all_subjects(max_subjects=1)

# Access and display the processed trials for a generated music run
subject_id = fmri_loader.subjects[0]
gen_music_run = 'genMusic01'
classical_music_run = 'classicalMusic'

if subject_id in fmri_loader.data and gen_music_run in fmri_loader.data[subject_id]['no_session']:
    print(f"--- Processed Trials for {gen_music_run} ---")
    gen_trials = fmri_loader.data[subject_id]['no_session'][gen_music_run]['processed_events']['fmri_trials']
    display(pd.DataFrame(gen_trials))

if subject_id in fmri_loader.data and classical_music_run in fmri_loader.data[subject_id]['no_session']:
    print(f"\n--- Processed Trials for {classical_music_run} ---")
    classical_trials = fmri_loader.data[subject_id]['no_session'][classical_music_run]['processed_events']['fmri_trials']
    display(pd.DataFrame(classical_trials))
# Out:
# {'raw': <RawEDF | sub-01_task-genMusic01_eeg.edf, 47 x 742000 (742.0 s), ~41 KiB, data not loaded>,
#  'events':         onset  duration  trial_type
#  0       0.001     0.001           1
#  1       0.041     0.001          47
#  2       0.161     0.001          47
#  3       1.172     0.001         265
#  4       2.161     0.001          47
#  5       4.161     0.001          47
#  6       4.645     0.001         265
#  7       6.161     0.001          47
#  8       6.523     0.001         265
#  9       8.161     0.001          47
#  10      8.345     0.001         265
#  11     10.161     0.001          47
#  12     11.033     0.001         265
#  13     12.161     0.001          47
#  14     13.880     0.001         265
#  15     14.161     0.001          47
#  16     15.796     0.001         265
#  17     16.161     0.001          47
#  18     16.821     0.001         265
#  19     18.161     0.001          47
#  20     18.736     0.001         265
#  21     20.161     0.001          47
#  22     21.643     0.001         265
#  23     22.161     0.001          47
#  24     24.161     0.001          47
#  25     24.641     0.001         265
#  26     26.161     0.001          47
#  27     26.675     0.001         265
#  28     28.161     0.001          47
#  29     28.572     0.001        1283
#  30     28.647     0.001         265
#  31     28.647     0.001        1285
#  32     29.072     0.001       34053
#  33     29.649     0.001         265
#  34     30.161     0.001          47
#  35     30.682     0.001         265
#  36     32.161     0.001          47
#  37     32.672     0.001         265
#  38     33.765     0.001         265
#  39     34.161     0.001          47
#  40     34.837     0.001         265
#  41     35.841     0.001         265
#  42     36.161     0.001          47
#  43     36.949     0.001         265
#  44     38.161     0.001          47
#  45     39.046     0.001         265
#  46     40.105     0.001         265
#  47     40.161     0.001          47
#  48     41.214     0.001         265
#  49     42.161     0.001          47
#  50     42.255     0.001         265
#  51     43.326     0.001         265
#  52     44.161     0.001          47
#  53     44.398     0.001         265
#  54     45.470     0.001         265
#  55     46.161     0.001          47
#  56     47.574     0.001         265
#  57     48.161     0.001          47
#  58     48.660     0.001         265
#  59     50.161     0.001          47
#  60     52.161     0.001          47
#  61     54.161     0.001          47
#  62     56.005     0.001          10
#  63     56.114     0.001         265
#  64     56.161     0.001          47
#  65     57.162     0.001         265
#  66     58.005     0.001          10
#  67     58.161     0.001          47
#  68     58.281     0.001         265
#  69     59.374     0.001         265
#  70     60.005     0.001          10
#  71     60.161     0.001          47
#  72     60.384     0.001         265
#  73     61.463     0.001         265
#  74     62.005     0.001          10
#  75     62.161     0.001          47
#  76     62.588     0.001         265
#  77     63.631     0.001         265
#  78     64.005     0.001          10
#  79     64.161     0.001          47
#  80     66.161     0.001          47
#  81     66.966     0.001         265
#  82     68.009     0.001         265
#  83     68.161     0.001          47
#  84     69.122     0.001         265
#  85     70.161     0.001          47
#  86     70.223     0.001         265
#  87     71.259     0.001         265
#  88     72.161     0.001          47
#  89     72.299     0.001         265
#  90     73.410     0.001         265
#  91     74.161     0.001          47
#  92     74.488     0.001         265
#  93     75.525     0.001         265
#  94     76.161     0.001          47
#  95     76.612     0.001         265
#  96     77.702     0.001         265
#  97     78.161     0.001          47
#  98     78.721     0.001         265
#  99     79.788     0.001         265
#  100    80.161     0.001          47
#  101    80.881     0.001         265
#  102    81.940     0.001         265
#  103    82.161     0.001          47
#  104    83.953     0.001         265
#  105    84.161     0.001          47
#  106    85.021     0.001         265
#  107    86.052     0.001         265
#  108    86.161     0.001          47
#  109    87.059     0.001         265
#  110    88.143     0.001         265
#  111    88.161     0.001          47
#  112    89.191     0.001         265
#  113    90.161     0.001          47
#  114    90.229     0.001         265
#  115    92.112     0.001         265
#  116    92.161     0.001          47
#  117    93.126     0.001         265
#  118    94.161     0.001          47
#  119    94.195     0.001         265
#  120    96.161     0.001          47
#  121    96.224     0.001         265
#  122    97.328     0.001         265
#  123    98.161     0.001          47
#  124    98.380     0.001         265
#  125    99.444     0.001         265
#  126   100.161     0.001          47
#  127   100.559     0.001         265
#  128   101.661     0.001         265
#  129   102.161     0.001          47
#  130   102.696     0.001         265
#  131   103.791     0.001         265
#  132   104.161     0.001          47
#  133   104.881     0.001         265
#  134   105.918     0.001         265
#  135   106.161     0.001          47
#  136   106.999     0.001         265
#  137   108.123     0.001         265
#  138   108.161     0.001          47
#  139   109.220     0.001         265
#  140   110.161     0.001          47
#  141   110.251     0.001         265
#  142   111.375     0.001         265
#  143   112.161     0.001          47
#  144   112.493     0.001         265
#  145   113.559     0.001         265
#  146   114.161     0.001          47
#  147   114.647     0.001         265
#  148   115.755     0.001         265
#  149   116.161     0.001          47
#  150   116.814     0.001         265
#  151   117.820     0.001         265
#  152   118.161     0.001          47
#  153   119.983     0.001         265
#  154   120.161     0.001          47
#  155   121.009     0.001         265
#  156   122.042     0.001         265
#  157   122.161     0.001          47
#  158   123.148     0.001         265
#  159   124.161     0.001          47
#  160   124.231     0.001         265
#  161   125.255     0.001         265
#  162   126.161     0.001          47
#  163   126.298     0.001         265
#  164   127.327     0.001         265
#  165   128.161     0.001          47
#  166   129.238     0.001         265
#  167   130.161     0.001          47
#  168   130.288     0.001         265
#  169   131.330     0.001         265
#  170   132.161     0.001          47
#  171   133.303     0.001         265
#  172   134.161     0.001          47
#  173   134.360     0.001         265
#  174   135.391     0.001         265
#  175   136.161     0.001          47
#  176   137.429     0.001         265
#  177   138.161     0.001          47
#  178   138.496     0.001         265
#  179   139.533     0.001         265
#  180   140.161     0.001          47
#  181   141.555     0.001         265
#  182   142.161     0.001          47
#  183   142.632     0.001         265
#  184   143.665     0.001         265
#  185   144.161     0.001          47
#  186   144.687     0.001         265
#  187   145.742     0.001         265
#  188   146.161     0.001          47
#  189   146.799     0.001         265
#  190   148.161     0.001          47
#  191   148.868     0.001         265
#  192   150.003     0.001         265
#  193   150.161     0.001          47
#  194   151.064     0.001         265
#  195   152.128     0.001         265
#  196   152.161     0.001          47
#  197   153.240     0.001         265
#  198   154.161     0.001          47
#  199   154.336     0.001         265
#  200   155.388     0.001         265
#  201   156.161     0.001          47
#  202   156.462     0.001         265
#  203   157.573     0.001         265
#  204   158.161     0.001          47
#  205   158.627     0.001         265
#  206   159.644     0.001         265
#  207   160.161     0.001          47
#  208   160.728     0.001         265
#  209   162.161     0.001          47
#  210   162.755     0.001         265
#  211   163.810     0.001         265
#  212   164.161     0.001          47
#  213   164.891     0.001         265
#  214   165.934     0.001         265
#  215   166.161     0.001          47
#  216   166.937     0.001         265
#  217   168.002     0.001         265
#  218   168.161     0.001          47
#  219   169.065     0.001         265
#  220   170.161     0.001          47
#  221   171.151     0.001         265
#  222   172.161     0.001          47
#  223   172.264     0.001         265
#  224   173.334     0.001         265
#  225   174.161     0.001          47
#  226   175.368     0.001         265
#  227   176.161     0.001          47
#  228   176.459     0.001         265
#  229   177.490     0.001         265
#  230   178.161     0.001          47
#  231   178.548     0.001         265
#  232   180.161     0.001          47
#  233   180.702     0.001         265
#  234   182.161     0.001          47
#  235   182.651     0.001         265
#  236   184.161     0.001          47
#  237   186.161     0.001          47
#  238   188.161     0.001          47
#  239   190.005     0.001          10
#  240   190.161     0.001          47
#  241   190.726     0.001         265
#  242   191.151     0.001         768
#  243   191.158     0.001         768
#  244   191.744     0.001         265
#  245   192.005     0.001          10
#  246   192.161     0.001          47
#  247   193.727     0.001         265
#  248   194.005     0.001          10
#  249   194.161     0.001          47
#  250   194.764     0.001         265
#  251   195.793     0.001         265
#  252   196.005     0.001          10
#  253   196.161     0.001          47
#  254   196.857     0.001         265
#  255   197.907     0.001         265
#  256   198.005     0.001          10
#  257   198.161     0.001          47
#  258   198.926     0.001         265
#  259   199.992     0.001         265
#  260   200.005     0.001          10
#  261   200.161     0.001          47
#  262   201.062     0.001         265
#  263   202.005     0.001          10
#  264   202.064     0.001         265
#  265   202.161     0.001          47
#  266   203.134     0.001         265
#  267   204.005     0.001          10
#  268   204.161     0.001          47
#  269   204.173     0.001         265
#  270   205.175     0.001         265
#  271   206.005     0.001          10
#  272   206.161     0.001          47
#  273   206.205     0.001         265
#  274   207.286     0.001         265
#  275   208.005     0.001          10
#  276   208.161     0.001          47
#  277   208.320     0.001         265
#  278   209.330     0.001         265
#  279   210.005     0.001          10
#  280   210.161     0.001          47
#  281   210.421     0.001         265
#  282   211.505     0.001         265
#  283   212.005     0.001          10
#  284   212.161     0.001          47
#  285   212.525     0.001         265
#  286   213.567     0.001         265
#  287   214.005     0.001          10
#  288   214.161     0.001          47
#  289   214.649     0.001         265
#  290   216.005     0.001          10
#  291   216.161     0.001          47
#  292   216.692     0.001         265
#  293   217.726     0.001         265
#  294   218.005     0.001          10
#  295   218.161     0.001          47
#  296   218.807     0.001         265
#  297   219.853     0.001         265
#  298   220.005     0.001          10
#  299   220.161     0.001          47
#  300   220.873     0.001         265
#  301   221.949     0.001         265
#  302   222.005     0.001          10
#  303   222.161     0.001          47
#  304   223.979     0.001         265
#  305   224.005     0.001          10
#  306   224.161     0.001          47
#  307   225.068     0.001         265
#  308   226.005     0.001          10
#  309   226.161     0.001          47
#  310   226.168     0.001         265
#  311   227.206     0.001         265
#  312   228.005     0.001          10
#  313   228.161     0.001          47
#  314   228.272     0.001         265
#  315   229.346     0.001         265
#  316   230.005     0.001          10
#  317   230.161     0.001          47
#  318   230.400     0.001         265
#  319   231.403     0.001         265
#  320   232.005     0.001          10
#  321   232.161     0.001          47
#  322   232.492     0.001         265
#  323   233.593     0.001         265
#  324   234.005     0.001          10
#  325   234.161     0.001          47
#  326   234.648     0.001         265
#  327   235.696     0.001         265
#  328   236.005     0.001          10
#  329   236.161     0.001          47
#  330   236.809     0.001         265
#  331   237.904     0.001         265
#  332   238.005     0.001          10
#  333   238.056     0.001         768
#  334   238.060     0.001         768
#  335   238.161     0.001          47
#  336   239.472     0.001         265
#  337   240.005     0.001          10
#  338   240.161     0.001          47
#  339   241.953     0.001         265
#  340   242.005     0.001          10
#  341   242.161     0.001          47
#  342   242.994     0.001         265
#  343   244.005     0.001          10
#  344   244.050     0.001         265
#  345   244.161     0.001          47
#  346   246.005     0.001          10
#  347   246.089     0.001         265
#  348   246.161     0.001          47
#  349   248.005     0.001          10
#  350   248.086     0.001         265
#  351   248.161     0.001          47
#  352   249.098     0.001         265
#  353   250.005     0.001          10
#  354   250.161     0.001          47
#  355   251.081     0.001         265
#  356   252.005     0.001          10
#  357   252.161     0.001          47
#  358   254.005     0.001          10
#  359   254.083     0.001         265
#  360   254.161     0.001          47
#  361   255.128     0.001         265
#  362   256.005     0.001          10
#  363   256.161     0.001          47
#  364   256.186     0.001         265
#  365   258.005     0.001          10
#  366   258.161     0.001          47
#  367   258.171     0.001         265
#  368   260.005     0.001          10
#  369   260.161     0.001          47
#  370   260.202     0.001         265
#  371   261.227     0.001         265
#  372   262.005     0.001          10
#  373   262.161     0.001          47
#  374   262.256     0.001         265
#  375   264.005     0.001          10
#  376   264.161     0.001          47
#  377   264.216     0.001         265
#  378   266.005     0.001          10
#  379   266.161     0.001          47
#  380   267.062     0.001         265
#  381   268.005     0.001          10
#  382   268.161     0.001          47
#  383   269.088     0.001         265
#  384   270.005     0.001          10
#  385   270.093     0.001         265
#  386   270.161     0.001          47
#  387   271.154     0.001         265
#  388   272.005     0.001          10
#  389   272.161     0.001          47
#  390   273.158     0.001         265
#  391   274.005     0.001          10
#  392   274.161     0.001          47
#  393   274.220     0.001         265
#  394   276.005     0.001          10
#  395   276.161     0.001          47
#  396   276.215     0.001         265
#  397   277.270     0.001         265
#  398   278.005     0.001          10
#  399   278.161     0.001          47
#  400   278.299     0.001         265
#  401   280.005     0.001          10
#  402   280.161     0.001          47
#  403   280.245     0.001         265
#  404   282.005     0.001          10
#  405   282.161     0.001          47
#  406   283.447     0.001         768
#  407   283.451     0.001         768
#  408   284.005     0.001          10
#  409   284.161     0.001          47
#  410   285.569     0.001         265
#  411   286.005     0.001          10
#  412   286.161     0.001          47
#  413   287.556     0.001         265
#  414   288.005     0.001          10
#  415   288.161     0.001          47
#  416   290.005     0.001          10
#  417   290.161     0.001          47
#  418   291.381     0.001         265
#  419   292.005     0.001          10
#  420   292.161     0.001          47
#  421   294.005     0.001          10
#  422   294.161     0.001          47
#  423   295.282     0.001         265
#  424   296.005     0.001          10
#  425   296.161     0.001          47
#  426   297.272     0.001         265
#  427   298.005     0.001          10
#  428   298.161     0.001          47
#  429   300.005     0.001          10
#  430   300.161     0.001          47
#  431   301.132     0.001         265
#  432   302.005     0.001          10
#  433   302.161     0.001          47
#  434   303.990     0.001         265
#  435   304.005     0.001          10
#  436   304.161     0.001          47
#  437   305.809     0.001         265
#  438   306.005     0.001          10
#  439   306.161     0.001          47
#  440   308.005     0.001          10
#  441   308.161     0.001          47
#  442   308.556     0.001         265
#  443   310.005     0.001          10
#  444   310.161     0.001          47
#  445   310.344     0.001         265
#  446   312.005     0.001          10
#  447   312.161     0.001          47
#  448   312.229     0.001         265
#  449   314.005     0.001          10
#  450   314.020     0.001         265
#  451   314.161     0.001          47
#  452   316.005     0.001          10
#  453   316.161     0.001          47
#  454   316.793     0.001         265
#  455   318.005     0.001          10
#  456   318.161     0.001          47
#  457   318.685     0.001         265
#  458   320.005     0.001          10
#  459   320.161     0.001          47
#  460   320.621     0.001         265
#  461   322.005     0.001          10
#  462   322.161     0.001          47
#  463   322.469     0.001         265
#  464   324.005     0.001          10
#  465   324.161     0.001          47
#  466   326.005     0.001          10
#  467   326.147     0.001         265
#  468   326.161     0.001          47
#  469   327.102     0.001         768
#  470   327.106     0.001         768
#  471   327.896     0.001         265
#  472   328.005     0.001          10
#  473   328.161     0.001          47
#  474   330.005     0.001          10
#  475   330.161     0.001          47
#  476   330.491     0.001         265
#  477   332.005     0.001          10
#  478   332.161     0.001          47
#  479   333.389     0.001         265
#  480   334.005     0.001          10
#  481   334.161     0.001          47
#  482   336.005     0.001          10
#  483   336.161     0.001          47
#  484   336.312     0.001         265
#  485   338.005     0.001          10
#  486   338.161     0.001          47
#  487   339.192     0.001         265
#  488   340.005     0.001          10
#  489   340.161     0.001          47
#  490   341.097     0.001         265
#  491   342.005     0.001          10
#  492   342.161     0.001          47
#  493   343.053     0.001         265
#  494   344.005     0.001          10
#  495   344.161     0.001          47
#  496   345.916     0.001         265
#  497   346.005     0.001          10
#  498   346.161     0.001          47
#  499   348.005     0.001          10
#  500   348.161     0.001          47
#  501   348.903     0.001         265
#  502   349.924     0.001         265
#  503   350.005     0.001          10
#  504   350.161     0.001          47
#  505   350.970     0.001         265
#  506   351.975     0.001         265
#  507   352.005     0.001          10
#  508   352.161     0.001          47
#  509   354.005     0.001          10
#  510   354.027     0.001         265
#  511   354.161     0.001          47
#  512   355.055     0.001         265
#  513   356.005     0.001          10
#  514   356.058     0.001         265
#  515   356.161     0.001          47
#  516   357.134     0.001         265
#  517   358.005     0.001          10
#  518   358.161     0.001          47
#  519   358.211     0.001         265
#  520   359.216     0.001         265
#  521   360.005     0.001          10
#  522   360.161     0.001          47
#  523   360.236     0.001         265
#  524   361.278     0.001         265
#  525   362.005     0.001          10
#  526   362.161     0.001          47
#  527   362.328     0.001         265
#  528   363.352     0.001         265
#  529   364.005     0.001          10
#  530   364.161     0.001          47
#  531   364.471     0.001         265
#  532   365.596     0.001         265
#  533   366.005     0.001          10
#  534   366.161     0.001          47
#  535   366.663     0.001         265
#  536   367.743     0.001         265
#  537   368.005     0.001          10
#  538   368.161     0.001          47
#  539   368.832     0.001         265
#  540   369.892     0.001         265
#  541   370.005     0.001          10
#  542   370.161     0.001          47
#  543   370.920     0.001         265
#  544   371.992     0.001         265
#  545   372.005     0.001          10
#  546   372.161     0.001          47
#  547   373.105     0.001         265
#  548   373.110     0.001         768
#  549   373.115     0.001         768
#  550   374.005     0.001          10
#  551   374.141     0.001         265
#  552   374.161     0.001          47
#  553   375.233     0.001         265
#  554   376.005     0.001          10
#  555   376.161     0.001          47
#  556   376.337     0.001         265
#  557   377.344     0.001         265
#  558   378.005     0.001          10
#  559   378.161     0.001          47
#  560   378.408     0.001         265
#  561   379.475     0.001         265
#  562   380.005     0.001          10
#  563   380.161     0.001          47
#  564   380.482     0.001         265
#  565   382.005     0.001          10
#  566   382.161     0.001          47
#  567   382.525     0.001         265
#  568   384.005     0.001          10
#  569   384.161     0.001          47
#  570   384.557     0.001         265
#  571   385.630     0.001         265
#  572   386.005     0.001          10
#  573   386.161     0.001          47
#  574   386.693     0.001         265
#  575   388.005     0.001          10
#  576   388.161     0.001          47
#  577   388.733     0.001         265
#  578   389.801     0.001         265
#  579   390.005     0.001          10
#  580   390.161     0.001          47
#  581   391.827     0.001         265
#  582   392.005     0.001          10
#  583   392.161     0.001          47
#  584   393.878     0.001         265
#  585   394.005     0.001          10
#  586   394.161     0.001          47
#  587   394.903     0.001         265
#  588   395.954     0.001         265
#  589   396.005     0.001          10
#  590   396.161     0.001          47
#  591   397.977     0.001         265
#  592   398.005     0.001          10
#  593   398.161     0.001          47
#  594   399.032     0.001         265
#  595   400.005     0.001          10
#  596   400.035     0.001         265
#  597   400.161     0.001          47
#  598   401.086     0.001         265
#  599   402.005     0.001          10
#  600   402.161     0.001          47
#  601   402.167     0.001         265
#  602   403.179     0.001         265
#  603   404.005     0.001          10
#  604   404.161     0.001          47
#  605   404.246     0.001         265
#  606   405.318     0.001         265
#  607   406.005     0.001          10
#  608   406.161     0.001          47
#  609   406.343     0.001         265
#  610   407.403     0.001         265
#  611   408.005     0.001          10
#  612   408.161     0.001          47
#  613   408.469     0.001         265
#  614   409.503     0.001         265
#  615   410.005     0.001          10
#  616   410.161     0.001          47
#  617   410.542     0.001         265
#  618   411.605     0.001         265
#  619   412.005     0.001          10
#  620   412.161     0.001          47
#  621   412.634     0.001         265
#  622   413.661     0.001         265
#  623   414.005     0.001          10
#  624   414.161     0.001          47
#  625   414.732     0.001         265
#  626   416.005     0.001          10
#  627   416.161     0.001          47
#  628   417.098     0.001         768
#  629   417.103     0.001         768
#  630   417.643     0.001         265
#  631   418.005     0.001          10
#  632   418.161     0.001          47
#  633   418.679     0.001         265
#  634   419.680     0.001         265
#  635   420.005     0.001          10
#  636   420.161     0.001          47
#  637   420.763     0.001         265
#  638   421.865     0.001         265
#  639   422.005     0.001          10
#  640   422.161     0.001          47
#  641   422.899     0.001         265
#  642   423.988     0.001         265
#  643   424.005     0.001          10
#  644   424.161     0.001          47
#  645   425.055     0.001         265
#  646   426.005     0.001          10
#  647   426.077     0.001         265
#  648   426.161     0.001          47
#  649   427.133     0.001         265
#  650   428.005     0.001          10
#  651   428.161     0.001          47
#  652   428.226     0.001         265
#  653   429.284     0.001         265
#  654   430.005     0.001          10
#  655   430.161     0.001          47
#  656   430.292     0.001         265
#  657   431.340     0.001         265
#  658   432.005     0.001          10
#  659   432.161     0.001          47
#  660   434.005     0.001          10
#  661   434.161     0.001          47
#  662   434.418     0.001         265
#  663   435.514     0.001         265
#  664   436.005     0.001          10
#  665   436.161     0.001          47
#  666   436.596     0.001         265
#  667   437.617     0.001         265
#  668   438.005     0.001          10
#  669   438.161     0.001          47
#  670   438.697     0.001         265
#  671   439.756     0.001         265
#  672   440.005     0.001          10
#  673   440.161     0.001          47
#  674   440.795     0.001         265
#  675   441.882     0.001         265
#  676   442.005     0.001          10
#  677   442.161     0.001          47
#  678   442.943     0.001         265
#  679   444.005     0.001          10
#  680   444.161     0.001          47
#  681   444.953     0.001         265
#  682   446.005     0.001          10
#  683   446.018     0.001         265
#  684   446.161     0.001          47
#  685   447.069     0.001         265
#  686   448.005     0.001          10
#  687   448.069     0.001         265
#  688   448.161     0.001          47
#  689   449.158     0.001         265
#  690   450.005     0.001          10
#  691   450.161     0.001          47
#  692   450.235     0.001         265
#  693   451.258     0.001         265
#  694   452.005     0.001          10
#  695   452.161     0.001          47
#  696   452.329     0.001         265
#  697   453.389     0.001         265
#  698   454.005     0.001          10
#  699   454.161     0.001          47
#  700   455.412     0.001         265
#  701   456.005     0.001          10
#  702   456.161     0.001          47
#  703   457.439     0.001         265
#  704   458.005     0.001          10
#  705   458.161     0.001          47
#  706   458.481     0.001         265
#  707   459.535     0.001         265
#  708   460.005     0.001          10
#  709   460.161     0.001          47
#  710   460.588     0.001         265
#  711   461.597     0.001         265
#  712   462.005     0.001          10
#  713   462.161     0.001          47
#  714   462.673     0.001         265
#  715   463.731     0.001         265
#  716   464.005     0.001          10
#  717   464.092     0.001         768
#  718   464.096     0.001         768
#  719   464.161     0.001          47
#  720   466.005     0.001          10
#  721   466.161     0.001          47
#  722   466.289     0.001         265
#  723   467.642     0.001         265
#  724   468.005     0.001          10
#  725   468.161     0.001          47
#  726   469.678     0.001         265
#  727   470.005     0.001          10
#  728   470.161     0.001          47
#  729   471.666     0.001         265
#  730   472.005     0.001          10
#  731   472.161     0.001          47
#  732   472.707     0.001         265
#  733   473.719     0.001         265
#  734   474.005     0.001          10
#  735   474.161     0.001          47
#  736   474.766     0.001         265
#  737   476.005     0.001          10
#  738   476.161     0.001          47
#  739   476.800     0.001         265
#  740   477.840     0.001         265
#  741   478.005     0.001          10
#  742   478.161     0.001          47
#  743   479.829     0.001         265
#  744   480.005     0.001          10
#  745   480.161     0.001          47
#  746   480.835     0.001         265
#  747   481.865     0.001         265
#  748   482.005     0.001          10
#  749   482.161     0.001          47
#  750   483.848     0.001         265
#  751   484.005     0.001          10
#  752   484.161     0.001          47
#  753   485.841     0.001         265
#  754   486.005     0.001          10
#  755   486.161     0.001          47
#  756   486.876     0.001         265
#  757   488.005     0.001          10
#  758   488.161     0.001          47
#  759   488.906     0.001         265
#  760   489.925     0.001         265
#  761   490.005     0.001          10
#  762   490.161     0.001          47
#  763   491.933     0.001         265
#  764   492.005     0.001          10
#  765   492.161     0.001          47
#  766   492.937     0.001         265
#  767   493.964     0.001         265
#  768   494.005     0.001          10
#  769   494.161     0.001          47
#  770   495.941     0.001         265
#  771   496.005     0.001          10
#  772   496.161     0.001          47
#  773   496.949     0.001         265
#  774   498.005     0.001          10
#  775   498.161     0.001          47
#  776   500.005     0.001          10
#  777   500.161     0.001          47
#  778   500.751     0.001         265
#  779   502.005     0.001          10
#  780   502.161     0.001          47
#  781   502.725     0.001         265
#  782   504.005     0.001          10
#  783   504.161     0.001          47
#  784   506.005     0.001          10
#  785   506.161     0.001          47
#  786   506.481     0.001         265
#  787   507.697     0.001         768
#  788   507.701     0.001         768
#  789   508.005     0.001          10
#  790   508.161     0.001          47
#  791   508.325     0.001         265
#  792   510.005     0.001          10
#  793   510.161     0.001          47
#  794   510.225     0.001         265
#  795   511.256     0.001         265
#  796   512.005     0.001          10
#  797   512.161     0.001          47
#  798   512.266     0.001         265
#  799   514.005     0.001          10
#  800   514.161     0.001          47
#  801   514.287     0.001         265
#  802   516.005     0.001          10
#  803   516.161     0.001          47
#  804   516.262     0.001         265
#  805   517.290     0.001         265
#  806   518.005     0.001          10
#  807   518.161     0.001          47
#  808   519.244     0.001         265
#  809   520.005     0.001          10
#  810   520.161     0.001          47
#  811   520.278     0.001         265
#  812   522.005     0.001          10
#  813   522.161     0.001          47
#  814   522.272     0.001         265
#  815   523.325     0.001         265
#  816   524.005     0.001          10
#  817   524.161     0.001          47
#  818   524.390     0.001         265
#  819   525.394     0.001         265
#  820   526.005     0.001          10
#  821   526.161     0.001          47
#  822   526.447     0.001         265
#  823   527.517     0.001         265
#  824   528.005     0.001          10
#  825   528.161     0.001          47
#  826   529.539     0.001         265
#  827   530.005     0.001          10
#  828   530.161     0.001          47
#  829   530.583     0.001         265
#  830   532.005     0.001          10
#  831   532.161     0.001          47
#  832   532.597     0.001         265
#  833   533.633     0.001         265
#  834   534.005     0.001          10
#  835   534.161     0.001          47
#  836   536.005     0.001          10
#  837   536.161     0.001          47
#  838   537.601     0.001         265
#  839   538.005     0.001          10
#  840   538.161     0.001          47
#  841   538.627     0.001         265
#  842   540.005     0.001          10
#  843   540.161     0.001          47
#  844   540.563     0.001         265
#  845   541.573     0.001         265
#  846   542.005     0.001          10
#  847   542.161     0.001          47
#  848   543.579     0.001         265
#  849   544.005     0.001          10
#  850   544.161     0.001          47
#  851   544.608     0.001         265
#  852   545.624     0.001         265
#  853   546.005     0.001          10
#  854   546.161     0.001          47
#  855   546.640     0.001         265
#  856   547.672     0.001         265
#  857   548.005     0.001          10
#  858   548.161     0.001          47
#  859   550.005     0.001          10
#  860   550.161     0.001          47
#  861   552.005     0.001          10
#  862   552.086     0.001         768
#  863   552.090     0.001         768
#  864   552.161     0.001          47
#  865   552.516     0.001         265
#  866   553.533     0.001         265
#  867   554.005     0.001          10
#  868   554.161     0.001          47
#  869   554.577     0.001         265
#  870   556.005     0.001          10
#  871   556.161     0.001          47
#  872   556.563     0.001         265
#  873   558.005     0.001          10
#  874   558.161     0.001          47
#  875   559.552     0.001         265
#  876   560.005     0.001          10
#  877   560.161     0.001          47
#  878   560.608     0.001         265
#  879   562.005     0.001          10
#  880   562.161     0.001          47
#  881   562.634     0.001         265
#  882   563.689     0.001         265
#  883   564.005     0.001          10
#  884   564.161     0.001          47
#  885   565.687     0.001         265
#  886   566.005     0.001          10
#  887   566.161     0.001          47
#  888   566.715     0.001         265
#  889   568.005     0.001          10
#  890   568.161     0.001          47
#  891   568.702     0.001         265
#  892   570.005     0.001          10
#  893   570.161     0.001          47
#  894   571.718     0.001         265
#  895   572.005     0.001          10
#  896   572.161     0.001          47
#  897   573.768     0.001         265
#  898   574.005     0.001          10
#  899   574.161     0.001          47
#  900   575.779     0.001         265
#  901   576.005     0.001          10
#  902   576.161     0.001          47
#  903   576.832     0.001         265
#  904   578.005     0.001          10
#  905   578.161     0.001          47
#  906   578.787     0.001         265
#  907   579.810     0.001         265
#  908   580.005     0.001          10
#  909   580.161     0.001          47
#  910   581.787     0.001         265
#  911   582.005     0.001          10
#  912   582.161     0.001          47
#  913   582.817     0.001         265
#  914   583.824     0.001         265
#  915   584.005     0.001          10
#  916   584.161     0.001          47
#  917   585.759     0.001         265
#  918   586.005     0.001          10
#  919   586.161     0.001          47
#  920   588.005     0.001          10
#  921   588.161     0.001          47
#  922   588.761     0.001         265
#  923   589.789     0.001         265
#  924   590.005     0.001          10
#  925   590.161     0.001          47
#  926   590.836     0.001         265
#  927   592.005     0.001          10
#  928   592.161     0.001          47
#  929   594.005     0.001          10
#  930   594.161     0.001          47
#  931   594.694     0.001         265
#  932   596.005     0.001          10
#  933   596.161     0.001          47
#  934   597.493     0.001         768
#  935   597.497     0.001         768
#  936   598.005     0.001          10
#  937   598.161     0.001          47
#  938   598.423     0.001         265
#  939   599.437     0.001         265
#  940   600.005     0.001          10
#  941   600.161     0.001          47
#  942   601.436     0.001         265
#  943   602.005     0.001          10
#  944   602.161     0.001          47
#  945   604.005     0.001          10
#  946   604.161     0.001          47
#  947   604.440     0.001         265
#  948   606.005     0.001          10
#  949   606.161     0.001          47
#  950   606.427     0.001         265
#  951   608.005     0.001          10
#  952   608.161     0.001          47
#  953   608.388     0.001         265
#  954   609.410     0.001         265
#  955   610.005     0.001          10
#  956   610.161     0.001          47
#  957   611.346     0.001         265
#  958   612.005     0.001          10
#  959   612.161     0.001          47
#  960   612.362     0.001         265
#  961   614.005     0.001          10
#  962   614.161     0.001          47
#  963   614.318     0.001         265
#  964   616.005     0.001          10
#  965   616.161     0.001          47
#  966   618.005     0.001          10
#  967   618.122     0.001         265
#  968   618.161     0.001          47
#  969   619.123     0.001         265
#  970   620.005     0.001          10
#  971   620.161     0.001          47
#  972   621.062     0.001         265
#  973   622.005     0.001          10
#  974   622.064     0.001         265
#  975   622.161     0.001          47
#  976   623.076     0.001         265
#  977   624.005     0.001          10
#  978   624.083     0.001         265
#  979   624.161     0.001          47
#  980   626.005     0.001          10
#  981   626.006     0.001         265
#  982   626.161     0.001          47
#  983   627.933     0.001         265
#  984   628.005     0.001          10
#  985   628.161     0.001          47
#  986   629.928     0.001         265
#  987   630.005     0.001          10
#  988   630.161     0.001          47
#  989   631.823     0.001         265
#  990   632.005     0.001          10
#  991   632.161     0.001          47
#  992   634.005     0.001          10
#  993   634.161     0.001          47
#  994   635.546     0.001         265
#  995   636.005     0.001          10
#  996   636.161     0.001          47
#  997   636.591     0.001         265
#  998   638.005     0.001          10
#  999   638.161     0.001          47
#  1000  639.568     0.001         265
#  1001  640.005     0.001          10
#  1002  640.161     0.001          47
#  1003  642.005     0.001          10
#  1004  642.161     0.001          47
#  1005  642.253     0.001         265
#  1006  643.735     0.001         768
#  1007  643.739     0.001         768
#  1008  644.005     0.001          10
#  1009  644.161     0.001          47
#  1010  645.327     0.001         265
#  1011  646.005     0.001          10
#  1012  646.161     0.001          47
#  1013  647.009     0.001         265
#  1014  648.005     0.001          10
#  1015  648.161     0.001          47
#  1016  648.721     0.001         265
#  1017  649.791     0.001         265
#  1018  650.005     0.001          10
#  1019  650.161     0.001          47
#  1020  650.850     0.001         265
#  1021  651.920     0.001         265
#  1022  652.005     0.001          10
#  1023  652.161     0.001          47
#  1024  652.967     0.001         265
#  1025  654.005     0.001          10
#  1026  654.017     0.001         265
#  1027  654.161     0.001          47
#  1028  655.064     0.001         265
#  1029  656.005     0.001          10
#  1030  656.161     0.001          47
#  1031  657.146     0.001         265
#  1032  658.005     0.001          10
#  1033  658.161     0.001         265
#  1034  658.161     0.001          47
#  1035  659.179     0.001         265
#  1036  660.005     0.001          10
#  1037  660.161     0.001          47
#  1038  661.178     0.001         265
#  1039  662.005     0.001          10
#  1040  662.161     0.001          47
#  1041  663.119     0.001         265
#  1042  664.005     0.001          10
#  1043  664.161     0.001          47
#  1044  665.991     0.001         265
#  1045  666.005     0.001          10
#  1046  666.161     0.001          47
#  1047  666.992     0.001         265
#  1048  668.005     0.001          10
#  1049  668.161     0.001          47
#  1050  668.909     0.001         265
#  1051  670.005     0.001          10
#  1052  670.161     0.001          47
#  1053  670.879     0.001         265
#  1054  672.005     0.001          10
#  1055  672.161     0.001          47
#  1056  672.743     0.001         265
#  1057  674.005     0.001          10
#  1058  674.161     0.001          47
#  1059  675.581     0.001         265
#  1060  676.005     0.001          10
#  1061  676.161     0.001          47
#  1062  678.005     0.001          10
#  1063  678.161     0.001          47
#  1064  678.540     0.001         265
#  1065  679.543     0.001         265
#  1066  680.005     0.001          10
#  1067  680.161     0.001          47
#  1068  681.566     0.001         265
#  1069  682.005     0.001          10
#  1070  682.161     0.001          47
#  1071  683.501     0.001         265
#  1072  684.005     0.001          10
#  1073  684.161     0.001          47
#  1074  686.005     0.001          10
#  1075  686.161     0.001          47
#  1076  686.297     0.001         265
#  1077  688.005     0.001          10
#  1078  688.161     0.001          47
#  1079  689.143     0.001         768
#  1080  689.147     0.001         768
#  1081  689.151     0.001         265
#  1082  690.005     0.001          10
#  1083  690.161     0.001          47
#  1084  691.164     0.001         265
#  1085  692.005     0.001          10
#  1086  692.161     0.001          47
#  1087  694.005     0.001          10
#  1088  694.161     0.001          47
#  1089  694.180     0.001         265
#  1090  696.005     0.001          10
#  1091  696.161     0.001          47
#  1092  696.197     0.001         265
#  1093  697.301     0.001         265
#  1094  698.005     0.001          10
#  1095  698.161     0.001          47
#  1096  699.988     0.001         265
#  1097  700.005     0.001          10
#  1098  700.161     0.001          47
#  1099  701.819     0.001         265
#  1100  702.005     0.001          10
#  1101  702.161     0.001          47
#  1102  703.645     0.001         265
#  1103  704.005     0.001          10
#  1104  704.161     0.001          47
#  1105  706.005     0.001          10
#  1106  706.161     0.001          47
#  1107  706.471     0.001         265
#  1108  707.471     0.001         265
#  1109  708.005     0.001          10
#  1110  708.161     0.001          47
#  1111  709.451     0.001         265
#  1112  710.005     0.001          10
#  1113  710.161     0.001          47
#  1114  711.438     0.001         265
#  1115  712.005     0.001          10
#  1116  712.161     0.001          47
#  1117  712.459     0.001         265
#  1118  714.005     0.001          10
#  1119  714.161     0.001          47
#  1120  714.393     0.001         265
#  1121  716.005     0.001          10
#  1122  716.161     0.001          47
#  1123  716.351     0.001         265
#  1124  718.005     0.001          10
#  1125  718.161     0.001          47
#  1126  718.349     0.001         265
#  1127  719.377     0.001         265
#  1128  720.005     0.001          10
#  1129  720.161     0.001          47
#  1130  721.410     0.001         265
#  1131  722.005     0.001          10
#  1132  722.161     0.001          47
#  1133  722.461     0.001         265
#  1134  723.468     0.001         265
#  1135  724.005     0.001          10
#  1136  724.161     0.001          47
#  1137  724.504     0.001         265
#  1138  725.540     0.001         265
#  1139  726.005     0.001          10
#  1140  726.161     0.001          47
#  1141  727.489     0.001         265
#  1142  728.005     0.001          10
#  1143  728.161     0.001          47
#  1144  729.256     0.001         265
#  1145  730.005     0.001          10
#  1146  730.161     0.001          47
#  1147  730.297     0.001         265
#  1148  732.005     0.001          10
#  1149  732.161     0.001          47
#  1150  732.309     0.001         265
#  1151  733.362     0.001         265
#  1152  734.005     0.001          10
#  1153  734.161     0.001          47
#  1154  734.409     0.001         265
#  1155  736.005     0.001          10
#  1156  736.161     0.001          47
#  1157  738.161     0.001          47
#  1158  738.531     0.001         265
#  1159  739.554     0.001         265
#  1160  740.161     0.001          47
#  1161  740.579     0.001         265,
#  'processed_events': {'emotion_events':    onset  duration  trial_type emotion_description valence arousal
#   0  0.001     0.001           1       Excited/Happy    High    High,
#   'marker_events':         onset  duration  trial_type
#   3       1.172     0.001         265
#   6       4.645     0.001         265
#   8       6.523     0.001         265
#   10      8.345     0.001         265
#   12     11.033     0.001         265
#   14     13.880     0.001         265
#   16     15.796     0.001         265
#   18     16.821     0.001         265
#   20     18.736     0.001         265
#   22     21.643     0.001         265
#   25     24.641     0.001         265
#   27     26.675     0.001         265
#   29     28.572     0.001        1283
#   30     28.647     0.001         265
#   31     28.647     0.001        1285
#   32     29.072     0.001       34053
#   33     29.649     0.001         265
#   35     30.682     0.001         265
#   37     32.672     0.001         265
#   38     33.765     0.001         265
#   40     34.837     0.001         265
#   41     35.841     0.001         265
#   43     36.949     0.001         265
#   45     39.046     0.001         265
#   46     40.105     0.001         265
#   48     41.214     0.001         265
#   50     42.255     0.001         265
#   51     43.326     0.001         265
#   53     44.398     0.001         265
#   54     45.470     0.001         265
#   56     47.574     0.001         265
#   58     48.660     0.001         265
#   63     56.114     0.001         265
#   65     57.162     0.001         265
#   68     58.281     0.001         265
#   69     59.374     0.001         265
#   72     60.384     0.001         265
#   73     61.463     0.001         265
#   76     62.588     0.001         265
#   77     63.631     0.001         265
#   81     66.966     0.001         265
#   82     68.009     0.001         265
#   84     69.122     0.001         265
#   86     70.223     0.001         265
#   87     71.259     0.001         265
#   89     72.299     0.001         265
#   90     73.410     0.001         265
#   92     74.488     0.001         265
#   93     75.525     0.001         265
#   95     76.612     0.001         265
#   96     77.702     0.001         265
#   98     78.721     0.001         265
#   99     79.788     0.001         265
#   101    80.881     0.001         265
#   102    81.940     0.001         265
#   104    83.953     0.001         265
#   106    85.021     0.001         265
#   107    86.052     0.001         265
#   109    87.059     0.001         265
#   110    88.143     0.001         265
#   112    89.191     0.001         265
#   114    90.229     0.001         265
#   115    92.112     0.001         265
#   117    93.126     0.001         265
#   119    94.195     0.001         265
#   121    96.224     0.001         265
#   122    97.328     0.001         265
#   124    98.380     0.001         265
#   125    99.444     0.001         265
#   127   100.559     0.001         265
#   128   101.661     0.001         265
#   130   102.696     0.001         265
#   131   103.791     0.001         265
#   133   104.881     0.001         265
#   134   105.918     0.001         265
#   136   106.999     0.001         265
#   137   108.123     0.001         265
#   139   109.220     0.001         265
#   141   110.251     0.001         265
#   142   111.375     0.001         265
#   144   112.493     0.001         265
#   145   113.559     0.001         265
#   147   114.647     0.001         265
#   148   115.755     0.001         265
#   150   116.814     0.001         265
#   151   117.820     0.001         265
#   153   119.983     0.001         265
#   155   121.009     0.001         265
#   156   122.042     0.001         265
#   158   123.148     0.001         265
#   160   124.231     0.001         265
#   161   125.255     0.001         265
#   163   126.298     0.001         265
#   164   127.327     0.001         265
#   166   129.238     0.001         265
#   168   130.288     0.001         265
#   169   131.330     0.001         265
#   171   133.303     0.001         265
#   173   134.360     0.001         265
#   174   135.391     0.001         265
#   176   137.429     0.001         265
#   178   138.496     0.001         265
#   179   139.533     0.001         265
#   181   141.555     0.001         265
#   183   142.632     0.001         265
#   184   143.665     0.001         265
#   186   144.687     0.001         265
#   187   145.742     0.001         265
#   189   146.799     0.001         265
#   191   148.868     0.001         265
#   192   150.003     0.001         265
#   194   151.064     0.001         265
#   195   152.128     0.001         265
#   197   153.240     0.001         265
#   199   154.336     0.001         265
#   200   155.388     0.001         265
#   202   156.462     0.001         265
#   203   157.573     0.001         265
#   205   158.627     0.001         265
#   206   159.644     0.001         265
#   208   160.728     0.001         265
# ...
#   763   491.933     0.001         265
#   764   492.005     0.001          10
#   765   492.161     0.001          47
#   766   492.937     0.001         265
#   767   493.964     0.001         265
#   768   494.005     0.001          10
#   769   494.161     0.001          47
#   770   495.941     0.001         265
#   771   496.005     0.001          10
#   772   496.161     0.001          47
#   773   496.949     0.001         265
#   774   498.005     0.001          10
#   775   498.161     0.001          47
#   776   500.005     0.001          10
#   777   500.161     0.001          47
#   778   500.751     0.001         265
#   779   502.005     0.001          10
#   780   502.161     0.001          47
#   781   502.725     0.001         265
#   782   504.005     0.001          10
#   783   504.161     0.001          47
#   784   506.005     0.001          10
#   785   506.161     0.001          47
#   786   506.481     0.001         265
#   787   507.697     0.001         768
#   788   507.701     0.001         768
#   789   508.005     0.001          10
#   790   508.161     0.001          47
#   791   508.325     0.001         265
#   792   510.005     0.001          10
#   793   510.161     0.001          47
#   794   510.225     0.001         265
#   795   511.256     0.001         265
#   796   512.005     0.001          10
#   797   512.161     0.001          47
#   798   512.266     0.001         265
#   799   514.005     0.001          10
#   800   514.161     0.001          47
#   801   514.287     0.001         265
#   802   516.005     0.001          10
#   803   516.161     0.001          47
#   804   516.262     0.001         265
#   805   517.290     0.001         265
#   806   518.005     0.001          10
#   807   518.161     0.001          47
#   808   519.244     0.001         265
#   809   520.005     0.001          10
#   810   520.161     0.001          47
#   811   520.278     0.001         265
#   812   522.005     0.001          10
#   813   522.161     0.001          47
#   814   522.272     0.001         265
#   815   523.325     0.001         265
#   816   524.005     0.001          10
#   817   524.161     0.001          47
#   818   524.390     0.001         265
#   819   525.394     0.001         265
#   820   526.005     0.001          10
#   821   526.161     0.001          47
#   822   526.447     0.001         265
#   823   527.517     0.001         265
#   824   528.005     0.001          10
#   825   528.161     0.001          47
#   826   529.539     0.001         265
#   827   530.005     0.001          10
#   828   530.161     0.001          47
#   829   530.583     0.001         265
#   830   532.005     0.001          10
#   831   532.161     0.001          47
#   832   532.597     0.001         265
#   833   533.633     0.001         265
#   834   534.005     0.001          10
#   835   534.161     0.001          47
#   836   536.005     0.001          10
#   837   536.161     0.001          47
#   838   537.601     0.001         265
#   839   538.005     0.001          10
#   840   538.161     0.001          47
#   841   538.627     0.001         265
#   842   540.005     0.001          10
#   843   540.161     0.001          47
#   844   540.563     0.001         265
#   845   541.573     0.001         265
#   846   542.005     0.001          10
#   847   542.161     0.001          47
#   848   543.579     0.001         265
#   849   544.005     0.001          10
#   850   544.161     0.001          47
#   851   544.608     0.001         265
#   852   545.624     0.001         265
#   853   546.005     0.001          10
#   854   546.161     0.001          47
#   855   546.640     0.001         265
#   856   547.672     0.001         265
#   857   548.005     0.001          10
#   858   548.161     0.001          47
#   859   550.005     0.001          10
#   860   550.161     0.001          47
#   861   552.005     0.001          10
#   862   552.086     0.001         768
#   863   552.090     0.001         768
#   864   552.161     0.001          47
#   865   552.516     0.001         265
#   866   553.533     0.001         265
#   867   554.005     0.001          10
#   868   554.161     0.001          47
#   869   554.577     0.001         265
#   870   556.005     0.001          10
#   871   556.161     0.001          47
#   872   556.563     0.001         265
#   873   558.005     0.001          10
#   874   558.161     0.001          47
#   875   559.552     0.001         265
#   876   560.005     0.001          10
#   877   560.161     0.001          47
#   878   560.608     0.001         265
#   879   562.005     0.001          10
#   880   562.161     0.001          47
#   881   562.634     0.001         265
#   882   563.689     0.001         265
#   883   564.005     0.001          10
#   884   564.161     0.001          47
#   885   565.687     0.001         265
#   886   566.005     0.001          10
#   887   566.161     0.001          47
#   888   566.715     0.001         265
#   889   568.005     0.001          10
#   890   568.161     0.001          47
#   891   568.702     0.001         265
#   892   570.005     0.001          10
#   893   570.161     0.001          47
#   894   571.718     0.001         265
#   895   572.005     0.001          10
#   896   572.161     0.001          47
#   897   573.768     0.001         265
#   898   574.005     0.001          10
#   899   574.161     0.001          47
#   900   575.779     0.001         265
#   901   576.005     0.001          10
#   902   576.161     0.001          47
#   903   576.832     0.001         265
#   904   578.005     0.001          10
#   905   578.161     0.001          47
#   906   578.787     0.001         265
#   907   579.810     0.001         265
#   908   580.005     0.001          10
#   909   580.161     0.001          47
#   910   581.787     0.001         265
#   911   582.005     0.001          10
#   912   582.161     0.001          47
#   913   582.817     0.001         265
#   914   583.824     0.001         265
#   915   584.005     0.001          10
#   916   584.161     0.001          47
#   917   585.759     0.001         265
#   918   586.005     0.001          10
#   919   586.161     0.001          47
#   920   588.005     0.001          10
#   921   588.161     0.001          47
#   922   588.761     0.001         265
#   923   589.789     0.001         265
#   924   590.005     0.001          10
#   925   590.161     0.001          47
#   926   590.836     0.001         265
#   927   592.005     0.001          10
#   928   592.161     0.001          47
#   929   594.005     0.001          10
#   930   594.161     0.001          47
#   931   594.694     0.001         265
#   932   596.005     0.001          10
#   933   596.161     0.001          47
#   934   597.493     0.001         768
#   935   597.497     0.001         768
#   936   598.005     0.001          10
#   937   598.161     0.001          47
#   938   598.423     0.001         265
#   939   599.437     0.001         265
#   940   600.005     0.001          10
#   941   600.161     0.001          47
#   942   601.436     0.001         265
#   943   602.005     0.001          10
#   944   602.161     0.001          47
#   945   604.005     0.001          10
#   946   604.161     0.001          47
#   947   604.440     0.001         265
#   948   606.005     0.001          10
#   949   606.161     0.001          47
#   950   606.427     0.001         265
#   951   608.005     0.001          10
#   952   608.161     0.001          47
#   953   608.388     0.001         265
#   954   609.410     0.001         265
#   955   610.005     0.001          10
#   956   610.161     0.001          47
#   957   611.346     0.001         265
#   958   612.005     0.001          10
#   959   612.161     0.001          47
#   960   612.362     0.001         265
#   961   614.005     0.001          10
#   962   614.161     0.001          47
#   963   614.318     0.001         265
#   964   616.005     0.001          10
#   965   616.161     0.001          47
#   966   618.005     0.001          10
#   967   618.122     0.001         265
#   968   618.161     0.001          47
#   969   619.123     0.001         265
#   970   620.005     0.001          10
#   971   620.161     0.001          47
#   972   621.062     0.001         265
#   973   622.005     0.001          10
#   974   622.064     0.001         265
#   975   622.161     0.001          47
#   976   623.076     0.001         265
#   977   624.005     0.001          10
#   978   624.083     0.001         265
#   979   624.161     0.001          47
#   980   626.005     0.001          10
#   981   626.006     0.001         265
#   982   626.161     0.001          47
#   983   627.933     0.001         265
#   984   628.005     0.001          10
#   985   628.161     0.001          47
#   986   629.928     0.001         265
#   987   630.005     0.001          10
#   988   630.161     0.001          47
#   989   631.823     0.001         265
#   990   632.005     0.001          10
#   991   632.161     0.001          47
#   992   634.005     0.001          10
#   993   634.161     0.001          47
#   994   635.546     0.001         265
#   995   636.005     0.001          10
#   996   636.161     0.001          47
#   997   636.591     0.001         265
#   998   638.005     0.001          10
#   999   638.161     0.001          47
#   1000  639.568     0.001         265
#   1001  640.005     0.001          10
#   1002  640.161     0.001          47
#   1003  642.005     0.001          10
#   1004  642.161     0.001          47
#   1005  642.253     0.001         265
#   1006  643.735     0.001         768
#   1007  643.739     0.001         768
#   1008  644.005     0.001          10
#   1009  644.161     0.001          47
#   1010  645.327     0.001         265
#   1011  646.005     0.001          10
#   1012  646.161     0.001          47
#   1013  647.009     0.001         265
#   1014  648.005     0.001          10
#   1015  648.161     0.001          47
#   1016  648.721     0.001         265
#   1017  649.791     0.001         265
#   1018  650.005     0.001          10
#   1019  650.161     0.001          47
#   1020  650.850     0.001         265
#   1021  651.920     0.001         265
#   1022  652.005     0.001          10
#   1023  652.161     0.001          47
#   1024  652.967     0.001         265
#   1025  654.005     0.001          10
#   1026  654.017     0.001         265
#   1027  654.161     0.001          47
#   1028  655.064     0.001         265
#   1029  656.005     0.001          10
#   1030  656.161     0.001          47
#   1031  657.146     0.001         265
#   1032  658.005     0.001          10
#   1033  658.161     0.001         265
#   1034  658.161     0.001          47
#   1035  659.179     0.001         265
#   1036  660.005     0.001          10
#   1037  660.161     0.001          47
#   1038  661.178     0.001         265
#   1039  662.005     0.001          10
#   1040  662.161     0.001          47
#   1041  663.119     0.001         265
#   1042  664.005     0.001          10
#   1043  664.161     0.001          47
#   1044  665.991     0.001         265
#   1045  666.005     0.001          10
#   1046  666.161     0.001          47
#   1047  666.992     0.001         265
#   1048  668.005     0.001          10
#   1049  668.161     0.001          47
#   1050  668.909     0.001         265
#   1051  670.005     0.001          10
#   1052  670.161     0.001          47
#   1053  670.879     0.001         265
#   1054  672.005     0.001          10
#   1055  672.161     0.001          47
#   1056  672.743     0.001         265
#   1057  674.005     0.001          10
#   1058  674.161     0.001          47
#   1059  675.581     0.001         265
#   1060  676.005     0.001          10
#   1061  676.161     0.001          47
#   1062  678.005     0.001          10
#   1063  678.161     0.001          47
#   1064  678.540     0.001         265
#   1065  679.543     0.001         265
#   1066  680.005     0.001          10
#   1067  680.161     0.001          47
#   1068  681.566     0.001         265
#   1069  682.005     0.001          10
#   1070  682.161     0.001          47
#   1071  683.501     0.001         265
#   1072  684.005     0.001          10
#   1073  684.161     0.001          47
#   1074  686.005     0.001          10
#   1075  686.161     0.001          47
#   1076  686.297     0.001         265
#   1077  688.005     0.001          10
#   1078  688.161     0.001          47
#   1079  689.143     0.001         768
#   1080  689.147     0.001         768
#   1081  689.151     0.001         265
#   1082  690.005     0.001          10
#   1083  690.161     0.001          47
#   1084  691.164     0.001         265
#   1085  692.005     0.001          10
#   1086  692.161     0.001          47
#   1087  694.005     0.001          10
#   1088  694.161     0.001          47
#   1089  694.180     0.001         265
#   1090  696.005     0.001          10
#   1091  696.161     0.001          47
#   1092  696.197     0.001         265
#   1093  697.301     0.001         265
#   1094  698.005     0.001          10
#   1095  698.161     0.001          47
#   1096  699.988     0.001         265
#   1097  700.005     0.001          10
#   1098  700.161     0.001          47
#   1099  701.819     0.001         265
#   1100  702.005     0.001          10
#   1101  702.161     0.001          47
#   1102  703.645     0.001         265
#   1103  704.005     0.001          10
#   1104  704.161     0.001          47
#   1105  706.005     0.001          10
#   1106  706.161     0.001          47
#   1107  706.471     0.001         265
#   1108  707.471     0.001         265
#   1109  708.005     0.001          10
#   1110  708.161     0.001          47
#   1111  709.451     0.001         265
#   1112  710.005     0.001          10
#   1113  710.161     0.001          47
#   1114  711.438     0.001         265
#   1115  712.005     0.001          10
#   1116  712.161     0.001          47
#   1117  712.459     0.001         265
#   1118  714.005     0.001          10
#   1119  714.161     0.001          47
#   1120  714.393     0.001         265
#   1121  716.005     0.001          10
#   1122  716.161     0.001          47
#   1123  716.351     0.001         265
#   1124  718.005     0.001          10
#   1125  718.161     0.001          47
#   1126  718.349     0.001         265
#   1127  719.377     0.001         265
#   1128  720.005     0.001          10
#   1129  720.161     0.001          47
#   1130  721.410     0.001         265
#   1131  722.005     0.001          10
#   1132  722.161     0.001          47
#   1133  722.461     0.001         265
#   1134  723.468     0.001         265
#   1135  724.005     0.001          10
#   1136  724.161     0.001          47
#   1137  724.504     0.001         265
#   1138  725.540     0.001         265
#   1139  726.005     0.001          10
#   1140  726.161     0.001          47
#   1141  727.489     0.001         265
#   1142  728.005     0.001          10
#   1143  728.161     0.001          47
#   1144  729.256     0.001         265
#   1145  730.005     0.001          10
#   1146  730.161     0.001          47
#   1147  730.297     0.001         265
#   1148  732.005     0.001          10
#   1149  732.161     0.001          47
#   1150  732.309     0.001         265
#   1151  733.362     0.001         265
#   1152  734.005     0.001          10
#   1153  734.161     0.001          47
#   1154  734.409     0.001         265
#   1155  736.005     0.001          10
#   1156  736.161     0.001          47
#   1157  738.161     0.001          47
#   1158  738.531     0.001         265
#   1159  739.554     0.001         265
#   1160  740.161     0.001          47
#   1161  740.579     0.001         265,
#   'fmri_trials': [{'trial_number': 1,
#     'music_condition': {'code': 1,
#      'onset': 0.001,
#      'duration': 0.001,
#      'target_emotion': 'Excited/Happy'},
#     'recording_method': 'Simultaneous EEG-fMRI',
#     'emotion_reporting': 'FEELTRACE continuous'}]},
#  'duration': np.float64(742.0),
#  'n_channels': 47,
#  'sfreq': 1000.0,
#  'experimental_info': {'paradigm_type': 'EEG-fMRI',
#   'trial_structure': '5 tasks: classicalMusic + 3 genMusic runs + washout',
#   'music_type': 'Generated music + classical pieces',
#   'additional_data': 'Simultaneous fMRI acquisition',
#   'emotion_reporting': 'FEELTRACE interface',
#   'tasks': ['classicalMusic',
#    'genMusic01',
#    'genMusic02',
#    'genMusic03',
#    'washout'],
#   'description': 'Joint EEG-fMRI with classical music and continuous emotion reporting'},
#  'n_trials': 1}

# %%
loader.data[loader.subjects[0]]['no_session']['classicalMusic']
# Out:
# {'raw': <RawEDF | sub-01_task-classicalMusic_eeg.edf, 47 x 1915000 (1915.0 s), ~41 KiB, data not loaded>,
#  'events':          onset  duration  trial_type
#  0        0.001     0.001           1
#  1        0.001     0.001          47
#  2        0.001     0.001        1283
#  3        0.913     0.001        1285
#  4        0.913     0.001         265
#  5        1.501     0.001       34053
#  6        1.801     0.001          47
#  7        3.801     0.001          47
#  8        3.836     0.001         265
#  9        4.845     0.001         265
#  10       5.801     0.001          47
#  11       6.811     0.001         265
#  12       7.801     0.001          47
#  13       7.836     0.001         265
#  14       9.801     0.001          47
#  15      10.794     0.001         265
#  16      11.801     0.001          47
#  17      13.759     0.001         265
#  18      13.801     0.001          47
#  19      14.828     0.001         265
#  20      15.801     0.001          47
#  21      16.888     0.001         265
#  22      17.801     0.001          47
#  23      17.954     0.001         265
#  24      19.801     0.001          47
#  25      20.017     0.001         265
#  26      21.037     0.001         265
#  27      21.801     0.001          47
#  28      23.076     0.001         265
#  29      23.801     0.001          47
#  30      24.097     0.001         265
#  31      25.801     0.001          47
#  32      27.801     0.001          47
#  33      29.801     0.001          47
#  34      30.675     0.001          10
#  35      31.771     0.001         768
#  36      31.801     0.001          47
#  37      32.675     0.001          10
#  38      33.801     0.001          47
#  39      34.675     0.001          10
#  40      35.801     0.001          47
#  41      36.675     0.001          10
#  42      37.753     0.001         265
#  43      37.801     0.001          47
#  44      38.675     0.001          10
#  45      39.801     0.001          47
#  46      40.675     0.001          10
#  47      41.801     0.001          47
#  48      42.675     0.001          10
#  49      43.801     0.001          47
#  50      43.873     0.001         265
#  51      44.675     0.001          10
#  52      45.801     0.001          47
#  53      46.675     0.001          10
#  54      47.801     0.001          47
#  55      48.675     0.001          10
#  56      49.801     0.001          47
#  57      50.675     0.001          10
#  58      50.785     0.001         265
#  59      51.801     0.001          47
#  60      52.675     0.001          10
#  61      53.801     0.001          47
#  62      54.675     0.001          10
#  63      55.801     0.001          47
#  64      56.675     0.001          10
#  65      56.942     0.001         265
#  66      57.801     0.001          47
#  67      58.675     0.001          10
#  68      59.801     0.001          47
#  69      60.081     0.001         265
#  70      60.675     0.001          10
#  71      61.801     0.001          47
#  72      62.083     0.001         265
#  73      62.675     0.001          10
#  74      63.106     0.001         265
#  75      63.801     0.001          47
#  76      64.675     0.001          10
#  77      65.801     0.001          47
#  78      66.242     0.001         265
#  79      66.675     0.001          10
#  80      67.801     0.001          47
#  81      68.675     0.001          10
#  82      69.801     0.001          47
#  83      70.412     0.001         265
#  84      70.675     0.001          10
#  85      71.801     0.001          47
#  86      72.675     0.001          10
#  87      73.437     0.001         265
#  88      73.801     0.001          47
#  89      74.546     0.001         265
#  90      74.675     0.001          10
#  91      75.801     0.001          47
#  92      76.675     0.001          10
#  93      77.801     0.001          47
#  94      78.502     0.001         265
#  95      78.675     0.001          10
#  96      79.801     0.001          47
#  97      80.675     0.001          10
#  98      81.694     0.001         265
#  99      81.801     0.001          47
#  100     82.675     0.001          10
#  101     82.777     0.001         265
#  102     83.801     0.001          47
#  103     84.675     0.001          10
#  104     85.801     0.001          47
#  105     86.675     0.001          10
#  106     87.801     0.001          47
#  107     88.675     0.001          10
#  108     89.797     0.001         265
#  109     89.801     0.001          47
#  110     90.675     0.001          10
#  111     91.801     0.001          47
#  112     92.675     0.001          10
#  113     93.801     0.001          47
#  114     93.856     0.001         265
#  115     94.675     0.001          10
#  116     95.801     0.001          47
#  117     96.675     0.001          10
#  118     96.928     0.001         265
#  119     97.801     0.001          47
#  120     98.675     0.001          10
#  121     99.801     0.001          47
#  122    100.675     0.001          10
#  123    101.801     0.001          47
#  124    102.675     0.001          10
#  125    102.836     0.001         265
#  126    103.801     0.001          47
#  127    104.675     0.001          10
#  128    105.760     0.001         265
#  129    105.801     0.001          47
#  130    106.675     0.001          10
#  131    107.759     0.001         265
#  132    107.801     0.001          47
#  133    108.675     0.001          10
#  134    108.788     0.001         265
#  135    109.801     0.001          47
#  136    110.675     0.001          10
#  137    111.760     0.001         265
#  138    111.801     0.001          47
#  139    112.675     0.001          10
#  140    113.801     0.001          47
#  141    114.675     0.001          10
#  142    114.774     0.001         265
#  143    115.801     0.001          47
#  144    116.675     0.001          10
#  145    117.801     0.001          47
#  146    117.856     0.001         265
#  147    118.675     0.001          10
#  148    119.801     0.001          47
#  149    120.675     0.001          10
#  150    120.896     0.001         265
#  151    121.801     0.001          47
#  152    122.675     0.001          10
#  153    123.801     0.001          47
#  154    124.675     0.001          10
#  155    124.954     0.001         265
#  156    125.801     0.001          47
#  157    126.675     0.001          10
#  158    127.801     0.001          47
#  159    128.085     0.001         265
#  160    128.675     0.001          10
#  161    129.801     0.001          47
#  162    130.675     0.001          10
#  163    131.203     0.001         265
#  164    131.801     0.001          47
#  165    132.675     0.001          10
#  166    133.801     0.001          47
#  167    134.281     0.001         265
#  168    134.675     0.001          10
#  169    135.801     0.001          47
#  170    136.675     0.001          10
#  171    137.801     0.001          47
#  172    138.675     0.001          10
#  173    139.801     0.001          47
#  174    140.675     0.001          10
#  175    141.362     0.001         265
#  176    141.801     0.001          47
#  177    142.675     0.001          10
#  178    143.801     0.001          47
#  179    144.353     0.001         265
#  180    144.675     0.001          10
#  181    145.801     0.001          47
#  182    146.675     0.001          10
#  183    147.373     0.001         265
#  184    147.801     0.001          47
#  185    148.675     0.001          10
#  186    149.495     0.001         265
#  187    149.801     0.001          47
#  188    150.611     0.001         265
#  189    150.675     0.001          10
#  190    151.801     0.001          47
#  191    152.673     0.001         265
#  192    152.675     0.001          10
#  193    153.701     0.001         265
#  194    153.801     0.001          47
#  195    154.675     0.001          10
#  196    155.801     0.001          47
#  197    156.675     0.001          10
#  198    157.801     0.001          47
#  199    157.818     0.001         265
#  200    158.675     0.001          10
#  201    159.801     0.001          47
#  202    159.915     0.001         265
#  203    160.675     0.001          10
#  204    161.801     0.001          47
#  205    162.675     0.001          10
#  206    163.801     0.001          47
#  207    164.194     0.001         265
#  208    164.675     0.001          10
#  209    165.317     0.001         265
#  210    165.801     0.001          47
#  211    166.675     0.001          10
#  212    167.801     0.001          47
#  213    168.675     0.001          10
#  214    169.801     0.001          47
#  215    170.612     0.001         265
#  216    170.675     0.001          10
#  217    171.755     0.001         265
#  218    171.801     0.001          47
#  219    172.675     0.001          10
#  220    173.801     0.001          47
#  221    174.675     0.001          10
#  222    175.801     0.001          47
#  223    176.675     0.001          10
#  224    177.801     0.001          47
#  225    178.675     0.001          10
#  226    179.801     0.001          47
#  227    180.675     0.001          10
#  228    181.801     0.001          47
#  229    182.675     0.001          10
#  230    183.801     0.001          47
#  231    184.675     0.001          10
#  232    185.695     0.001         265
#  233    185.801     0.001          47
#  234    186.675     0.001          10
#  235    187.801     0.001          47
#  236    188.675     0.001          10
#  237    189.801     0.001          47
#  238    190.675     0.001          10
#  239    191.801     0.001          47
#  240    192.229     0.001         265
#  241    192.675     0.001          10
#  242    193.321     0.001         265
#  243    193.801     0.001          47
#  244    194.675     0.001          10
#  245    195.801     0.001          47
#  246    195.807     0.001         768
#  247    196.514     0.001         265
#  248    196.675     0.001          10
#  249    197.801     0.001          47
#  250    198.675     0.001          10
#  251    198.681     0.001         265
#  252    199.801     0.001          47
#  253    200.675     0.001          10
#  254    200.820     0.001         265
#  255    201.801     0.001          47
#  256    202.675     0.001          10
#  257    203.801     0.001          47
#  258    204.675     0.001          10
#  259    205.801     0.001          47
#  260    206.675     0.001          10
#  261    207.801     0.001          47
#  262    208.675     0.001          10
#  263    209.801     0.001          47
#  264    210.407     0.001         265
#  265    210.675     0.001          10
#  266    211.801     0.001          47
#  267    212.675     0.001          10
#  268    213.801     0.001          47
#  269    214.675     0.001          10
#  270    215.661     0.001         265
#  271    215.801     0.001          47
#  272    216.675     0.001          10
#  273    216.727     0.001         265
#  274    217.801     0.001          47
#  275    218.675     0.001          10
#  276    218.836     0.001         265
#  277    219.801     0.001          47
#  278    219.871     0.001         265
#  279    220.675     0.001          10
#  280    221.801     0.001          47
#  281    222.675     0.001          10
#  282    223.050     0.001         265
#  283    223.801     0.001          47
#  284    224.675     0.001          10
#  285    225.094     0.001         265
#  286    225.801     0.001          47
#  287    226.143     0.001         265
#  288    226.675     0.001          10
#  289    227.254     0.001         265
#  290    227.801     0.001          47
#  291    228.675     0.001          10
#  292    229.374     0.001         265
#  293    229.801     0.001          47
#  294    230.410     0.001         265
#  295    230.675     0.001          10
#  296    231.441     0.001         265
#  297    231.801     0.001          47
#  298    232.675     0.001          10
#  299    233.801     0.001          47
#  300    234.556     0.001         265
#  301    234.675     0.001          10
#  302    235.801     0.001          47
#  303    236.675     0.001          10
#  304    237.801     0.001          47
#  305    238.675     0.001          10
#  306    238.783     0.001         265
#  307    239.801     0.001          47
#  308    240.675     0.001          10
#  309    241.801     0.001          47
#  310    242.675     0.001          10
#  311    243.801     0.001          47
#  312    244.675     0.001          10
#  313    245.736     0.001         265
#  314    245.801     0.001          47
#  315    246.675     0.001          10
#  316    247.801     0.001          47
#  317    248.675     0.001          10
#  318    248.840     0.001         265
#  319    249.801     0.001          47
#  320    250.675     0.001          10
#  321    251.801     0.001          47
#  322    251.818     0.001         265
#  323    252.675     0.001          10
#  324    253.801     0.001          47
#  325    254.675     0.001          10
#  326    255.801     0.001          47
#  327    255.866     0.001         265
#  328    256.675     0.001          10
#  329    257.801     0.001          47
#  330    258.675     0.001          10
#  331    259.801     0.001          47
#  332    260.675     0.001          10
#  333    261.801     0.001          47
#  334    262.085     0.001         265
#  335    262.675     0.001          10
#  336    263.161     0.001         265
#  337    263.801     0.001          47
#  338    264.675     0.001          10
#  339    265.801     0.001          47
#  340    266.187     0.001         265
#  341    266.675     0.001          10
#  342    267.255     0.001         265
#  343    267.801     0.001          47
#  344    268.675     0.001          10
#  345    269.801     0.001          47
#  346    270.675     0.001          10
#  347    271.801     0.001          47
#  348    272.675     0.001          10
#  349    273.801     0.001          47
#  350    274.572     0.001         265
#  351    274.675     0.001          10
#  352    275.801     0.001          47
#  353    276.675     0.001          10
#  354    277.801     0.001          47
#  355    278.675     0.001          10
#  356    279.801     0.001          47
#  357    280.675     0.001          10
#  358    281.801     0.001          47
#  359    282.675     0.001          10
#  360    283.801     0.001          47
#  361    283.864     0.001         265
#  362    284.675     0.001          10
#  363    284.952     0.001         265
#  364    285.801     0.001          47
#  365    286.675     0.001          10
#  366    287.056     0.001         265
#  367    287.801     0.001          47
#  368    288.175     0.001         265
#  369    288.675     0.001          10
#  370    289.801     0.001          47
#  371    290.675     0.001          10
#  372    291.359     0.001         265
#  373    291.801     0.001          47
#  374    292.675     0.001          10
#  375    293.801     0.001          47
#  376    294.675     0.001          10
#  377    295.801     0.001          47
#  378    296.675     0.001          10
#  379    297.584     0.001         265
#  380    297.801     0.001          47
#  381    298.675     0.001          10
#  382    299.801     0.001          47
#  383    300.675     0.001          10
#  384    301.801     0.001          47
#  385    302.675     0.001          10
#  386    303.801     0.001          47
#  387    303.961     0.001         265
#  388    304.675     0.001          10
#  389    305.801     0.001          47
#  390    306.675     0.001          10
#  391    307.801     0.001          47
#  392    308.136     0.001         265
#  393    308.675     0.001          10
#  394    309.801     0.001          47
#  395    310.675     0.001          10
#  396    311.214     0.001         265
#  397    311.801     0.001          47
#  398    312.675     0.001          10
#  399    313.265     0.001         265
#  400    313.801     0.001          47
#  401    314.675     0.001          10
#  402    315.801     0.001          47
#  403    316.675     0.001          10
#  404    317.579     0.001         265
#  405    317.801     0.001          47
#  406    318.675     0.001          10
#  407    319.801     0.001          47
#  408    320.675     0.001          10
#  409    321.589     0.001         265
#  410    321.801     0.001          47
#  411    322.675     0.001          10
#  412    323.801     0.001          47
#  413    324.675     0.001          10
#  414    325.801     0.001          47
#  415    326.675     0.001          10
#  416    327.058     0.001         265
#  417    327.801     0.001          47
#  418    328.675     0.001          10
#  419    329.801     0.001          47
#  420    330.675     0.001          10
#  421    331.801     0.001          47
#  422    332.675     0.001          10
#  423    333.440     0.001         265
#  424    333.801     0.001          47
#  425    334.675     0.001          10
#  426    335.801     0.001          47
#  427    336.675     0.001          10
#  428    337.801     0.001          47
#  429    338.675     0.001          10
#  430    339.801     0.001          47
#  431    340.675     0.001          10
#  432    341.801     0.001          47
#  433    342.675     0.001          10
#  434    343.801     0.001          47
#  435    344.007     0.001         265
#  436    344.675     0.001          10
#  437    345.801     0.001          47
#  438    346.675     0.001          10
#  439    347.801     0.001          47
#  440    348.675     0.001          10
#  441    349.801     0.001          47
#  442    350.675     0.001          10
#  443    351.801     0.001          47
#  444    352.406     0.001         265
#  445    352.675     0.001          10
#  446    353.801     0.001          47
#  447    354.675     0.001          10
#  448    355.801     0.001          47
#  449    356.675     0.001          10
#  450    357.756     0.001         265
#  451    357.801     0.001          47
#  452    358.675     0.001          10
#  453    359.801     0.001          47
#  454    360.675     0.001          10
#  455    361.801     0.001          47
#  456    362.010     0.001         768
#  457    362.675     0.001          10
#  458    363.801     0.001          47
#  459    364.675     0.001          10
#  460    364.822     0.001         265
#  461    365.801     0.001          47
#  462    366.675     0.001          10
#  463    367.801     0.001          47
#  464    367.972     0.001         265
#  465    368.675     0.001          10
#  466    369.801     0.001          47
#  467    370.675     0.001          10
#  468    371.115     0.001         265
#  469    371.801     0.001          47
#  470    372.675     0.001          10
#  471    373.221     0.001         265
#  472    373.801     0.001          47
#  473    374.284     0.001         265
#  474    374.675     0.001          10
#  475    375.801     0.001          47
#  476    376.675     0.001          10
#  477    377.801     0.001          47
#  478    378.675     0.001          10
#  479    379.801     0.001          47
#  480    380.675     0.001          10
#  481    381.801     0.001          47
#  482    381.834     0.001         265
#  483    382.675     0.001          10
#  484    382.958     0.001         265
#  485    383.801     0.001          47
#  486    384.090     0.001         265
#  487    384.675     0.001          10
#  488    385.801     0.001          47
#  489    386.675     0.001          10
#  490    387.445     0.001         265
#  491    387.801     0.001          47
#  492    388.592     0.001         265
#  493    388.675     0.001          10
#  494    389.801     0.001          47
#  495    390.675     0.001          10
#  496    390.786     0.001         265
#  497    391.801     0.001          47
#  498    391.910     0.001         265
#  499    392.675     0.001          10
#  500    393.801     0.001          47
#  501    394.675     0.001          10
#  502    395.801     0.001          47
#  503    396.675     0.001          10
#  504    397.801     0.001          47
#  505    398.675     0.001          10
#  506    399.801     0.001          47
#  507    400.675     0.001          10
#  508    401.801     0.001          47
#  509    402.675     0.001          10
#  510    403.107     0.001         265
#  511    403.801     0.001          47
#  512    404.675     0.001          10
#  513    405.187     0.001         265
#  514    405.801     0.001          47
#  515    406.675     0.001          10
#  516    407.801     0.001          47
#  517    408.675     0.001          10
#  518    409.801     0.001          47
#  519    410.419     0.001         265
#  520    410.675     0.001          10
#  521    411.801     0.001          47
#  522    412.675     0.001          10
#  523    413.315     0.001         265
#  524    413.801     0.001          47
#  525    414.675     0.001          10
#  526    415.801     0.001          47
#  527    416.675     0.001          10
#  528    417.801     0.001          47
#  529    418.675     0.001          10
#  530    419.801     0.001          47
#  531    420.675     0.001          10
#  532    421.801     0.001          47
#  533    422.675     0.001          10
#  534    423.801     0.001          47
#  535    424.408     0.001         265
#  536    424.675     0.001          10
#  537    425.801     0.001          47
#  538    426.675     0.001          10
#  539    427.457     0.001         265
#  540    427.801     0.001          47
#  541    428.675     0.001          10
#  542    429.801     0.001          47
#  543    430.532     0.001         265
#  544    430.675     0.001          10
#  545    431.801     0.001          47
#  546    432.594     0.001         265
#  547    432.675     0.001          10
#  548    433.616     0.001         265
#  549    433.801     0.001          47
#  550    434.675     0.001          10
#  551    435.801     0.001          47
#  552    436.620     0.001         265
#  553    436.675     0.001          10
#  554    437.801     0.001          47
#  555    438.675     0.001          10
#  556    439.614     0.001         265
#  557    439.801     0.001          47
#  558    440.675     0.001          10
#  559    441.801     0.001          47
#  560    442.675     0.001          10
#  561    443.515     0.001         265
#  562    443.801     0.001          47
#  563    444.675     0.001          10
#  564    445.801     0.001          47
#  565    446.560     0.001         265
#  566    446.675     0.001          10
#  567    447.801     0.001          47
#  568    448.675     0.001          10
#  569    449.801     0.001          47
#  570    450.675     0.001          10
#  571    451.801     0.001          47
#  572    452.647     0.001         265
#  573    452.675     0.001          10
#  574    453.801     0.001          47
#  575    454.675     0.001          10
#  576    455.801     0.001          47
#  577    456.675     0.001          10
#  578    457.801     0.001          47
#  579    458.529     0.001         265
#  580    458.675     0.001          10
#  581    459.547     0.001         265
#  582    459.801     0.001          47
#  583    460.675     0.001          10
#  584    461.801     0.001          47
#  585    462.467     0.001         265
#  586    462.675     0.001          10
#  587    463.801     0.001          47
#  588    464.675     0.001          10
#  589    465.801     0.001          47
#  590    466.675     0.001          10
#  591    467.801     0.001          47
#  592    468.361     0.001         265
#  593    468.675     0.001          10
#  594    469.801     0.001          47
#  595    470.675     0.001          10
#  596    471.801     0.001          47
#  597    472.225     0.001         265
#  598    472.675     0.001          10
#  599    473.801     0.001          47
#  600    474.675     0.001          10
#  601    475.129     0.001         265
#  602    475.801     0.001          47
#  603    476.675     0.001          10
#  604    477.801     0.001          47
#  605    478.675     0.001          10
#  606    479.801     0.001          47
#  607    480.675     0.001          10
#  608    481.801     0.001          47
#  609    482.675     0.001          10
#  610    483.801     0.001          47
#  611    484.503     0.001         265
#  612    484.675     0.001          10
#  613    485.801     0.001          47
#  614    486.675     0.001          10
#  615    487.413     0.001         265
#  616    487.801     0.001          47
#  617    488.675     0.001          10
#  618    489.801     0.001          47
#  619    490.289     0.001         265
#  620    490.675     0.001          10
#  621    491.801     0.001          47
#  622    492.675     0.001          10
#  623    493.801     0.001          47
#  624    494.675     0.001          10
#  625    495.801     0.001          47
#  626    496.675     0.001          10
#  627    497.801     0.001          47
#  628    498.675     0.001          10
#  629    499.047     0.001         265
#  630    499.801     0.001          47
#  631    500.057     0.001         265
#  632    500.675     0.001          10
#  633    501.801     0.001          47
#  634    502.675     0.001          10
#  635    503.028     0.001         265
#  636    503.801     0.001          47
#  637    504.675     0.001          10
#  638    505.801     0.001          47
#  639    505.934     0.001         265
#  640    506.675     0.001          10
#  641    507.801     0.001          47
#  642    508.675     0.001          10
#  643    509.801     0.001          47
#  644    510.675     0.001          10
#  645    511.784     0.001         265
#  646    511.801     0.001          47
#  647    512.675     0.001          10
#  648    512.805     0.001         265
#  649    513.801     0.001          47
#  650    514.675     0.001          10
#  651    515.801     0.001          47
#  652    516.675     0.001          10
#  653    517.801     0.001          47
#  654    517.864     0.001         768
#  655    518.675     0.001          10
#  656    519.801     0.001          47
#  657    520.675     0.001          10
#  658    521.801     0.001          47
#  659    522.675     0.001          10
#  660    523.801     0.001          47
#  661    524.675     0.001          10
#  662    525.801     0.001          47
#  663    526.675     0.001          10
#  664    527.801     0.001          47
#  665    528.675     0.001          10
#  666    529.801     0.001          47
#  667    530.675     0.001          10
#  668    531.801     0.001          47
#  669    532.675     0.001          10
#  670    533.801     0.001          47
#  671    534.675     0.001          10
#  672    535.801     0.001          47
#  673    536.675     0.001          10
#  674    537.801     0.001          47
#  675    538.675     0.001          10
#  676    538.922     0.001         265
#  677    539.801     0.001          47
#  678    540.675     0.001          10
#  679    541.801     0.001          47
#  680    541.872     0.001         265
#  681    542.675     0.001          10
#  682    543.801     0.001          47
#  683    544.675     0.001          10
#  684    545.801     0.001          47
#  685    545.958     0.001         265
#  686    546.675     0.001          10
#  687    547.801     0.001          47
#  688    548.675     0.001          10
#  689    549.105     0.001         265
#  690    549.801     0.001          47
#  691    550.184     0.001         265
#  692    550.675     0.001          10
#  693    551.801     0.001          47
#  694    552.236     0.001         265
#  695    552.675     0.001          10
#  696    553.313     0.001         265
#  697    553.801     0.001          47
#  698    554.675     0.001          10
#  699    555.801     0.001          47
#  700    556.451     0.001         265
#  701    556.675     0.001          10
#  702    557.801     0.001          47
#  703    558.675     0.001          10
#  704    559.801     0.001          47
#  705    560.675     0.001          10
#  706    560.676     0.001         265
#  707    561.801     0.001          47
#  708    562.675     0.001          10
#  709    563.801     0.001          47
#  710    564.675     0.001          10
#  711    565.801     0.001          47
#  712    566.675     0.001          10
#  713    567.052     0.001         265
#  714    567.801     0.001          47
#  715    568.167     0.001         265
#  716    568.675     0.001          10
#  717    569.801     0.001          47
#  718    570.675     0.001          10
#  719    571.801     0.001          47
#  720    572.675     0.001          10
#  721    573.801     0.001          47
#  722    574.496     0.001         265
#  723    574.675     0.001          10
#  724    575.801     0.001          47
#  725    576.675     0.001          10
#  726    577.801     0.001          47
#  727    578.675     0.001          10
#  728    579.801     0.001          47
#  729    580.675     0.001          10
#  730    581.801     0.001          47
#  731    582.675     0.001          10
#  732    583.801     0.001          47
#  733    584.675     0.001          10
#  734    585.801     0.001          47
#  735    586.675     0.001          10
#  736    587.801     0.001          47
#  737    588.068     0.001         265
#  738    588.675     0.001          10
#  739    589.801     0.001          47
#  740    590.675     0.001          10
#  741    591.801     0.001          47
#  742    591.969     0.001         265
#  743    592.675     0.001          10
#  744    593.801     0.001          47
#  745    594.675     0.001          10
#  746    595.210     0.001         265
#  747    595.801     0.001          47
#  748    596.675     0.001          10
#  749    597.801     0.001          47
#  750    598.675     0.001          10
#  751    599.801     0.001          47
#  752    600.675     0.001          10
#  753    601.801     0.001          47
#  754    602.673     0.001         265
#  755    602.675     0.001          10
#  756    603.801     0.001          47
#  757    604.675     0.001          10
#  758    605.801     0.001          47
#  759    606.675     0.001          10
#  760    606.726     0.001         265
#  761    607.801     0.001          47
#  762    608.675     0.001          10
#  763    609.801     0.001          47
#  764    610.675     0.001          10
#  765    611.801     0.001          47
#  766    612.675     0.001          10
#  767    613.801     0.001          47
#  768    614.675     0.001          10
#  769    615.143     0.001         265
#  770    615.801     0.001          47
#  771    616.675     0.001          10
#  772    617.801     0.001          47
#  773    618.337     0.001         265
#  774    618.675     0.001          10
#  775    619.801     0.001          47
#  776    620.675     0.001          10
#  777    621.533     0.001         265
#  778    621.801     0.001          47
#  779    622.675     0.001          10
#  780    623.801     0.001          47
#  781    624.675     0.001          10
#  782    624.722     0.001         265
#  783    625.801     0.001          47
#  784    626.675     0.001          10
#  785    627.763     0.001         265
#  786    627.801     0.001          47
#  787    628.675     0.001          10
#  788    629.801     0.001          47
#  789    630.675     0.001          10
#  790    631.801     0.001          47
#  791    632.675     0.001          10
#  792    633.801     0.001          47
#  793    634.675     0.001          10
#  794    635.801     0.001          47
#  795    635.845     0.001         265
#  796    636.675     0.001          10
#  797    637.801     0.001          47
#  798    638.675     0.001          10
#  799    639.801     0.001          47
#  800    640.675     0.001          10
#  801    641.801     0.001          47
#  802    642.675     0.001          10
#  803    643.801     0.001          47
#  804    644.675     0.001          10
#  805    645.801     0.001          47
#  806    646.675     0.001          10
#  807    646.776     0.001         265
#  808    647.801     0.001          47
#  809    648.675     0.001          10
#  810    649.801     0.001          47
#  811    650.675     0.001          10
#  812    651.315     0.001         265
#  813    651.801     0.001          47
#  814    652.675     0.001          10
#  815    653.801     0.001          47
#  816    654.675     0.001          10
#  817    655.801     0.001          47
#  818    656.675     0.001          10
#  819    657.801     0.001          47
#  820    658.515     0.001         265
#  821    658.675     0.001          10
#  822    659.801     0.001          47
#  823    660.675     0.001          10
#  824    661.801     0.001          47
#  825    662.675     0.001          10
#  826    663.801     0.001          47
#  827    664.675     0.001          10
#  828    665.801     0.001          47
#  829    666.675     0.001          10
#  830    667.801     0.001          47
#  831    667.976     0.001         265
#  832    668.675     0.001          10
#  833    669.801     0.001          47
#  834    670.675     0.001          10
#  835    671.196     0.001         265
#  836    671.801     0.001          47
#  837    672.675     0.001          10
#  838    673.801     0.001          47
#  839    674.675     0.001          10
#  840    675.060     0.001         265
#  841    675.801     0.001          47
#  842    676.140     0.001         768
#  843    676.675     0.001          10
#  844    677.801     0.001          47
#  845    678.675     0.001          10
#  846    679.801     0.001          47
#  847    680.675     0.001          10
#  848    681.801     0.001          47
#  849    682.675     0.001          10
#  850    683.801     0.001          47
#  851    684.221     0.001         265
#  852    684.675     0.001          10
#  853    685.321     0.001         265
#  854    685.801     0.001          47
#  855    686.675     0.001          10
#  856    687.801     0.001          47
#  857    688.532     0.001         265
#  858    688.675     0.001          10
#  859    689.801     0.001          47
#  860    690.675     0.001          10
#  861    691.801     0.001          47
#  862    692.675     0.001          10
#  863    693.801     0.001          47
#  864    694.675     0.001          10
#  865    695.801     0.001          47
#  866    696.675     0.001          10
#  867    697.801     0.001          47
#  868    698.675     0.001          10
#  869    699.599     0.001         265
#  870    699.801     0.001          47
#  871    700.675     0.001          10
#  872    701.801     0.001          47
#  873    702.675     0.001          10
#  874    703.801     0.001          47
#  875    704.675     0.001          10
#  876    705.801     0.001          47
#  877    706.675     0.001          10
#  878    707.801     0.001          47
#  879    708.675     0.001          10
#  880    709.801     0.001          47
#  881    710.675     0.001          10
#  882    711.801     0.001          47
#  883    712.675     0.001          10
#  884    713.801     0.001          47
#  885    714.675     0.001          10
#  886    715.801     0.001          47
#  887    716.675     0.001          10
#  888    717.801     0.001          47
#  889    718.675     0.001          10
#  890    719.801     0.001          47
#  891    720.675     0.001          10
#  892    721.058     0.001         265
#  893    721.801     0.001          47
#  894    722.675     0.001          10
#  895    723.801     0.001          47
#  896    724.675     0.001          10
#  897    725.801     0.001          47
#  898    726.675     0.001          10
#  899    727.801     0.001          47
#  900    728.675     0.001          10
#  901    729.801     0.001          47
#  902    730.675     0.001          10
#  903    731.801     0.001          47
#  904    732.675     0.001          10
#  905    733.801     0.001          47
#  906    734.675     0.001          10
#  907    735.801     0.001          47
#  908    736.675     0.001          10
#  909    737.243     0.001         265
#  910    737.801     0.001          47
#  911    738.675     0.001          10
#  912    739.801     0.001          47
#  913    740.675     0.001          10
#  914    741.801     0.001          47
#  915    742.675     0.001          10
#  916    743.801     0.001          47
#  917    744.675     0.001          10
#  918    745.801     0.001          47
#  919    746.675     0.001          10
#  920    747.801     0.001          47
#  921    748.675     0.001          10
#  922    749.801     0.001          47
#  923    750.675     0.001          10
#  924    751.801     0.001          47
#  925    751.992     0.001         265
#  926    752.675     0.001          10
#  927    753.801     0.001          47
#  928    754.675     0.001          10
#  929    755.801     0.001          47
#  930    756.675     0.001          10
#  931    757.801     0.001          47
#  932    758.675     0.001          10
#  933    759.801     0.001          47
#  934    760.675     0.001          10
#  935    761.333     0.001         265
#  936    761.801     0.001          47
#  937    762.675     0.001          10
#  938    763.801     0.001          47
#  939    764.675     0.001          10
#  940    765.619     0.001         265
#  941    765.801     0.001          47
#  942    766.675     0.001          10
#  943    767.666     0.001         265
#  944    767.801     0.001          47
#  945    768.675     0.001          10
#  946    769.801     0.001          47
#  947    770.675     0.001          10
#  948    771.801     0.001          47
#  949    772.675     0.001          10
#  950    773.801     0.001          47
#  951    774.675     0.001          10
#  952    775.801     0.001          47
#  953    776.675     0.001          10
#  954    777.801     0.001          47
#  955    778.675     0.001          10
#  956    779.801     0.001          47
#  957    780.675     0.001          10
#  958    781.801     0.001          47
#  959    782.675     0.001          10
#  960    783.448     0.001         265
#  961    783.801     0.001          47
#  962    784.675     0.001          10
#  963    785.801     0.001          47
#  964    786.675     0.001          10
#  965    787.801     0.001          47
#  966    788.675     0.001          10
#  967    789.462     0.001         265
#  968    789.801     0.001          47
#  969    790.675     0.001          10
#  970    791.801     0.001          47
#  971    792.675     0.001          10
#  972    793.801     0.001          47
#  973    794.675     0.001          10
#  974    795.801     0.001          47
#  975    796.387     0.001         265
#  976    796.675     0.001          10
#  977    797.801     0.001          47
#  978    798.675     0.001          10
#  979    799.801     0.001          47
#  980    800.675     0.001          10
#  981    801.801     0.001          47
#  982    802.675     0.001          10
#  983    803.801     0.001          47
#  984    804.675     0.001          10
#  985    805.801     0.001          47
#  986    806.675     0.001          10
#  987    807.801     0.001          47
#  988    808.675     0.001          10
#  989    809.801     0.001          47
#  990    810.675     0.001          10
#  991    811.801     0.001          47
#  992    812.675     0.001          10
#  993    813.801     0.001          47
#  994    814.675     0.001          10
#  995    815.801     0.001          47
#  996    816.675     0.001          10
#  997    817.801     0.001          47
#  998    818.080     0.001         265
#  999    818.675     0.001          10
#  1000   819.801     0.001          47
#  1001   820.675     0.001          10
#  1002   821.801     0.001          47
#  1003   822.675     0.001          10
#  1004   823.801     0.001          47
#  1005   824.675     0.001          10
#  1006   825.801     0.001          47
#  1007   826.675     0.001          10
#  1008   827.187     0.001         265
#  1009   827.801     0.001          47
#  1010   828.675     0.001          10
#  1011   829.801     0.001          47
#  1012   830.675     0.001          10
#  1013   831.801     0.001          47
#  1014   832.675     0.001          10
#  1015   833.801     0.001          47
#  1016   834.675     0.001          10
#  1017   835.801     0.001          47
#  1018   836.675     0.001          10
#  1019   837.801     0.001          47
#  1020   838.675     0.001          10
#  1021   839.801     0.001          47
#  1022   840.675     0.001          10
#  1023   841.794     0.001         768
#  1024   841.801     0.001          47
#  1025   842.675     0.001          10
#  1026   843.801     0.001          47
#  1027   844.675     0.001          10
#  1028   845.270     0.001         265
#  1029   845.801     0.001          47
#  1030   846.675     0.001          10
#  1031   847.801     0.001          47
#  1032   848.675     0.001          10
#  1033   849.801     0.001          47
#  1034   850.675     0.001          10
#  1035   851.801     0.001          47
#  1036   852.675     0.001          10
#  1037   853.801     0.001          47
#  1038   854.675     0.001          10
#  1039   855.801     0.001          47
#  1040   856.675     0.001          10
#  1041   857.801     0.001          47
#  1042   858.675     0.001          10
#  1043   859.801     0.001          47
#  1044   860.675     0.001          10
#  1045   861.801     0.001          47
#  1046   862.675     0.001          10
#  1047   863.801     0.001          47
#  1048   864.675     0.001          10
#  1049   865.801     0.001          47
#  1050   865.919     0.001         265
#  1051   866.675     0.001          10
#  1052   866.985     0.001         265
#  1053   867.801     0.001          47
#  1054   868.675     0.001          10
#  1055   868.996     0.001         265
#  1056   869.801     0.001          47
#  1057   870.012     0.001         265
#  1058   870.675     0.001          10
#  1059   871.801     0.001          47
#  1060   872.675     0.001          10
#  1061   873.801     0.001          47
#  1062   873.874     0.001         265
#  1063   874.675     0.001          10
#  1064   875.801     0.001          47
#  1065   876.675     0.001          10
#  1066   877.061     0.001         265
#  1067   877.801     0.001          47
#  1068   878.675     0.001          10
#  1069   879.215     0.001         265
#  1070   879.801     0.001          47
#  1071   880.675     0.001          10
#  1072   881.801     0.001          47
#  1073   882.675     0.001          10
#  1074   883.801     0.001          47
#  1075   884.675     0.001          10
#  1076   885.801     0.001          47
#  1077   886.675     0.001          10
#  1078   887.801     0.001          47
#  1079   888.675     0.001          10
#  1080   888.768     0.001         265
#  1081   889.801     0.001          47
#  1082   890.675     0.001          10
#  1083   891.801     0.001          47
#  1084   892.675     0.001          10
#  1085   893.801     0.001          47
#  1086   894.675     0.001          10
#  1087   895.801     0.001          47
#  1088   896.675     0.001          10
#  1089   897.801     0.001          47
#  1090   898.675     0.001          10
#  1091   899.101     0.001         265
#  1092   899.801     0.001          47
#  1093   900.675     0.001          10
#  1094   901.801     0.001          47
#  1095   902.675     0.001          10
#  1096   903.801     0.001          47
#  1097   904.675     0.001          10
#  1098   905.801     0.001          47
#  1099   906.613     0.001         265
#  1100   906.675     0.001          10
#  1101   907.801     0.001          47
#  1102   908.675     0.001          10
#  1103   909.702     0.001         265
#  1104   909.801     0.001          47
#  1105   910.675     0.001          10
#  1106   911.801     0.001          47
#  1107   912.675     0.001          10
#  1108   913.801     0.001          47
#  1109   914.675     0.001          10
#  1110   915.801     0.001          47
#  1111   916.675     0.001          10
#  1112   917.801     0.001          47
#  1113   918.675     0.001          10
#  1114   919.801     0.001          47
#  1115   920.675     0.001          10
#  1116   921.801     0.001          47
#  1117   922.675     0.001          10
#  1118   922.682     0.001         265
#  1119   923.801     0.001          47
#  1120   924.675     0.001          10
#  1121   925.756     0.001         265
#  1122   925.801     0.001          47
#  1123   926.675     0.001          10
#  1124   927.801     0.001          47
#  1125   928.675     0.001          10
#  1126   928.991     0.001         265
#  1127   929.801     0.001          47
#  1128   930.675     0.001          10
#  1129   931.801     0.001          47
#  1130   932.234     0.001         265
#  1131   932.675     0.001          10
#  1132   933.801     0.001          47
#  1133   934.675     0.001          10
#  1134   935.801     0.001          47
#  1135   936.675     0.001          10
#  1136   937.801     0.001          47
#  1137   938.675     0.001          10
#  1138   939.801     0.001          47
#  1139   940.675     0.001          10
#  1140   941.801     0.001          47
#  1141   942.675     0.001          10
#  1142   943.801     0.001          47
#  1143   944.675     0.001          10
#  1144   945.269     0.001         265
#  1145   945.801     0.001          47
#  1146   946.675     0.001          10
#  1147   947.801     0.001          47
#  1148   948.675     0.001          10
#  1149   949.801     0.001          47
#  1150   950.675     0.001          10
#  1151   951.801     0.001          47
#  1152   952.675     0.001          10
#  1153   953.801     0.001          47
#  1154   954.675     0.001          10
#  1155   955.801     0.001          47
#  1156   956.675     0.001          10
#  1157   957.801     0.001          47
#  1158   958.675     0.001          10
#  1159   959.801     0.001          47
#  1160   960.675     0.001          10
#  1161   961.801     0.001          47
#  1162   962.675     0.001          10
#  1163   963.801     0.001          47
#  1164   964.675     0.001          10
#  1165   965.801     0.001          47
#  1166   966.675     0.001          10
#  1167   967.801     0.001          47
#  1168   968.675     0.001          10
#  1169   969.801     0.001          47
#  1170   970.675     0.001          10
#  1171   971.801     0.001          47
#  1172   972.675     0.001          10
#  1173   973.801     0.001          47
#  1174   973.926     0.001         768
#  1175   974.675     0.001          10
#  1176   975.801     0.001          47
#  1177   976.675     0.001          10
#  1178   977.801     0.001          47
#  1179   978.675     0.001          10
#  1180   979.801     0.001          47
#  1181   980.675     0.001          10
#  1182   981.801     0.001          47
#  1183   982.016     0.001         265
#  1184   982.675     0.001          10
#  1185   983.801     0.001          47
#  1186   984.675     0.001          10
#  1187   985.150     0.001         265
#  1188   985.801     0.001          47
#  1189   986.675     0.001          10
#  1190   987.801     0.001          47
#  1191   988.147     0.001         265
#  1192   988.675     0.001          10
#  1193   989.801     0.001          47
#  1194   990.675     0.001          10
#  1195   990.976     0.001         265
#  1196   991.801     0.001          47
#  1197   992.675     0.001          10
#  1198   993.801     0.001          47
#  1199   994.675     0.001          10
#  1200   995.801     0.001          47
#  1201   996.675     0.001          10
#  1202   997.801     0.001          47
#  1203   998.675     0.001          10
#  1204   999.801     0.001          47
#  1205  1000.675     0.001          10
#  1206  1001.801     0.001          47
#  1207  1002.675     0.001          10
#  1208  1003.697     0.001         265
#  1209  1003.801     0.001          47
#  1210  1004.675     0.001          10
#  1211  1005.751     0.001         265
#  1212  1005.801     0.001          47
#  1213  1006.675     0.001          10
#  1214  1007.801     0.001          47
#  1215  1008.675     0.001          10
#  1216  1009.801     0.001          47
#  1217  1010.675     0.001          10
#  1218  1011.801     0.001          47
#  1219  1012.675     0.001          10
#  1220  1013.801     0.001          47
#  1221  1014.675     0.001          10
#  1222  1015.801     0.001          47
#  1223  1016.479     0.001         265
#  1224  1016.675     0.001          10
#  1225  1017.801     0.001          47
#  1226  1018.515     0.001         265
#  1227  1018.675     0.001          10
#  1228  1019.801     0.001          47
#  1229  1020.675     0.001          10
#  1230  1021.801     0.001          47
#  1231  1022.675     0.001          10
#  1232  1023.801     0.001          47
#  1233  1024.675     0.001          10
#  1234  1025.801     0.001          47
#  1235  1026.675     0.001          10
#  1236  1027.801     0.001          47
#  1237  1027.826     0.001         265
#  1238  1028.675     0.001          10
#  1239  1029.801     0.001          47
#  1240  1030.675     0.001          10
#  1241  1031.801     0.001          47
#  1242  1032.675     0.001          10
#  1243  1033.801     0.001          47
#  1244  1034.631     0.001         265
#  1245  1034.675     0.001          10
#  1246  1035.801     0.001          47
#  1247  1036.675     0.001          10
#  1248  1037.801     0.001          47
#  1249  1038.675     0.001          10
#  1250  1039.801     0.001          47
#  1251  1040.675     0.001          10
#  1252  1041.679     0.001         265
#  1253  1041.801     0.001          47
#  1254  1042.675     0.001          10
#  1255  1043.801     0.001          47
#  1256  1044.675     0.001          10
#  1257  1045.801     0.001          47
#  1258  1046.675     0.001          10
# ...
#   1867  1576.683     0.001         265
#   1868  1577.801     0.001          47
#   1869  1578.675     0.001          10
#   1870  1579.779     0.001         265
#   1871  1579.801     0.001          47
#   1872  1580.675     0.001          10
#   1873  1581.801     0.001          47
#   1874  1582.675     0.001          10
#   1875  1583.746     0.001         265
#   1876  1583.801     0.001          47
#   1877  1584.675     0.001          10
#   1878  1585.801     0.001          47
#   1879  1586.675     0.001          10
#   1880  1587.801     0.001          47
#   1881  1588.675     0.001          10
#   1882  1589.801     0.001          47
#   1883  1590.675     0.001          10
#   1884  1591.801     0.001          47
#   1885  1592.675     0.001          10
#   1886  1593.801     0.001          47
#   1887  1594.423     0.001         768
#   1888  1594.675     0.001          10
#   1889  1595.801     0.001          47
#   1890  1596.675     0.001          10
#   1891  1597.801     0.001          47
#   1892  1598.675     0.001          10
#   1893  1599.801     0.001          47
#   1894  1600.675     0.001          10
#   1895  1601.801     0.001          47
#   1896  1602.675     0.001          10
#   1897  1603.507     0.001         265
#   1898  1603.801     0.001          47
#   1899  1604.675     0.001          10
#   1900  1605.801     0.001          47
#   1901  1606.675     0.001          10
#   1902  1607.801     0.001          47
#   1903  1608.675     0.001          10
#   1904  1609.801     0.001          47
#   1905  1610.675     0.001          10
#   1906  1611.801     0.001          47
#   1907  1612.097     0.001         265
#   1908  1612.675     0.001          10
#   1909  1613.105     0.001         265
#   1910  1613.801     0.001          47
#   1911  1614.675     0.001          10
#   1912  1615.096     0.001         265
#   1913  1615.801     0.001          47
#   1914  1616.675     0.001          10
#   1915  1617.801     0.001          47
#   1916  1618.076     0.001         265
#   1917  1618.675     0.001          10
#   1918  1619.801     0.001          47
#   1919  1620.675     0.001          10
#   1920  1621.801     0.001          47
#   1921  1622.675     0.001          10
#   1922  1623.801     0.001          47
#   1923  1624.675     0.001          10
#   1924  1625.595     0.001         265
#   1925  1625.801     0.001          47
#   1926  1626.675     0.001          10
#   1927  1627.730     0.001         265
#   1928  1627.801     0.001          47
#   1929  1628.675     0.001          10
#   1930  1629.801     0.001          47
#   1931  1630.675     0.001          10
#   1932  1630.755     0.001         265
#   1933  1631.801     0.001          47
#   1934  1632.675     0.001          10
#   1935  1633.801     0.001          47
#   1936  1634.675     0.001          10
#   1937  1635.801     0.001          47
#   1938  1636.675     0.001          10
#   1939  1637.801     0.001          47
#   1940  1638.675     0.001          10
#   1941  1638.870     0.001         265
#   1942  1639.801     0.001          47
#   1943  1640.675     0.001          10
#   1944  1640.868     0.001         265
#   1945  1641.801     0.001          47
#   1946  1642.675     0.001          10
#   1947  1643.801     0.001          47
#   1948  1644.675     0.001          10
#   1949  1645.801     0.001          47
#   1950  1645.915     0.001         265
#   1951  1646.675     0.001          10
#   1952  1647.801     0.001          47
#   1953  1648.675     0.001          10
#   1954  1649.801     0.001          47
#   1955  1650.675     0.001          10
#   1956  1651.801     0.001          47
#   1957  1652.675     0.001          10
#   1958  1653.801     0.001          47
#   1959  1654.675     0.001          10
#   1960  1655.801     0.001          47
#   1961  1656.675     0.001          10
#   1962  1657.174     0.001         265
#   1963  1657.801     0.001          47
#   1964  1658.675     0.001          10
#   1965  1659.239     0.001         265
#   1966  1659.801     0.001          47
#   1967  1660.264     0.001         265
#   1968  1660.675     0.001          10
#   1969  1661.801     0.001          47
#   1970  1662.675     0.001          10
#   1971  1663.186     0.001         265
#   1972  1663.801     0.001          47
#   1973  1664.675     0.001          10
#   1974  1665.175     0.001         265
#   1975  1665.801     0.001          47
#   1976  1666.675     0.001          10
#   1977  1667.801     0.001          47
#   1978  1668.675     0.001          10
#   1979  1669.153     0.001         265
#   1980  1669.801     0.001          47
#   1981  1670.675     0.001          10
#   1982  1671.801     0.001          47
#   1983  1672.675     0.001          10
#   1984  1673.801     0.001          47
#   1985  1674.675     0.001          10
#   1986  1675.801     0.001          47
#   1987  1676.675     0.001          10
#   1988  1677.801     0.001          47
#   1989  1678.675     0.001          10
#   1990  1679.801     0.001          47
#   1991  1680.675     0.001          10
#   1992  1681.801     0.001          47
#   1993  1682.675     0.001          10
#   1994  1683.801     0.001          47
#   1995  1684.675     0.001          10
#   1996  1685.801     0.001          47
#   1997  1686.675     0.001          10
#   1998  1687.801     0.001          47
#   1999  1688.675     0.001          10
#   2000  1689.801     0.001          47
#   2001  1690.675     0.001          10
#   2002  1691.801     0.001          47
#   2003  1692.675     0.001          10
#   2004  1693.801     0.001          47
#   2005  1694.675     0.001          10
#   2006  1695.801     0.001          47
#   2007  1696.675     0.001          10
#   2008  1697.801     0.001          47
#   2009  1698.675     0.001          10
#   2010  1699.801     0.001          47
#   2011  1700.675     0.001          10
#   2012  1701.801     0.001          47
#   2013  1702.216     0.001         265
#   2014  1702.675     0.001          10
#   2015  1703.801     0.001          47
#   2016  1704.675     0.001          10
#   2017  1705.801     0.001          47
#   2018  1706.675     0.001          10
#   2019  1707.801     0.001          47
#   2020  1708.675     0.001          10
#   2021  1709.801     0.001          47
#   2022  1710.675     0.001          10
#   2023  1711.801     0.001          47
#   2024  1712.048     0.001         265
#   2025  1712.675     0.001          10
#   2026  1713.801     0.001          47
#   2027  1714.675     0.001          10
#   2028  1715.801     0.001          47
#   2029  1715.837     0.001         265
#   2030  1716.675     0.001          10
#   2031  1717.801     0.001          47
#   2032  1718.675     0.001          10
#   2033  1718.799     0.001         265
#   2034  1719.801     0.001          47
#   2035  1720.675     0.001          10
#   2036  1721.801     0.001          47
#   2037  1722.675     0.001          10
#   2038  1723.801     0.001          47
#   2039  1724.675     0.001          10
#   2040  1725.455     0.001         265
#   2041  1725.801     0.001          47
#   2042  1726.675     0.001          10
#   2043  1727.801     0.001          47
#   2044  1728.323     0.001         265
#   2045  1728.675     0.001          10
#   2046  1729.801     0.001          47
#   2047  1730.675     0.001          10
#   2048  1731.801     0.001          47
#   2049  1732.675     0.001          10
#   2050  1733.801     0.001          47
#   2051  1734.675     0.001          10
#   2052  1735.801     0.001          47
#   2053  1736.675     0.001          10
#   2054  1737.398     0.001         265
#   2055  1737.801     0.001          47
#   2056  1738.675     0.001          10
#   2057  1739.801     0.001          47
#   2058  1740.427     0.001         265
#   2059  1740.675     0.001          10
#   2060  1741.801     0.001          47
#   2061  1742.675     0.001          10
#   2062  1743.801     0.001          47
#   2063  1744.377     0.001         265
#   2064  1744.675     0.001          10
#   2065  1745.801     0.001          47
#   2066  1746.675     0.001          10
#   2067  1747.801     0.001          47
#   2068  1748.675     0.001          10
#   2069  1749.801     0.001          47
#   2070  1750.675     0.001          10
#   2071  1751.801     0.001          47
#   2072  1752.100     0.001         265
#   2073  1752.675     0.001          10
#   2074  1753.801     0.001          47
#   2075  1754.675     0.001          10
#   2076  1755.071     0.001         265
#   2077  1755.801     0.001          47
#   2078  1756.675     0.001          10
#   2079  1757.801     0.001          47
#   2080  1758.157     0.001         768
#   2081  1758.675     0.001          10
#   2082  1759.801     0.001          47
#   2083  1760.675     0.001          10
#   2084  1761.801     0.001          47
#   2085  1762.675     0.001          10
#   2086  1763.801     0.001          47
#   2087  1764.675     0.001          10
#   2088  1765.801     0.001          47
#   2089  1766.675     0.001          10
#   2090  1766.918     0.001         265
#   2091  1767.801     0.001          47
#   2092  1767.938     0.001         265
#   2093  1768.675     0.001          10
#   2094  1769.801     0.001          47
#   2095  1770.675     0.001          10
#   2096  1771.801     0.001          47
#   2097  1772.675     0.001          10
#   2098  1773.572     0.001         265
#   2099  1773.801     0.001          47
#   2100  1774.675     0.001          10
#   2101  1775.801     0.001          47
#   2102  1776.569     0.001         265
#   2103  1776.675     0.001          10
#   2104  1777.801     0.001          47
#   2105  1778.675     0.001          10
#   2106  1779.801     0.001          47
#   2107  1780.675     0.001          10
#   2108  1781.801     0.001          47
#   2109  1782.675     0.001          10
#   2110  1783.504     0.001         265
#   2111  1783.801     0.001          47
#   2112  1784.530     0.001         265
#   2113  1784.675     0.001          10
#   2114  1785.554     0.001         265
#   2115  1785.801     0.001          47
#   2116  1786.675     0.001          10
#   2117  1787.801     0.001          47
#   2118  1788.469     0.001         265
#   2119  1788.675     0.001          10
#   2120  1789.519     0.001         265
#   2121  1789.801     0.001          47
#   2122  1790.675     0.001          10
#   2123  1791.673     0.001         265
#   2124  1791.801     0.001          47
#   2125  1792.675     0.001          10
#   2126  1793.801     0.001          47
#   2127  1794.675     0.001          10
#   2128  1795.801     0.001          47
#   2129  1796.675     0.001          10
#   2130  1796.990     0.001         265
#   2131  1797.801     0.001          47
#   2132  1798.675     0.001          10
#   2133  1799.801     0.001          47
#   2134  1800.675     0.001          10
#   2135  1801.801     0.001          47
#   2136  1802.675     0.001          10
#   2137  1803.801     0.001          47
#   2138  1804.675     0.001          10
#   2139  1805.801     0.001          47
#   2140  1806.675     0.001          10
#   2141  1807.801     0.001          47
#   2142  1808.675     0.001          10
#   2143  1809.801     0.001          47
#   2144  1810.675     0.001          10
#   2145  1811.801     0.001          47
#   2146  1812.675     0.001          10
#   2147  1813.801     0.001          47
#   2148  1814.042     0.001         265
#   2149  1814.675     0.001          10
#   2150  1815.801     0.001          47
#   2151  1816.234     0.001         265
#   2152  1816.675     0.001          10
#   2153  1817.801     0.001          47
#   2154  1818.675     0.001          10
#   2155  1819.801     0.001          47
#   2156  1820.366     0.001         265
#   2157  1820.675     0.001          10
#   2158  1821.801     0.001          47
#   2159  1822.675     0.001          10
#   2160  1823.801     0.001          47
#   2161  1824.675     0.001          10
#   2162  1825.801     0.001          47
#   2163  1826.675     0.001          10
#   2164  1827.096     0.001         265
#   2165  1827.801     0.001          47
#   2166  1828.675     0.001          10
#   2167  1829.801     0.001          47
#   2168  1830.056     0.001         265
#   2169  1830.675     0.001          10
#   2170  1831.801     0.001          47
#   2171  1832.675     0.001          10
#   2172  1833.801     0.001          47
#   2173  1834.096     0.001         265
#   2174  1834.675     0.001          10
#   2175  1835.801     0.001          47
#   2176  1836.675     0.001          10
#   2177  1837.801     0.001          47
#   2178  1838.675     0.001          10
#   2179  1838.863     0.001         265
#   2180  1839.801     0.001          47
#   2181  1840.675     0.001          10
#   2182  1840.779     0.001         265
#   2183  1841.801     0.001          47
#   2184  1842.675     0.001          10
#   2185  1843.801     0.001          47
#   2186  1844.675     0.001          10
#   2187  1844.882     0.001         265
#   2188  1845.801     0.001          47
#   2189  1845.934     0.001         265
#   2190  1846.675     0.001          10
#   2191  1847.801     0.001          47
#   2192  1848.675     0.001          10
#   2193  1849.801     0.001          47
#   2194  1850.091     0.001         265
#   2195  1850.675     0.001          10
#   2196  1851.801     0.001          47
#   2197  1852.675     0.001          10
#   2198  1853.801     0.001          47
#   2199  1854.675     0.001          10
#   2200  1855.801     0.001          47
#   2201  1856.675     0.001          10
#   2202  1856.925     0.001         265
#   2203  1857.801     0.001          47
#   2204  1858.675     0.001          10
#   2205  1859.801     0.001          47
#   2206  1860.675     0.001          10
#   2207  1861.801     0.001          47
#   2208  1862.675     0.001          10
#   2209  1863.801     0.001          47
#   2210  1864.675     0.001          10
#   2211  1865.290     0.001         265
#   2212  1865.801     0.001          47
#   2213  1866.675     0.001          10
#   2214  1867.801     0.001          47
#   2215  1868.675     0.001          10
#   2216  1869.801     0.001          47
#   2217  1870.086     0.001         265
#   2218  1870.675     0.001          10
#   2219  1871.097     0.001         265
#   2220  1871.801     0.001          47
#   2221  1872.675     0.001          10
#   2222  1873.801     0.001          47
#   2223  1874.675     0.001          10
#   2224  1875.801     0.001          47
#   2225  1876.675     0.001          10
#   2226  1877.801     0.001          47
#   2227  1877.837     0.001         265
#   2228  1878.675     0.001          10
#   2229  1879.801     0.001          47
#   2230  1879.863     0.001         265
#   2231  1880.675     0.001          10
#   2232  1881.801     0.001          47
#   2233  1882.675     0.001          10
#   2234  1883.801     0.001          47
#   2235  1884.675     0.001          10
#   2236  1885.801     0.001          47
#   2237  1886.675     0.001          10
#   2238  1887.801     0.001          47
#   2239  1888.675     0.001          10
#   2240  1889.801     0.001          47
#   2241  1891.801     0.001          47
#   2242  1892.904     0.001         265
#   2243  1893.801     0.001          47
#   2244  1895.801     0.001          47
#   2245  1895.920     0.001         265
#   2246  1897.801     0.001          47
#   2247  1899.801     0.001          47
#   2248  1901.801     0.001          47
#   2249  1903.801     0.001          47
#   2250  1905.801     0.001          47
#   2251  1906.102     0.001         265
#   2252  1907.801     0.001          47
#   2253  1909.801     0.001          47
#   2254  1911.801     0.001          47
#   2255  1913.801     0.001          47,
#   'fmri_trials': [{'trial_number': 1,
#     'music_condition': {'code': 1,
#      'onset': 0.001,
#      'duration': 0.001,
#      'target_emotion': 'Excited/Happy'},
#     'recording_method': 'Simultaneous EEG-fMRI',
#     'emotion_reporting': 'FEELTRACE continuous'}]},
#  'duration': np.float64(1915.0),
#  'n_channels': 47,
#  'sfreq': 1000.0,
#  'experimental_info': {'paradigm_type': 'EEG-fMRI',
#   'trial_structure': '5 tasks: classicalMusic + 3 genMusic runs + washout',
#   'music_type': 'Generated music + classical pieces',
#   'additional_data': 'Simultaneous fMRI acquisition',
#   'emotion_reporting': 'FEELTRACE interface',
#   'tasks': ['classicalMusic',
#    'genMusic01',
#    'genMusic02',
#    'genMusic03',
#    'washout'],
#   'description': 'Joint EEG-fMRI with classical music and continuous emotion reporting'},
#  'n_trials': 1}

# %%
# Test the updated BCMIFMRILoader implementation
# %load_ext autoreload
# %autoreload 2

from bcmi import create_bcmi_loader
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 120)

print("🧪 Testing BCMI-fMRI Loader Implementation")
print("=" * 60)

# Load the fMRI dataset
fmri_loader = create_bcmi_loader('./datasets/bcmi/bcmi-fmri')
fmri_loader.load_all_subjects(max_subjects=1)

# Access the first subject's data
subject_id = fmri_loader.subjects[0]
print(f"\n📊 Testing with subject: {subject_id}")

# Test genMusic trials
print(f"\n🎵 TESTING genMusic TRIALS:")
for gen_task in ['genMusic01', 'genMusic02', 'genMusic03']:
    if gen_task in fmri_loader.data[subject_id]['no_session']:
        print(f"\n--- {gen_task} ---")
        task_data = fmri_loader.data[subject_id]['no_session'][gen_task]
        
        # Show raw events with 768 markers
        events_768 = task_data['events'][task_data['events']['trial_type'] == 768]
        print(f"Raw 768 events found: {len(events_768)}")
        if len(events_768) > 0:
            print("First few 768 events:")
            print(events_768.head())
        
        # Show processed trials
        fmri_trials = task_data['processed_events'].get('fmri_trials', [])
        print(f"Processed trials: {len(fmri_trials)}")
        if fmri_trials:
            for trial in fmri_trials[:3]:  # Show first 3 trials
                print(f"  Trial {trial['trial_number']}: onset={trial['onset']:.3f}s, "
                      f"music_file={trial['music_file']}, duration={trial['duration']}s")

# Test classicalMusic trials  
print(f"\n🎼 TESTING classicalMusic TRIALS:")
if 'classicalMusic' in fmri_loader.data[subject_id]['no_session']:
    classical_data = fmri_loader.data[subject_id]['no_session']['classicalMusic']
    
    # Show raw events with 768 markers
    events_768 = classical_data['events'][classical_data['events']['trial_type'] == 768]
    print(f"Raw 768 events found: {len(events_768)}")
    if len(events_768) > 0:
        print("First few 768 events:")
        print(events_768.head())
    
    # Show processed trials
    fmri_trials = classical_data['processed_events'].get('fmri_trials', [])
    print(f"Processed trials: {len(fmri_trials)}")
    if fmri_trials:
        for trial in fmri_trials:
            print(f"  Trial {trial['trial_number']}: onset={trial['onset']:.3f}s, "
                  f"music_file={trial['music_file']}, duration={trial['duration']:.1f}s")

print(f"\n✅ Test completed!")

# %%
# Simple debug test for BCMI-fMRI loader
from bcmi import create_bcmi_loader
import pandas as pd

print("🔍 DEBUGGING BCMI-fMRI Loader")

# Load one subject
fmri_loader = create_bcmi_loader('./datasets/bcmi/bcmi-fmri')

# Check what we have before processing
print(f"Available subjects: {fmri_loader.subjects[:3]}")

# Load just one subject
if fmri_loader.subjects:
    subject_id = fmri_loader.subjects[0]
    print(f"\nLoading subject: {subject_id}")
    
    try:
        fmri_loader.load_subject_data(subject_id, max_runs=2)  # Load only 2 runs for testing
        
        print(f"\nLoaded data structure:")
        for session_key, session_data in fmri_loader.data[subject_id].items():
            print(f"  Session: {session_key}")
            for run_key, run_data in session_data.items():
                print(f"    Run: {run_key}")
                if 'processed_events' in run_data:
                    fmri_trials = run_data['processed_events'].get('fmri_trials', [])
                    print(f"      fMRI trials: {len(fmri_trials)}")
                    if fmri_trials:
                        print(f"      First trial: {fmri_trials[0]}")
    except Exception as e:
        print(f"Error during loading: {e}")
        import traceback
        traceback.print_exc()
# Out:
# 🔍 DEBUGGING BCMI-fMRI Loader
# Available subjects: ['01', '02', '03']
#
# Loading subject: 01
# Loading subject 01 (bcmi-fmri):
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Run classicalMusic: 1915.0s, 2256 events, 1 trials
#     Warning: Could not process fMRI events for task genMusic01 - 'music'
#   ✓ Run genMusic01: 742.0s, 1162 events, 1 trials
#
# Loaded data structure:
#   Session: no_session
#     Run: classicalMusic
#       fMRI trials: 1
#       First trial: {'trial_number': 1, 'onset': np.float64(31.771), 'duration': np.float64(1883.228), 'music_file': 'classical/unknown_piece_for_classicalMusic.mp3', 'task_type': 'classicalMusic'}
#     Run: genMusic01
#       fMRI trials: 0
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)

# %%
# Test the CORRECTED BCMIFMRILoader implementation
# %load_ext autoreload
# %autoreload 2

from bcmi import create_bcmi_loader
import pandas as pd

print("🔧 Testing CORRECTED BCMI-fMRI Loader")
print("=" * 50)

# Load the fMRI dataset
fmri_loader = create_bcmi_loader('./datasets/bcmi/bcmi-fmri')

# Load one subject with both genMusic and classicalMusic
subject_id = fmri_loader.subjects[0]
print(f"\nTesting with subject: {subject_id}")

try:
    fmri_loader.load_subject_data(subject_id, max_runs=3)  # Load classicalMusic + 2 genMusic runs
    
    print(f"\n✅ RESULTS:")
    for session_key, session_data in fmri_loader.data[subject_id].items():
        print(f"\nSession: {session_key}")
        for run_key, run_data in session_data.items():
            fmri_trials = run_data['processed_events'].get('fmri_trials', [])
            print(f"  {run_key}: {len(fmri_trials)} trials")
            
            # Show details for each trial
            for trial in fmri_trials:
                onset = trial['onset']
                duration = trial['duration']
                music_file = trial['music_file']
                task_type = trial['task_type']
                music_code = trial.get('music_code', 'N/A')
                
                print(f"    Trial {trial['trial_number']}: {onset:.3f}s -> {onset+duration:.1f}s")
                print(f"      File: {music_file}")
                print(f"      Type: {task_type}")
                if music_code != 'N/A':
                    print(f"      Music code: {music_code}")
                    
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# 🔧 Testing CORRECTED BCMI-fMRI Loader
# ==================================================
#
# Testing with subject: 01
# Loading subject 01 (bcmi-fmri):
#   ✓ Run classicalMusic: 1915.0s, 2256 events, 1 trials
#     Warning: Could not process fMRI events for task genMusic01 - 'music'
#   ✓ Run genMusic01: 742.0s, 1162 events, 1 trials
#     Warning: Could not process fMRI events for task genMusic02 - 'music'
#   ✓ Run genMusic02: 621.0s, 637 events, 1 trials
#
# ✅ RESULTS:
#
# Session: no_session
#   classicalMusic: 1 trials
#     Trial 1: 31.771s -> 1915.0s
#       File: classical/unknown_piece_for_classicalMusic.mp3
#       Type: classicalMusic
#   genMusic01: 0 trials
#   genMusic02: 0 trials
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)

# %%
# Debug: Check what channels are actually in the EEG data
from bcmi import create_bcmi_loader

print("🔍 INSPECTING EEG CHANNELS")
print("=" * 40)

fmri_loader = create_bcmi_loader('./datasets/bcmi/bcmi-fmri')
subject_id = fmri_loader.subjects[0]

# Load just one run to check channels
fmri_loader.load_subject_data(subject_id, max_runs=1)

if 'genMusic01' in fmri_loader.data[subject_id]['no_session']:
    raw = fmri_loader.data[subject_id]['no_session']['genMusic01']['raw']
    
    print(f"Channel names in genMusic01:")
    for i, ch_name in enumerate(raw.ch_names):
        print(f"  {i:2d}: {ch_name}")
    
    print(f"\nTotal channels: {len(raw.ch_names)}")
    
    # Check if 'music' channel exists
    if 'music' in raw.ch_names:
        print(f"\n✅ 'music' channel found at index: {raw.ch_names.index('music')}")
        
        # Sample some values from the music channel
        music_idx = raw.ch_names.index('music')
        music_data = raw.get_data(picks=[music_idx])[0]
        print(f"Music channel stats:")
        print(f"  Min: {music_data.min():.6f}")
        print(f"  Max: {music_data.max():.6f}")
        print(f"  Mean: {music_data.mean():.6f}")
        print(f"  First 10 values: {music_data[:10]}")
    else:
        print(f"\n❌ 'music' channel NOT found!")
        print("Available channels containing 'music' or similar:")
        for ch in raw.ch_names:
            if 'music' in ch.lower() or 'stimuli' in ch.lower():
                print(f"  - {ch}")
else:
    print("genMusic01 not loaded or available")
# Out:
# 🔍 INSPECTING EEG CHANNELS
# ========================================
# Loading subject 01 (bcmi-fmri):
#   ✓ Run classicalMusic: 1915.0s, 2256 events, 1 trials
# genMusic01 not loaded or available
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:298: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)

# %%
fmri_loader = create_bcmi_loader('./datasets/bcmi/bcmi-fmri')
fmri_loader.load_all_subjects()
# Out:
# 🔄 Loading bcmi-fmri dataset...
# 📦 Subjects to load: 21 of 21
#
# Loading subject 01 (bcmi-fmri):
#   ✓ Run classicalMusic: 1915.0s, 2256 events, 1 trials
#   ✓ Run genMusic01: 742.0s, 1162 events, 1 trials
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Run genMusic02: 621.0s, 637 events, 1 trials
#   ✓ Run genMusic03: 578.0s, 595 events, 1 trials
#   ✓ Run washout: 90.0s, 102 events, 1 trials
# Loading subject 02 (bcmi-fmri):
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Physical range is not defined in following channels:
# ft_valance, ft_arousal, ft_x, ft_y, ft_ghostvalence, ft_ghostarousal, music, trialtype, sams_valence, sams_arousal, sams_valencert, sams_arousalrt
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Run classicalMusic: 1898.0s, 1901 events, 1 trials
#   ✓ Run genMusic01: 600.0s, 854 events, 1 trials
#   ✓ Run genMusic02: 594.0s, 775 events, 1 trials
#   ✓ Run genMusic03: 593.0s, 793 events, 1 trials
#   ✓ Run washout: 112.0s, 125 events, 1 trials
# Loading subject 03 (bcmi-fmri):
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Physical range is not defined in following channels:
# ft_valance, ft_arousal, ft_x, ft_y, ft_ghostvalence, ft_ghostarousal, music, trialtype, sams_valence, sams_arousal, sams_valencert, sams_arousalrt
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Physical range is not defined in following channels:
# ft_ghostvalence, ft_ghostarousal, sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)
# ...
#        'music_file': 'generated/2-*_*.wav',
#        'music_code': 2,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 12,
#        'onset': np.float64(513.878),
#        'duration': 40.0,
#        'music_file': 'generated/2-*_*.wav',
#        'music_code': 2,
#        'task_type': 'generatedMusic'}]},
#     'duration': np.float64(597.0),
#     'n_channels': 47,
#     'sfreq': 1000.0,
#     'experimental_info': {'paradigm_type': 'EEG-fMRI',
#      'trial_structure': '5 tasks: classicalMusic + 3 genMusic runs + washout',
#      'music_type': 'Generated music + classical pieces',
#      'additional_data': 'Simultaneous fMRI acquisition',
#      'emotion_reporting': 'FEELTRACE interface',
#      'tasks': ['classicalMusic',
#       'genMusic01',
#       'genMusic02',
#       'genMusic03',
#       'washout'],
#      'description': 'Joint EEG-fMRI with classical music and continuous emotion reporting',
#      'task_name': 'genMusic01'},
#     'bids_path': BIDSPath(
#     root: datasets/bcmi/bcmi-fmri
#     datatype: eeg
#     basename: sub-21_task-genMusic01),
#     'n_trials': 1},
#    'genMusic02': {'raw': <RawEDF | sub-21_task-genMusic02_eeg.edf, 47 x 581000 (581.0 s), ~41 KiB, data not loaded>,
#     'events':        onset  duration  trial_type
#     0      0.001     0.001           1
#     1      0.001     0.001        1283
#     2      0.041     0.001          47
#     3      0.769     0.001        1285
#     4      1.501     0.001       34053
#     ..       ...       ...         ...
#     589  571.981     0.001          47
#     590  573.981     0.001          47
#     591  575.981     0.001          47
#     592  577.981     0.001          47
#     593  579.981     0.001          47
#
#     [594 rows x 3 columns],
#     'processed_events': {'emotion_events':    onset  duration  trial_type emotion_description valence arousal
#      0  0.001     0.001           1       Excited/Happy    High    High,
#      'marker_events':        onset  duration  trial_type
#      1      0.001     0.001        1283
#      3      0.769     0.001        1285
#      4      1.501     0.001       34053
#      13    15.238     0.001         768
#      14    15.244     0.001         768
#      59    59.595     0.001         768
#      60    59.599     0.001         768
#      107  104.906     0.001         768
#      108  104.911     0.001         768
#      153  148.910     0.001         768
#      154  148.915     0.001         768
#      202  195.905     0.001         768
#      203  195.909     0.001         768
#      250  241.898     0.001         768
#      251  241.902     0.001         768
#      297  287.574     0.001         768
#      298  287.578     0.001         768
#      345  333.251     0.001         768
#      346  333.256     0.001         768
#      393  379.226     0.001         768
#      394  379.230     0.001         768
#      442  425.904     0.001         768
#      443  425.908     0.001         768
#      489  470.912     0.001         768
#      490  470.916     0.001         768
#      537  516.888     0.001         768
#      538  516.893     0.001         768,
#      'all_events':        onset  duration  trial_type
#      0      0.001     0.001           1
#      1      0.001     0.001        1283
#      2      0.041     0.001          47
#      3      0.769     0.001        1285
#      4      1.501     0.001       34053
#      ..       ...       ...         ...
#      589  571.981     0.001          47
#      590  573.981     0.001          47
#      591  575.981     0.001          47
#      592  577.981     0.001          47
#      593  579.981     0.001          47
#
#      [594 rows x 3 columns],
#      'fmri_trials': [{'trial_number': 1,
#        'onset': np.float64(15.238),
#        'duration': 40.0,
#        'music_file': None,
#        'music_code': 0,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 2,
#        'onset': np.float64(59.595),
#        'duration': 40.0,
#        'music_file': 'generated/2-*_*.wav',
#        'music_code': 2,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 3,
#        'onset': np.float64(104.906),
#        'duration': 40.0,
#        'music_file': 'generated/4-*_*.wav',
#        'music_code': 4,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 4,
#        'onset': np.float64(148.91),
#        'duration': 40.0,
#        'music_file': 'generated/1-*_*.wav',
#        'music_code': 1,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 5,
#        'onset': np.float64(195.905),
#        'duration': 40.0,
#        'music_file': None,
#        'music_code': 0,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 6,
#        'onset': np.float64(241.898),
#        'duration': 40.0,
#        'music_file': 'generated/4-*_*.wav',
#        'music_code': 4,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 7,
#        'onset': np.float64(287.574),
#        'duration': 40.0,
#        'music_file': 'generated/4-*_*.wav',
#        'music_code': 4,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 8,
#        'onset': np.float64(333.251),
#        'duration': 40.0,
#        'music_file': 'generated/4-*_*.wav',
#        'music_code': 4,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 9,
#        'onset': np.float64(379.226),
#        'duration': 40.0,
#        'music_file': None,
#        'music_code': 0,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 10,
#        'onset': np.float64(425.904),
#        'duration': 40.0,
#        'music_file': None,
#        'music_code': 0,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 11,
#        'onset': np.float64(470.912),
#        'duration': 40.0,
#        'music_file': 'generated/1-*_*.wav',
#        'music_code': 1,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 12,
#        'onset': np.float64(516.888),
#        'duration': 40.0,
#        'music_file': 'generated/2-*_*.wav',
#        'music_code': 2,
#        'task_type': 'generatedMusic'}]},
#     'duration': np.float64(581.0),
#     'n_channels': 47,
#     'sfreq': 1000.0,
#     'experimental_info': {'paradigm_type': 'EEG-fMRI',
#      'trial_structure': '5 tasks: classicalMusic + 3 genMusic runs + washout',
#      'music_type': 'Generated music + classical pieces',
#      'additional_data': 'Simultaneous fMRI acquisition',
#      'emotion_reporting': 'FEELTRACE interface',
#      'tasks': ['classicalMusic',
#       'genMusic01',
#       'genMusic02',
#       'genMusic03',
#       'washout'],
#      'description': 'Joint EEG-fMRI with classical music and continuous emotion reporting',
#      'task_name': 'genMusic02'},
#     'bids_path': BIDSPath(
#     root: datasets/bcmi/bcmi-fmri
#     datatype: eeg
#     basename: sub-21_task-genMusic02),
#     'n_trials': 1},
#    'genMusic03': {'raw': <RawEDF | sub-21_task-genMusic03_eeg.edf, 47 x 580000 (580.0 s), ~41 KiB, data not loaded>,
#     'events':        onset  duration  trial_type
#     0      0.001     0.001           1
#     1      0.001     0.001          47
#     2      0.001     0.001        1283
#     3      1.121     0.001          47
#     4      1.169     0.001        1285
#     ..       ...       ...         ...
#     585  571.121     0.001          47
#     586  573.121     0.001          47
#     587  575.121     0.001          47
#     588  577.121     0.001          47
#     589  579.121     0.001          47
#
#     [590 rows x 3 columns],
#     'processed_events': {'emotion_events':    onset  duration  trial_type emotion_description valence arousal
#      0  0.001     0.001           1       Excited/Happy    High    High,
#      'marker_events':        onset  duration  trial_type
#      2      0.001     0.001        1283
#      4      1.169     0.001        1285
#      5      1.501     0.001       34053
#      13    13.123     0.001         768
#      14    13.128     0.001         768
#      60    58.767     0.001         768
#      61    58.772     0.001         768
#      108  105.043     0.001         768
#      109  105.047     0.001         768
#      154  148.448     0.001         768
#      155  148.452     0.001         768
#      202  193.422     0.001         768
#      203  193.426     0.001         768
#      246  237.062     0.001         768
#      247  237.066     0.001         768
#      295  283.139     0.001         768
#      296  283.143     0.001         768
#      342  328.384     0.001         768
#      343  328.390     0.001         768
#      389  373.121     0.001         768
#      390  373.125     0.001         768
#      438  419.450     0.001         768
#      439  419.455     0.001         768
#      482  463.038     0.001         768
#      483  463.042     0.001         768
#      530  508.397     0.001         768
#      531  508.401     0.001         768,
#      'all_events':        onset  duration  trial_type
#      0      0.001     0.001           1
#      1      0.001     0.001          47
#      2      0.001     0.001        1283
#      3      1.121     0.001          47
#      4      1.169     0.001        1285
#      ..       ...       ...         ...
#      585  571.121     0.001          47
#      586  573.121     0.001          47
#      587  575.121     0.001          47
#      588  577.121     0.001          47
#      589  579.121     0.001          47
#
#      [590 rows x 3 columns],
#      'fmri_trials': [{'trial_number': 1,
#        'onset': np.float64(13.123),
#        'duration': 40.0,
#        'music_file': 'generated/4-*_*.wav',
#        'music_code': 4,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 2,
#        'onset': np.float64(58.767),
#        'duration': 40.0,
#        'music_file': None,
#        'music_code': 0,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 3,
#        'onset': np.float64(105.043),
#        'duration': 40.0,
#        'music_file': None,
#        'music_code': 0,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 4,
#        'onset': np.float64(148.448),
#        'duration': 40.0,
#        'music_file': 'generated/4-*_*.wav',
#        'music_code': 4,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 5,
#        'onset': np.float64(193.422),
#        'duration': 40.0,
#        'music_file': None,
#        'music_code': 0,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 6,
#        'onset': np.float64(237.062),
#        'duration': 40.0,
#        'music_file': 'generated/1-*_*.wav',
#        'music_code': 1,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 7,
#        'onset': np.float64(283.139),
#        'duration': 40.0,
#        'music_file': None,
#        'music_code': 0,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 8,
#        'onset': np.float64(328.384),
#        'duration': 40.0,
#        'music_file': 'generated/4-*_*.wav',
#        'music_code': 4,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 9,
#        'onset': np.float64(373.121),
#        'duration': 40.0,
#        'music_file': None,
#        'music_code': 0,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 10,
#        'onset': np.float64(419.45),
#        'duration': 40.0,
#        'music_file': None,
#        'music_code': 0,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 11,
#        'onset': np.float64(463.038),
#        'duration': 40.0,
#        'music_file': None,
#        'music_code': 0,
#        'task_type': 'generatedMusic'},
#       {'trial_number': 12,
#        'onset': np.float64(508.397),
#        'duration': 40.0,
#        'music_file': 'generated/4-*_*.wav',
#        'music_code': 4,
#        'task_type': 'generatedMusic'}]},
#     'duration': np.float64(580.0),
#     'n_channels': 47,
#     'sfreq': 1000.0,
#     'experimental_info': {'paradigm_type': 'EEG-fMRI',
#      'trial_structure': '5 tasks: classicalMusic + 3 genMusic runs + washout',
#      'music_type': 'Generated music + classical pieces',
#      'additional_data': 'Simultaneous fMRI acquisition',
#      'emotion_reporting': 'FEELTRACE interface',
#      'tasks': ['classicalMusic',
#       'genMusic01',
#       'genMusic02',
#       'genMusic03',
#       'washout'],
#      'description': 'Joint EEG-fMRI with classical music and continuous emotion reporting',
#      'task_name': 'genMusic03'},
#     'bids_path': BIDSPath(
#     root: datasets/bcmi/bcmi-fmri
#     datatype: eeg
#     basename: sub-21_task-genMusic03),
#     'n_trials': 1},
#    'washout': {'raw': <RawEDF | sub-21_task-washout_eeg.edf, 47 x 103000 (103.0 s), ~41 KiB, data not loaded>,
#     'events':        onset  duration  trial_type
#     0      0.001     0.001           1
#     1      0.001     0.001          47
#     2      0.141     0.001          47
#     3      0.422     0.001         265
#     4      2.141     0.001          47
#     ..       ...       ...         ...
#     125   97.605     0.001         265
#     126   98.141     0.001          47
#     127   99.458     0.001         265
#     128  100.141     0.001          47
#     129  101.235     0.001         265
#
#     [130 rows x 3 columns],
#     'processed_events': {'emotion_events':    onset  duration  trial_type emotion_description valence arousal
#      0  0.001     0.001           1       Excited/Happy    High    High,
#      'marker_events':        onset  duration  trial_type
#      3      0.422     0.001         265
#      5      2.239     0.001         265
#      7      5.095     0.001         265
#      13    13.174     0.001         265
#      16    16.011     0.001         265
#      19    17.825     0.001         265
#      24    21.406     0.001         265
#      28    24.159     0.001         265
#      30    25.968     0.001         265
#      35    29.533     0.001         265
#      39    32.184     0.001         265
#      43    34.816     0.001         265
#      45    36.562     0.001         265
#      48    38.278     0.001         265
#      52    40.775     0.001         265
#      55    43.379     0.001         265
#      58    45.198     0.001         265
#      61    47.017     0.001         265
#      64    48.843     0.001         265
#      66    50.624     0.001         265
#      70    53.201     0.001         265
#      75    57.609     0.001         265
#      79    60.259     0.001         265
#      81    62.047     0.001         265
#      86    64.752     0.001         265
#      88    66.488     0.001         265
#      92    69.106     0.001         265
#      95    71.832     0.001         265
#      100   75.166     0.001         265
#      102   76.959     0.001         265
#      104   78.989     0.001         265
#      105   80.060     0.001         265
#      107   82.068     0.001         265
#      110   84.978     0.001         265
#      112   86.940     0.001         265
#      114   89.745     0.001        1283
#      115   89.775     0.001         265
#      116   89.775     0.001        1285
#      118   90.245     0.001       34053
#      119   91.594     0.001         265
#      121   93.319     0.001         265
#      123   95.857     0.001         265
#      125   97.605     0.001         265
#      127   99.458     0.001         265
#      129  101.235     0.001         265,
#      'all_events':        onset  duration  trial_type
#      0      0.001     0.001           1
#      1      0.001     0.001          47
#      2      0.141     0.001          47
#      3      0.422     0.001         265
#      4      2.141     0.001          47
#      ..       ...       ...         ...
#      125   97.605     0.001         265
#      126   98.141     0.001          47
#      127   99.458     0.001         265
#      128  100.141     0.001          47
#      129  101.235     0.001         265
#
#      [130 rows x 3 columns],
#      'fmri_trials': []},
#     'duration': np.float64(103.0),
#     'n_channels': 47,
#     'sfreq': 1000.0,
#     'experimental_info': {'paradigm_type': 'EEG-fMRI',
#      'trial_structure': '5 tasks: classicalMusic + 3 genMusic runs + washout',
#      'music_type': 'Generated music + classical pieces',
#      'additional_data': 'Simultaneous fMRI acquisition',
#      'emotion_reporting': 'FEELTRACE interface',
#      'tasks': ['classicalMusic',
#       'genMusic01',
#       'genMusic02',
#       'genMusic03',
#       'washout'],
#      'description': 'Joint EEG-fMRI with classical music and continuous emotion reporting',
#      'task_name': 'washout'},
#     'bids_path': BIDSPath(
#     root: datasets/bcmi/bcmi-fmri
#     datatype: eeg
#     basename: sub-21_task-washout),
#     'n_trials': 1}}}}

# %%
# Direct EEG data inspection
from mne_bids import BIDSPath, read_raw_bids
import pandas as pd

print("🔍 DIRECT EEG DATA INSPECTION")
print("=" * 40)

# Load genMusic01 directly
bids_path = BIDSPath(
    subject='01',
    task='genMusic01',
    datatype='eeg',
    root='./datasets/bcmi/bcmi-fmri'
)

try:
    print("Loading raw EEG data...")
    raw = read_raw_bids(bids_path, verbose=False)
    
    print(f"\nChannel names ({len(raw.ch_names)} total):")
    for i, ch_name in enumerate(raw.ch_names):
        if 'music' in ch_name.lower() or 'stimuli' in ch_name.lower():
            print(f"  {i:2d}: {ch_name} ⭐")
        else:
            print(f"  {i:2d}: {ch_name}")
    
    # Check for music channel specifically
    if 'music' in raw.ch_names:
        print(f"\n✅ 'music' channel found!")
        
        # Load events to see trial onsets
        events_path = bids_path.copy().update(suffix='events', extension='.tsv')
        events_df = pd.read_csv(events_path.fpath, sep='\t')
        
        # Find 768 events (trial starts)
        trial_starts = events_df[events_df['trial_type'] == 768]
        print(f"\nTrial start events (768): {len(trial_starts)}")
        if len(trial_starts) > 0:
            print(trial_starts[['onset', 'duration', 'trial_type']].head())
            
            # Sample music channel at first trial start
            first_onset = trial_starts.iloc[0]['onset']
            music_idx = raw.ch_names.index('music')
            sample_idx = int(first_onset * raw.info['sfreq'])
            
            music_val = raw.get_data(picks=[music_idx])[0, sample_idx]
            music_code = int(music_val * 20)
            
            print(f"\nAt first trial (onset={first_onset:.3f}s):")
            print(f"  Music channel value: {music_val}")
            print(f"  Music code (val*20): {music_code}")
            print(f"  Formatted: {str(music_code).zfill(3)}")
            
            if len(str(music_code).zfill(3)) >= 3:
                s_code = str(music_code).zfill(3)
                music_file = f"{s_code[0]}-{s_code[1]}_{s_code[2]}.wav"
                print(f"  Music file: {music_file}")
    else:
        print(f"\n❌ 'music' channel not found!")
        
except Exception as e:
    print(f"❌ Error loading data: {e}")
    import traceback
    traceback.print_exc()
# Out:
# 🔍 DIRECT EEG DATA INSPECTION
# ========================================
# Loading raw EEG data...
#
# Channel names (47 total):
#    0: Fp1
#    1: Fp2
#    2: F3
#    3: F4
#    4: C3
#    5: C4
#    6: P3
#    7: P4
#    8: O1
#    9: O2
#   10: F7
#   11: F8
#   12: T7
#   13: T8
#   14: P7
#   15: P8
#   16: Fz
#   17: Cz
#   18: Pz
#   19: Oz
#   20: FC1
#   21: FC2
#   22: CP1
#   23: CP2
#   24: FC5
#   25: FC6
#   26: CP5
#   27: CP6
#   28: TP9
#   29: TP10
#   30: POz
#   31: ECG
#   32: ft_valance
#   33: ft_arousal
#   34: ft_x
#   35: ft_y
#   36: ft_ghostvalence
#   37: ft_ghostarousal
#   38: music ⭐
#   39: trialtype
#   40: sams_valence
#   41: sams_arousal
#   42: sams_valencert
#   43: sams_arousalrt
#   44: nback_stimuli ⭐
#   45: nback_keypress
#   46: Status
#
# ✅ 'music' channel found!
#
# Trial start events (768): 24
#        onset  duration  trial_type
# 242  191.151     0.001         768
# 243  191.158     0.001         768
# 333  238.056     0.001         768
# 334  238.060     0.001         768
# 406  283.447     0.001         768
#
# At first trial (onset=191.151s):
#   Music channel value: 1.4050086213473715e-05
#   Music code (val*20): 0
#   Formatted: 000
#   Music file: 0-0_0.wav
# /tmp/ipykernel_26767/1809379087.py:18: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/1809379087.py:18: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/1809379087.py:18: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/1809379087.py:18: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/1809379087.py:18: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/1809379087.py:18: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/1809379087.py:18: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/1809379087.py:18: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/1809379087.py:18: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/1809379087.py:18: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/1809379087.py:18: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/1809379087.py:18: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/1809379087.py:18: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/1809379087.py:18: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/1809379087.py:18: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/1809379087.py:18: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/1809379087.py:18: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)

# %%
# Sample music channel values at multiple trial onsets
from mne_bids import BIDSPath, read_raw_bids
import pandas as pd
import numpy as np

print("🎵 SAMPLING MUSIC CHANNEL VALUES")
print("=" * 45)

# Load genMusic01 data
bids_path = BIDSPath(
    subject='01',
    task='genMusic01', 
    datatype='eeg',
    root='./datasets/bcmi/bcmi-fmri'
)

raw = read_raw_bids(bids_path, verbose=False)
events_path = bids_path.copy().update(suffix='events', extension='.tsv')
events_df = pd.read_csv(events_path.fpath, sep='\t')

# Find all 768 events (removing consecutive duplicates)
trial_starts = events_df[events_df['trial_type'] == 768].copy()
onsets = trial_starts['onset'].values
unique_onsets = onsets[np.concatenate([[True], np.diff(onsets) > 1])]

print(f"Total 768 events: {len(trial_starts)}")
print(f"Unique trial onsets (>1s apart): {len(unique_onsets)}")

# Sample music channel at each unique trial onset
music_idx = raw.ch_names.index('music')
sfreq = raw.info['sfreq']

print(f"\nMusic channel sampling at trial onsets:")
for i, onset in enumerate(unique_onsets):
    sample_idx = int(onset * sfreq)
    if sample_idx < raw.n_times:
        music_val = raw.get_data(picks=[music_idx])[0, sample_idx]
        music_code = int(music_val * 20) if music_val > 0 else 0
        
        # Format as 3-digit string
        s_code = str(music_code).zfill(3)
        if len(s_code) >= 3 and music_code > 0:
            music_file = f"generated/{s_code[0]}-{s_code[1]}_{s_code[2]}.wav"
        else:
            music_file = f"generated/silence_or_baseline.wav"
            
        print(f"  Trial {i+1:2d}: onset={onset:7.3f}s, val={music_val:12.6e}, "
              f"code={music_code:3d}, file={music_file}")

# Also check around the trial onsets to see if values change
print(f"\nChecking music channel around first trial onset:")
first_onset = unique_onsets[0]
start_sample = int((first_onset - 5) * sfreq)  # 5s before
end_sample = int((first_onset + 5) * sfreq)    # 5s after

if start_sample >= 0 and end_sample < raw.n_times:
    music_segment = raw.get_data(picks=[music_idx])[0, start_sample:end_sample]
    unique_vals = np.unique(music_segment)
    
    print(f"  Unique values in 10s window: {len(unique_vals)}")
    print(f"  Min: {music_segment.min():.6e}")
    print(f"  Max: {music_segment.max():.6e}")
    print(f"  Non-zero values: {len(music_segment[music_segment != 0])}")
    
    if len(unique_vals) > 1:
        print(f"  Sample unique values: {unique_vals[:10]}")
# Out:
# 🎵 SAMPLING MUSIC CHANNEL VALUES
# =============================================
# /tmp/ipykernel_26767/4019187128.py:17: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/4019187128.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/4019187128.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/4019187128.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/4019187128.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/4019187128.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/4019187128.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/4019187128.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/4019187128.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/4019187128.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/4019187128.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/4019187128.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/4019187128.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/4019187128.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/4019187128.py:17: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/4019187128.py:17: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/4019187128.py:17: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)
# Total 768 events: 24
# Unique trial onsets (>1s apart): 12
#
# Music channel sampling at trial onsets:
#   Trial  1: onset=191.151s, val=1.405009e-05, code=  0, file=generated/silence_or_baseline.wav
#   Trial  2: onset=238.056s, val=2.259969e-05, code=  0, file=generated/silence_or_baseline.wav
#   Trial  3: onset=283.447s, val=1.409969e-05, code=  0, file=generated/silence_or_baseline.wav
#   Trial  4: onset=327.102s, val=4.105016e-05, code=  0, file=generated/silence_or_baseline.wav
#   Trial  5: onset=373.110s, val=1.409969e-05, code=  0, file=generated/silence_or_baseline.wav
#   Trial  6: onset=417.098s, val=1.409969e-05, code=  0, file=generated/silence_or_baseline.wav
#   Trial  7: onset=464.092s, val=4.109977e-05, code=  0, file=generated/silence_or_baseline.wav
#   Trial  8: onset=507.697s, val=1.414992e-05, code=  0, file=generated/silence_or_baseline.wav
#   Trial  9: onset=552.086s, val=1.405009e-05, code=  0, file=generated/silence_or_baseline.wav
#   Trial 10: onset=597.493s, val=0.000000e+00, code=  0, file=generated/silence_or_baseline.wav
#   Trial 11: onset=643.735s, val=4.115000e-05, code=  0, file=generated/silence_or_baseline.wav
#   Trial 12: onset=689.143s, val=2.259969e-05, code=  0, file=generated/silence_or_baseline.wav
#
# Checking music channel around first trial onset:
#   Unique values in 10s window: 2
#   Min: 0.000000e+00
#   Max: 1.405009e-05
#   Non-zero values: 1000
#   Sample unique values: [0.00000000e+00 1.40500862e-05]

# %%
# Check music channel values at 768 markers for both genMusic and classicalMusic
from mne_bids import BIDSPath, read_raw_bids
import pandas as pd
import numpy as np

print("🔍 MUSIC CHANNEL VALUES AT 768 TRIAL MARKERS")
print("=" * 55)

tasks_to_check = ['genMusic01', 'classicalMusic']

for task in tasks_to_check:
    print(f"\n--- {task.upper()} ---")
    
    # Load data
    bids_path = BIDSPath(
        subject='01',
        task=task,
        datatype='eeg',
        root='./datasets/bcmi/bcmi-fmri'
    )
    
    try:
        raw = read_raw_bids(bids_path, verbose=False)
        events_path = bids_path.copy().update(suffix='events', extension='.tsv')
        events_df = pd.read_csv(events_path.fpath, sep='\t')
        
        # Find 768 events
        trial_starts = events_df[events_df['trial_type'] == 768].copy()
        print(f"Total 768 events: {len(trial_starts)}")
        
        if len(trial_starts) > 0 and 'music' in raw.ch_names:
            music_idx = raw.ch_names.index('music')
            sfreq = raw.info['sfreq']
            
            print(f"Music channel values at 768 markers:")
            for i, (_, event) in enumerate(trial_starts.head(10).iterrows()):  # Check first 10
                onset = event['onset']
                sample_idx = int(onset * sfreq)
                
                if sample_idx < raw.n_times:
                    music_val = raw.get_data(picks=[music_idx])[0, sample_idx]
                    
                    # Check values shortly after the marker too
                    after_samples = [sample_idx + offset for offset in [100, 500, 1000]]  # 0.1s, 0.5s, 1s after
                    after_values = []
                    
                    for after_idx in after_samples:
                        if after_idx < raw.n_times:
                            after_val = raw.get_data(picks=[music_idx])[0, after_idx]
                            after_values.append(after_val)
                        else:
                            after_values.append(None)
                    
                    print(f"  Event {i+1}: onset={onset:7.3f}s")
                    print(f"    At marker:    {music_val:.8e}")
                    print(f"    +0.1s:        {after_values[0]:.8e}" if after_values[0] is not None else "    +0.1s:        N/A")
                    print(f"    +0.5s:        {after_values[1]:.8e}" if after_values[1] is not None else "    +0.5s:        N/A")
                    print(f"    +1.0s:        {after_values[2]:.8e}" if after_values[2] is not None else "    +1.0s:        N/A")
                    
                    # Check if value is essentially zero
                    is_zero = abs(music_val) < 1e-10
                    print(f"    Is ~zero:     {is_zero}")
                    print()
        else:
            print("No 768 events found or no music channel")
            
    except Exception as e:
        print(f"Error loading {task}: {e}")

print("✅ Analysis completed!")
# Out:
# 🔍 MUSIC CHANNEL VALUES AT 768 TRIAL MARKERS
# =======================================================
#
# --- GENMUSIC01 ---
# Total 768 events: 24
# Music channel values at 768 markers:
#   Event 1: onset=191.151s
#     At marker:    1.40500862e-05
#     +0.1s:        1.40500862e-05
#     +0.5s:        1.40500862e-05
#     +1.0s:        0.00000000e+00
#     Is ~zero:     False
#
#   Event 2: onset=191.158s
#     At marker:    1.40500862e-05
#     +0.1s:        1.40500862e-05
#     +0.5s:        1.40500862e-05
#     +1.0s:        0.00000000e+00
#     Is ~zero:     False
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)
#   Event 3: onset=238.056s
#     At marker:    2.25996918e-05
#     +0.1s:        2.25996918e-05
#     +0.5s:        2.25996918e-05
#     +1.0s:        0.00000000e+00
#     Is ~zero:     False
#
#   Event 4: onset=238.060s
#     At marker:    2.25996918e-05
#     +0.1s:        2.25996918e-05
#     +0.5s:        2.25996918e-05
#     +1.0s:        0.00000000e+00
#     Is ~zero:     False
#
#   Event 5: onset=283.447s
#     At marker:    1.40996910e-05
#     +0.1s:        1.40996910e-05
#     +0.5s:        1.40996910e-05
#     +1.0s:        0.00000000e+00
#     Is ~zero:     False
#
#   Event 6: onset=283.451s
#     At marker:    1.40996910e-05
#     +0.1s:        1.40996910e-05
#     +0.5s:        1.40996910e-05
#     +1.0s:        0.00000000e+00
#     Is ~zero:     False
#
#   Event 7: onset=327.102s
#     At marker:    4.10501625e-05
#     +0.1s:        4.10501625e-05
#     +0.5s:        4.10501625e-05
#     +1.0s:        0.00000000e+00
#     Is ~zero:     False
#
#   Event 8: onset=327.106s
#     At marker:    4.10501625e-05
#     +0.1s:        4.10501625e-05
#     +0.5s:        4.10501625e-05
#     +1.0s:        0.00000000e+00
#     Is ~zero:     False
#
#   Event 9: onset=373.110s
#     At marker:    1.40996910e-05
#     +0.1s:        1.40996910e-05
#     +0.5s:        1.40996910e-05
#     +1.0s:        0.00000000e+00
#     Is ~zero:     False
#
#   Event 10: onset=373.115s
#     At marker:    1.40996910e-05
#     +0.1s:        1.40996910e-05
#     +0.5s:        1.40996910e-05
#     +1.0s:        0.00000000e+00
#     Is ~zero:     False
#
#
# --- CLASSICALMUSIC ---
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#   raw = read_raw_bids(bids_path, verbose=False)
# /tmp/ipykernel_26767/3196285421.py:23: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   raw = read_raw_bids(bids_path, verbose=False)
# Total 768 events: 12
# Music channel values at 768 markers:
#   Event 1: onset= 31.771s
#     At marker:    3.50000000e-07
#     +0.1s:        3.50000000e-07
#     +0.5s:        0.00000000e+00
#     +1.0s:        0.00000000e+00
#     Is ~zero:     False
#
#   Event 2: onset=195.807s
#     At marker:    2.50001526e-07
#     +0.1s:        2.50001526e-07
#     +0.5s:        0.00000000e+00
#     +1.0s:        0.00000000e+00
#     Is ~zero:     False
#
#   Event 3: onset=362.010s
#     At marker:    1.49997711e-07
#     +0.1s:        1.49997711e-07
#     +0.5s:        1.49997711e-07
#     +1.0s:        0.00000000e+00
#     Is ~zero:     False
#
#   Event 4: onset=517.864s
#     At marker:    1.49997711e-07
#     +0.1s:        1.49997711e-07
#     +0.5s:        0.00000000e+00
#     +1.0s:        0.00000000e+00
#     Is ~zero:     False
#
#   Event 5: onset=676.140s
#     At marker:    2.50001526e-07
#     +0.1s:        2.50001526e-07
#     +0.5s:        2.50001526e-07
#     +1.0s:        0.00000000e+00
#     Is ~zero:     False
#
#   Event 6: onset=841.794s
#     At marker:    9.99984741e-08
#     +0.1s:        9.99984741e-08
#     +0.5s:        0.00000000e+00
#     +1.0s:        0.00000000e+00
#     Is ~zero:     False
#
#   Event 7: onset=973.926s
#     At marker:    0.00000000e+00
#     +0.1s:        0.00000000e+00
#     +0.5s:        0.00000000e+00
#     +1.0s:        0.00000000e+00
#     Is ~zero:     True
#
#   Event 8: onset=1140.532s
#     At marker:    0.00000000e+00
#     +0.1s:        0.00000000e+00
#     +0.5s:        0.00000000e+00
#     +1.0s:        0.00000000e+00
#     Is ~zero:     True
#
#   Event 9: onset=1296.737s
#     At marker:    3.50000000e-07
#     +0.1s:        3.50000000e-07
#     +0.5s:        0.00000000e+00
#     +1.0s:        0.00000000e+00
#     Is ~zero:     False
#
#   Event 10: onset=1460.071s
#     At marker:    9.99984741e-08
#     +0.1s:        9.99984741e-08
#     +0.5s:        9.99984741e-08
#     +1.0s:        0.00000000e+00
#     Is ~zero:     False
#
# ✅ Analysis completed!

# %%
print("🔬 TESTING DIFFERENT SCALING APPROACHES")
print("=" * 50)

# Sample values from our analysis
genmusic_values = [1.40500862e-05, 2.25996918e-05, 1.40996910e-05, 4.10501625e-05]
classical_values = [3.50000000e-07, 2.50001526e-07, 1.49997711e-07]

print("\n--- GENMUSIC VALUES ---")
for i, val in enumerate(genmusic_values[:4]):
    print(f"Original value: {val:.2e}")
    print(f"  × 20:        {val * 20:.6f}")
    print(f"  × 1000:      {val * 1000:.6f}")
    print(f"  × 100000:    {val * 100000:.1f}")
    print(f"  × 1000000:   {val * 1000000:.1f}")
    # Try to find integer codes
    for scale in [20, 1000, 100000, 1000000]:
        scaled = val * scale
        if 0 < scaled < 1000:  # reasonable music file range
            print(f"  → {scale:>7}× = {scaled:.0f} (music file code?)")
    print()

print("\n--- CLASSICAL VALUES ---")
for i, val in enumerate(classical_values[:3]):
    print(f"Original value: {val:.2e}")
    print(f"  × 20:        {val * 20:.6f}")
    print(f"  × 1000:      {val * 1000:.6f}")
    print(f"  × 100000:    {val * 100000:.6f}")
    print(f"  × 1000000:   {val * 1000000:.1f}")
    print(f"  × 10000000:  {val * 10000000:.1f}")
    # Try to find integer codes
    for scale in [20, 1000, 100000, 1000000, 10000000]:
        scaled = val * scale
        if 0 < scaled < 1000:  # reasonable music file range
            print(f"  → {scale:>8}× = {scaled:.0f} (music file code?)")
    print()
# Out:
# 🔬 TESTING DIFFERENT SCALING APPROACHES
# ==================================================
#
# --- GENMUSIC VALUES ---
# Original value: 1.41e-05
#   × 20:        0.000281
#   × 1000:      0.014050
#   × 100000:    1.4
#   × 1000000:   14.1
#   →      20× = 0 (music file code?)
#   →    1000× = 0 (music file code?)
#   →  100000× = 1 (music file code?)
#   → 1000000× = 14 (music file code?)
#
# Original value: 2.26e-05
#   × 20:        0.000452
#   × 1000:      0.022600
#   × 100000:    2.3
#   × 1000000:   22.6
#   →      20× = 0 (music file code?)
#   →    1000× = 0 (music file code?)
#   →  100000× = 2 (music file code?)
#   → 1000000× = 23 (music file code?)
#
# Original value: 1.41e-05
#   × 20:        0.000282
#   × 1000:      0.014100
#   × 100000:    1.4
#   × 1000000:   14.1
#   →      20× = 0 (music file code?)
#   →    1000× = 0 (music file code?)
#   →  100000× = 1 (music file code?)
#   → 1000000× = 14 (music file code?)
#
# Original value: 4.11e-05
#   × 20:        0.000821
#   × 1000:      0.041050
#   × 100000:    4.1
#   × 1000000:   41.1
#   →      20× = 0 (music file code?)
#   →    1000× = 0 (music file code?)
#   →  100000× = 4 (music file code?)
#   → 1000000× = 41 (music file code?)
#
#
# --- CLASSICAL VALUES ---
# Original value: 3.50e-07
#   × 20:        0.000007
#   × 1000:      0.000350
#   × 100000:    0.035000
#   × 1000000:   0.3
#   × 10000000:  3.5
#   →       20× = 0 (music file code?)
#   →     1000× = 0 (music file code?)
#   →   100000× = 0 (music file code?)
#   →  1000000× = 0 (music file code?)
#   → 10000000× = 4 (music file code?)
#
# Original value: 2.50e-07
#   × 20:        0.000005
#   × 1000:      0.000250
#   × 100000:    0.025000
#   × 1000000:   0.3
#   × 10000000:  2.5
#   →       20× = 0 (music file code?)
#   →     1000× = 0 (music file code?)
#   →   100000× = 0 (music file code?)
#   →  1000000× = 0 (music file code?)
#   → 10000000× = 3 (music file code?)
#
# Original value: 1.50e-07
#   × 20:        0.000003
#   × 1000:      0.000150
#   × 100000:    0.015000
#   × 1000000:   0.1
#   × 10000000:  1.5
#   →       20× = 0 (music file code?)
#   →     1000× = 0 (music file code?)
#   →   100000× = 0 (music file code?)
#   →  1000000× = 0 (music file code?)
#   → 10000000× = 1 (music file code?)

# %%
print("🎵 COMPREHENSIVE MUSIC FILE MAPPING TEST")
print("=" * 50)

import os
from pathlib import Path

# Check what music files exist
stimuli_path = Path("/home/zmrocze/studia/uwr/magisterka/datasets/bcmi/bcmi-fmri/stimuli")
generated_files = list((stimuli_path / "generated").glob("*.wav"))
classical_files = list((stimuli_path / "classical").glob("*.mp3"))

print(f"📁 Found {len(generated_files)} generated music files")
print(f"📁 Found {len(classical_files)} classical music files")

# Test our scaling hypothesis
def decode_music_channel(value, task_type):
    """Decode music channel value to get file identifier"""
    if task_type == "genMusic":
        # Scale by 100,000 for generated music
        scaled = value * 100000
        return int(round(scaled))
    elif task_type == "classicalMusic":
        # Scale by 10,000,000 for classical music  
        scaled = value * 10000000
        return int(round(scaled))
    return None

# Test with our sample values
print("\n--- GENMUSIC DECODING ---")
genmusic_values = [1.40500862e-05, 2.25996918e-05, 1.40996910e-05, 4.10501625e-05]
for i, val in enumerate(genmusic_values):
    code = decode_music_channel(val, "genMusic")
    print(f"Value {val:.2e} → Code {code}")
    
    # Try to find matching files
    matches = [f for f in generated_files if f.name.startswith(f"{code}-")]
    if matches:
        print(f"  ✅ Found {len(matches)} files: {matches[0].name} ...")
    else:
        print(f"  ❌ No files found for code {code}")

print("\n--- CLASSICAL DECODING ---")
classical_values = [3.50000000e-07, 2.50001526e-07, 1.49997711e-07]
for i, val in enumerate(classical_values):
    code = decode_music_channel(val, "classicalMusic")
    print(f"Value {val:.2e} → Code {code}")
    
    # Try to find matching files
    matches = [f for f in classical_files if f.name.startswith(f"p{code}_")]
    if matches:
        print(f"  ✅ Found file: {matches[0].name}")
    else:
        print(f"  ❌ No file found for code p{code}")

# Let's also list the actual classical files to see the pattern
print("\n--- CLASSICAL FILES ---")
for f in sorted(classical_files):
    print(f"  {f.name}")
# Out:
# 🎵 COMPREHENSIVE MUSIC FILE MAPPING TEST
# ==================================================
# 📁 Found 216 generated music files
# 📁 Found 7 classical music files
#
# --- GENMUSIC DECODING ---
# Value 1.41e-05 → Code 1
#   ✅ Found 24 files: 1-2_3.wav ...
# Value 2.26e-05 → Code 2
#   ✅ Found 24 files: 2-9_1.wav ...
# Value 1.41e-05 → Code 1
#   ✅ Found 24 files: 1-2_3.wav ...
# Value 4.11e-05 → Code 4
#   ✅ Found 24 files: 4-1_3.wav ...
#
# --- CLASSICAL DECODING ---
# Value 3.50e-07 → Code 4
#   ✅ Found file: p4_chopin-n4-op28-Konczal.mp3
# Value 2.50e-07 → Code 3
#   ✅ Found file: p3_chopin-n3-op10-bertoglio.mp3
# Value 1.50e-07 → Code 1
#   ✅ Found file: p1_chopin-n10-op12-bertoglio.mp3
#
# --- CLASSICAL FILES ---
#   p1_chopin-n10-op12-bertoglio.mp3
#   p2_rachmaninoff-n5-op32-prelude-in-g-major.mp3
#   p3_chopin-n3-op10-bertoglio.mp3
#   p4_chopin-n4-op28-Konczal.mp3
#   p5_mendelssohn-variations-serieuses-op54-larrard.mp3
#   p6_beethoven-n4-allegro-molte-e-con-brio-sinadinovic.mp3
#   p7_beethoven-n3-adagio-con-expression-bertoli.mp3

# %%
print("🧪 TESTING CORRECTED BCMIFMRILoader")
print("=" * 50)

# Reload the module to get the updated implementation
import importlib
import bcmi
importlib.reload(bcmi)

from bcmi import BCMIFMRILoader

# Test with our dataset
loader = BCMIFMRILoader("/home/zmrocze/studia/uwr/magisterka/datasets/bcmi/bcmi-fmri")

# Load subjects using the correct method
print("📁 Loading subjects...")
try:
    loader.load_all_subjects(max_subjects=1, max_runs_per_session=2)  # Load just one subject with 2 runs to test
    
    if loader.data:
        print(f"✅ Data loaded successfully!")
        print(f"   Available subjects: {list(loader.data.keys())}")
        
        # Check the processed events for each subject
        for subject_id, subject_data in loader.data.items():
            print(f"\n=== SUBJECT {subject_id} ===")
            for session_id, session_data in subject_data.items():
                print(f"\n--- SESSION {session_id} ---")
                for run_id, run_data in session_data.items():
                    task_name = run_data['experimental_info']['task_name']
                    processed_events = run_data.get('processed_events', {})
                    fmri_trials = processed_events.get('fmri_trials', [])
                    
                    print(f"\n--- RUN {run_id} ({task_name}) ---")
                    print(f"Found {len(fmri_trials)} fMRI trials")
                    
                    for i, trial in enumerate(fmri_trials[:3]):  # Show first 3 trials
                        print(f"  Trial {trial['trial_number']}: {trial['onset']:.1f}s")
                        print(f"    Task: {trial['task_type']}")
                        print(f"    Music: {trial['music_file']}")
                        print(f"    Code: {trial['music_code']}")
                        print(f"    Duration: {trial['duration']:.1f}s")
                    
                    if len(fmri_trials) > 3:
                        print(f"  ... and {len(fmri_trials) - 3} more trials")
        
    else:
        print("❌ No data loaded")
        
except Exception as e:
    print(f"❌ Error loading data: {e}")
    import traceback
    traceback.print_exc()
# Out:
# 🧪 TESTING CORRECTED BCMIFMRILoader
# ==================================================
# 📁 Loading subjects...
# 🔄 Loading bcmi-fmri dataset...
# 📦 Subjects to load: 1 of 21
# 🏃 Max runs per session: 2
#
# Loading subject 01 (bcmi-fmri):
#   ✓ Run classicalMusic: 1915.0s, 2256 events, 1 trials
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Physical range is not defined in following channels:
# sams_valence, sams_arousal, sams_valencert, sams_arousalrt, nback_stimuli, nback_keypress
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_valance" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_arousal" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_x" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_y" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostvalence" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "ft_ghostarousal" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "music" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "trialtype" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valence" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousal" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_valencert" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "reponse". Type of channel "sams_arousalrt" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "stimuli". Type of channel "nback_stimuli" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: No BIDS -> MNE mapping found for channel type "response". Type of channel "nback_keypress" will be set to "misc".
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: The number of channels in the channels.tsv sidecar file (46) does not match the number of channels in the raw data file (47). Will not try to set channel names.
#
# /home/zmrocze/studia/uwr/magisterka/src/bcmi.py:299: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: FP1, FP2
#   ✓ Run genMusic01: 742.0s, 1162 events, 1 trials
#
# 📊 LOADING SUMMARY:
# • Successfully loaded: 1 subjects
# • Failed to load: 0 subjects
# • Success rate: 100.0%
# ✅ Data loaded successfully!
#    Available subjects: ['01']
#
# === SUBJECT 01 ===
#
# --- SESSION no_session ---
#
# --- RUN classicalMusic (classicalMusic) ---
# Found 12 fMRI trials
#   Trial 1: 31.8s
#     Task: classicalMusic
#     Music: classical/p4_*.mp3
#     Code: 4
#     Duration: 164.0s
#   Trial 2: 195.8s
#     Task: classicalMusic
#     Music: classical/p3_*.mp3
#     Code: 3
#     Duration: 166.2s
#   Trial 3: 362.0s
#     Task: classicalMusic
#     Music: classical/p1_*.mp3
#     Code: 1
#     Duration: 155.9s
#   ... and 9 more trials
#
# --- RUN genMusic01 (genMusic01) ---
# Found 12 fMRI trials
#   Trial 1: 191.2s
#     Task: generatedMusic
#     Music: generated/1-*_*.wav
#     Code: 1
#     Duration: 40.0s
#   Trial 2: 238.1s
#     Task: generatedMusic
#     Music: generated/2-*_*.wav
#     Code: 2
#     Duration: 40.0s
#   Trial 3: 283.4s
#     Task: generatedMusic
#     Music: generated/1-*_*.wav
#     Code: 1
#     Duration: 40.0s
#   ... and 9 more trials
